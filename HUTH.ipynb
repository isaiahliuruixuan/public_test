# %%
import numpy as np
import random as rn

# The below is necessary in Python 3.2.3 onwards to
# have reproducible behavior for certain hash-based operations.
# See these references for further details:
# https://docs.python.org/3.4/using/cmdline.html#envvar-PYTHONHASHSEED
# https://github.com/fchollet/keras/issues/2280#issuecomment-306959926

import os
os.environ['PYTHONHASHSEED'] = '01'

# The below is necessary for starting Numpy generated random numbers
# in a well-defined initial state.

np.random.seed(421)

# The below is necessary for starting core Python generated random numbers
# in a well-defined state.

rn.seed(123451)


import logging

import numpy as np
from keras import layers
from keras.models import Model, load_model

from data.datasets import *
from eval import keras_metrics, metrics
from nlp import tokenizer as tk
from utils import info, preprocessing, postprocessing, plots

# %%
# LOGGING CONFIGURATION

logging.basicConfig(
    format='%(asctime)s\t%(levelname)s\t%(message)s',
    level=logging.DEBUG)

info.log_versions()

# END LOGGING CONFIGURATION

# GLOBAL VARIABLES

SAVE_MODEL = False
MODEL_PATH = "models/mergernn.h5"
SHOW_PLOTS = False

# END GLOBAL VARIABLES

# Dataset and hyperparameters for each dataset

DATASET = Hulth

if DATASET == Semeval2017:
    tokenizer = tk.tokenizers.nltk
    DATASET_FOLDER = "data/Semeval2017"
    MAX_DOCUMENT_LENGTH = 400
    MAX_VOCABULARY_SIZE = 20000
    EMBEDDINGS_SIZE = 300
    BATCH_SIZE = 32
    EPOCHS = 10
elif DATASET == Hulth:
    tokenizer = tk.tokenizers.nltk
    DATASET_FOLDER = "data/Hulth2003"
    MAX_DOCUMENT_LENGTH = 550
    MAX_VOCABULARY_SIZE = 20000
    EMBEDDINGS_SIZE = 300
    BATCH_SIZE = 32
    EPOCHS = 41
else:
    raise NotImplementedError("Can't set the hyperparameters: unknown dataset")


# END PARAMETERS

logging.info("Loading dataset...")

data = DATASET(DATASET_FOLDER)

train_doc_str, train_answer_str = data.load_train()
test_doc_str, test_answer_str = data.load_test()
val_doc_str, val_answer_str = data.load_validation()

train_doc, train_answer = tk.tokenize_set(train_doc_str,train_answer_str,tokenizer)
test_doc, test_answer = tk.tokenize_set(test_doc_str,test_answer_str,tokenizer)
val_doc, val_answer = tk.tokenize_set(val_doc_str,val_answer_str,tokenizer)

# Sanity check
# logging.info("Sanity check: %s",metrics.precision(test_answer,test_answer))

logging.info("Dataset loaded. Preprocessing data...")
# Out:
# 2021-12-03 21:44:34,763	INFO	Keras version 2.7.0
# 2021-12-03 21:44:34,764	INFO	Numpy version 1.20.1
# 2021-12-03 21:44:34,765	INFO	Tensorflow version 2.7.0
# 2021-12-03 21:44:34,766	INFO	Loading dataset...
# 2021-12-03 21:44:34,767	DEBUG	Initialized dataset Hulth, 2003 from folder data/Hulth2003
# 2021-12-03 21:44:35,439	DEBUG	Loaded training set for dataset Hulth, 2003
# 2021-12-03 21:44:35,754	DEBUG	Loaded test set for dataset Hulth, 2003
# 2021-12-03 21:44:36,079	DEBUG	Loaded validation set for dataset Hulth, 2003
# 2021-12-03 21:44:38,458	INFO	Dataset loaded. Preprocessing data...

# %%
print(train_doc_str['1174'])
print(train_answer_str['1174'])
# Out:
# Optimization of cutting conditions for single pass turning operations using a
# 	deterministic approach
# An optimization analysis, strategy and CAM software for the selection of
# 	economic cutting conditions in single pass turning operations are
# 	presented using a deterministic approach. The optimization is based on
# 	criteria typified by the maximum production rate and includes a host of
# 	practical constraints. It is shown that the deterministic optimization
# 	approach involving mathematical analyses of constrained economic trends
# 	and graphical representation on the feed-speed domain provides a
# 	clearly defined strategy that not only provides a unique global optimum
# 	solution, but also the software that is suitable for on-line CAM
# 	applications. A numerical study has verified the developed optimization
# 	strategies and software and has shown the economic benefits of using
# 	optimization
#
# ['cutting conditions optimization', 'single pass turning operations', 'deterministic\n\tapproach', 'CAM software', 'economic cutting conditions', 'maximum production\n\trate', 'mathematical analyses', 'constrained economic trends', 'process\n\tplanning']

# %%
train_x,train_y,test_x,test_y,val_x,val_y,embedding_matrix = preprocessing.\
    prepare_sequential(train_doc, train_answer, test_doc, test_answer,val_doc,val_answer,
                       max_document_length=MAX_DOCUMENT_LENGTH,
                       max_vocabulary_size=MAX_VOCABULARY_SIZE,
                       embeddings_size=EMBEDDINGS_SIZE)

# weigh training examples: everything that's not class 0 (not kp)
# gets a heavier score
#train_y_weights = np.argmax(train_y,axis=2) # this removes the one-hot representation
#train_y_weights[train_y_weights > 0] = 20
#train_y_weights[train_y_weights < 1] = 1

from sklearn.utils import class_weight
train_y_weights = np.argmax(train_y, axis=2)
train_y_weights = np.reshape(class_weight.compute_sample_weight('balanced', train_y_weights.flatten()),
                             np.shape(train_y_weights))


logging.info("Data preprocessing complete.")
logging.info("Maximum possible recall: %s",
             metrics.recall(test_answer,
                               postprocessing.get_words(test_doc,postprocessing.undo_sequential(test_y))))
# Out:
# 2021-12-03 21:44:38,668	DEBUG	Fitting dictionary on 2000 documents...
# 2021-12-03 21:44:38,748	DEBUG	Dictionary fitting completed. Found 18312 unique tokens
# 2021-12-03 21:44:38,815	DEBUG	Longest training document : 556 tokens
# 2021-12-03 21:44:38,816	DEBUG	Longest test document :     380 tokens
# 2021-12-03 21:44:38,816	DEBUG	Longest validation document : 314 tokens
# 2021-12-03 21:44:38,999	DEBUG	Training set samples size   : (1000, 550)
# 2021-12-03 21:44:38,999	DEBUG	Training set answers size   : (1000, 550, 3)
# 2021-12-03 21:44:39,000	DEBUG	Test set samples size       : (500, 550)
# 2021-12-03 21:44:39,000	DEBUG	Test set answers size       : (500, 550, 3)
# 2021-12-03 21:44:39,001	DEBUG	Validation set samples size : (500, 550)
# 2021-12-03 21:44:39,002	DEBUG	Validation set answers size : (500, 550, 3)
# 2021-12-03 21:44:39,003	DEBUG	Loading GloVe pre-trained embeddings from glove.6B.300d.txt
# 2021-12-03 21:44:57,199	DEBUG	Total embeddings found: 400000.
# 2021-12-03 21:44:57,199	DEBUG	Building embedding matrix of size [18313,300]...
# 2021-12-03 21:44:57,544	INFO	Data preprocessing complete.
# 2021-12-03 21:44:57,646	INFO	Maximum possible recall: 0.7691837980867088

# %%
if not SAVE_MODEL or not os.path.isfile(MODEL_PATH) :

    logging.debug("Building the network...")

    summary = layers.Input(shape=(MAX_DOCUMENT_LENGTH,))
    encoded_summary = layers.Embedding(np.shape(embedding_matrix)[0],
                        EMBEDDINGS_SIZE,
                        weights=[embedding_matrix],
                        input_length=MAX_DOCUMENT_LENGTH,
                        trainable=False)(summary)


    encoded_summary = layers.Bidirectional(layers.GRU((int)(EMBEDDINGS_SIZE/2)))\
        (encoded_summary)
    encoded_summary = layers.Dropout(0.25)(encoded_summary)
    encoded_summary = layers.Dense(EMBEDDINGS_SIZE) \
        (encoded_summary)
    encoded_summary = layers.RepeatVector(MAX_DOCUMENT_LENGTH)(encoded_summary)

    document = layers.Input(shape=(MAX_DOCUMENT_LENGTH,))
    encoded_document = layers.Embedding(np.shape(embedding_matrix)[0],
                        EMBEDDINGS_SIZE,
                        weights=[embedding_matrix],
                        input_length=MAX_DOCUMENT_LENGTH,
                        trainable=False)(document)

    merged = layers.add([encoded_summary, encoded_document])
    merged = layers.Bidirectional(layers.GRU((int)(EMBEDDINGS_SIZE/2),return_sequences=True))(merged)
    merged = layers.Dropout(0.3)(merged)
    merged = layers.Bidirectional(layers.GRU((int)(EMBEDDINGS_SIZE /4), return_sequences=True))(merged)
    merged = layers.Dropout(0.3)(merged)
    merged = layers.Dense((int)(EMBEDDINGS_SIZE / 2))(merged)
    merged = layers.Dropout(0.3)(merged)
    prediction = layers.TimeDistributed(layers.Dense(3,activation='softmax'))(merged)

    model = Model([document,summary],prediction)

    logging.info("Compiling the network...")
    model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'],
                  sample_weight_mode="temporal")
    print(model.summary())

    metrics_callback = keras_metrics.MetricsCallback([val_x,val_x],val_y)

    logging.info("Fitting the network...")
    history = model.fit([train_x,train_x], train_y,
                        validation_data=([val_x,val_x],val_y),
                        epochs=EPOCHS,
                        batch_size=BATCH_SIZE,
                        sample_weight=train_y_weights,
                        callbacks=[metrics_callback])

    if SHOW_PLOTS :
        plots.plot_accuracy(history)
        plots.plot_loss(history)
        plots.plot_prf(metrics_callback)

    if SAVE_MODEL :
        model.save(MODEL_PATH)
        logging.info("Model saved in %s", MODEL_PATH)

else :
    logging.info("Loading existing model from %s...",MODEL_PATH)
    model = load_model(MODEL_PATH)
    logging.info("Completed loading model from file")


logging.info("Predicting on test set...")
output = model.predict(x=[test_x,test_x], verbose=1)
logging.debug("Shape of output array: %s",np.shape(output))

obtained_tokens = postprocessing.undo_sequential(output)
obtained_words = postprocessing.get_words(test_doc,obtained_tokens)

precision = metrics.precision(test_answer,obtained_words)
recall = metrics.recall(test_answer,obtained_words)
f1 = metrics.f1(precision,recall)

print("###    Obtained Scores    ###")
print("###     (full dataset)    ###")
print("###")
print("### Precision : %.4f" % precision)
print("### Recall    : %.4f" % recall)
print("### F1        : %.4f" % f1)
print("###                       ###")

keras_precision = keras_metrics.keras_precision(test_y,output)
keras_recall = keras_metrics.keras_recall(test_y,output)
keras_f1 = keras_metrics.keras_f1(test_y,output)

print("###    Obtained Scores    ###")
print("###    (fixed dataset)    ###")
print("###")
print("### Precision : %.4f" % keras_precision)
print("### Recall    : %.4f" % keras_recall)
print("### F1        : %.4f" % keras_f1)
print("###                       ###")

clean_words = postprocessing.get_valid_patterns(obtained_words)

precision = metrics.precision(test_answer,clean_words)
recall = metrics.recall(test_answer,clean_words)
f1 = metrics.f1(precision,recall)

print("###    Obtained Scores    ###")
print("### (full dataset,        ###")
print("###  pos patterns filter) ###")
print("###")
print("### Precision : %.4f" % precision)
print("### Recall    : %.4f" % recall)
print("### F1        : %.4f" % f1)
print("###                       ###")


obtained_words_top = postprocessing.get_top_words(test_doc, output, 5)

precision_top = metrics.precision(test_answer, obtained_words_top)
recall_top = metrics.recall(test_answer, obtained_words_top)
f1_top = metrics.f1(precision_top, recall_top)

print("###    Obtained Scores    ###")
print("### (full dataset, top 5) ###")
print("###")
print("### Precision : %.4f" % precision_top)
print("### Recall    : %.4f" % recall_top)
print("### F1        : %.4f" % f1_top)
print("###                       ###")

obtained_words_top = postprocessing.get_top_words(test_doc, output, 10)

precision_top = metrics.precision(test_answer, obtained_words_top)
recall_top = metrics.recall(test_answer, obtained_words_top)
f1_top = metrics.f1(precision_top, recall_top)

print("###    Obtained Scores    ###")
print("### (full dataset, top 10)###")
print("###")
print("### Precision : %.4f" % precision_top)
print("### Recall    : %.4f" % recall_top)
print("### F1        : %.4f" % f1_top)
print("###                       ###")

obtained_words_top = postprocessing.get_top_words(test_doc, output, 15)

precision_top = metrics.precision(test_answer, obtained_words_top)
recall_top = metrics.recall(test_answer, obtained_words_top)
f1_top = metrics.f1(precision_top, recall_top)

print("###    Obtained Scores    ###")
print("### (full dataset, top 15)###")
print("###")
print("### Precision : %.4f" % precision_top)
print("### Recall    : %.4f" % recall_top)
print("### F1        : %.4f" % f1_top)
print("###                       ###")


print("###                       ###")
print("###                       ###")
print("###       STEMMING        ###")
print("###                       ###")
print("###                       ###")

STEM_MODE = metrics.stemMode.both

precision = metrics.precision(test_answer, obtained_words,STEM_MODE)
recall = metrics.recall(test_answer, obtained_words,STEM_MODE)
f1 = metrics.f1(precision, recall)

print("###    Obtained Scores    ###")
print("###     (full dataset)    ###")
print("###")
print("### Precision : %.4f" % precision)
print("### Recall    : %.4f" % recall)
print("### F1        : %.4f" % f1)
print("###                       ###")

keras_precision = keras_metrics.keras_precision(test_y, output)
keras_recall = keras_metrics.keras_recall(test_y, output)
keras_f1 = keras_metrics.keras_f1(test_y, output)

print("###    Obtained Scores    ###")
print("###    (fixed dataset)    ###")
print("###")
print("### Precision : %.4f" % keras_precision)
print("### Recall    : %.4f" % keras_recall)
print("### F1        : %.4f" % keras_f1)
print("###                       ###")

clean_words = postprocessing.get_valid_patterns(obtained_words)

precision = metrics.precision(test_answer, clean_words,STEM_MODE)
recall = metrics.recall(test_answer, clean_words,STEM_MODE)
f1 = metrics.f1(precision, recall)

print("###    Obtained Scores    ###")
print("### (full dataset,        ###")
print("###  pos patterns filter) ###")
print("###")
print("### Precision : %.4f" % precision)
print("### Recall    : %.4f" % recall)
print("### F1        : %.4f" % f1)
print("###                       ###")

obtained_words_top = postprocessing.get_top_words(test_doc, output, 5)

precision_top = metrics.precision(test_answer, obtained_words_top,STEM_MODE)
recall_top = metrics.recall(test_answer, obtained_words_top,STEM_MODE)
f1_top = metrics.f1(precision_top, recall_top)

print("###    Obtained Scores    ###")
print("### (full dataset, top 5) ###")
print("###")
print("### Precision : %.4f" % precision_top)
print("### Recall    : %.4f" % recall_top)
print("### F1        : %.4f" % f1_top)
print("###                       ###")

obtained_words_top = postprocessing.get_top_words(test_doc, output, 10)

precision_top = metrics.precision(test_answer, obtained_words_top,STEM_MODE)
recall_top = metrics.recall(test_answer, obtained_words_top,STEM_MODE)
f1_top = metrics.f1(precision_top, recall_top)

print("###    Obtained Scores    ###")
print("### (full dataset, top 10)###")
print("###")
print("### Precision : %.4f" % precision_top)
print("### Recall    : %.4f" % recall_top)
print("### F1        : %.4f" % f1_top)
print("###                       ###")

obtained_words_top = postprocessing.get_top_words(test_doc, output, 15)

precision_top = metrics.precision(test_answer, obtained_words_top,STEM_MODE)
recall_top = metrics.recall(test_answer, obtained_words_top,STEM_MODE)
f1_top = metrics.f1(precision_top, recall_top)

print("###    Obtained Scores    ###")
print("### (full dataset, top 15)###")
print("###")
print("### Precision : %.4f" % precision_top)
print("### Recall    : %.4f" % recall_top)
print("### F1        : %.4f" % f1_top)
print("###                       ###")
# Out:
# 2021-12-03 21:44:57,672	DEBUG	Building the network...
# 2021-12-03 21:44:58,845	INFO	Compiling the network...
# 2021-12-03 21:44:58,857	INFO	Fitting the network...
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 550)]        0           []
#
#  embedding (Embedding)          (None, 550, 300)     5493900     ['input_1[0][0]']
#
#  bidirectional (Bidirectional)  (None, 300)          406800      ['embedding[0][0]']
#
#  dropout (Dropout)              (None, 300)          0           ['bidirectional[0][0]']
#
#  dense (Dense)                  (None, 300)          90300       ['dropout[0][0]']
#
#  input_2 (InputLayer)           [(None, 550)]        0           []
#
#  repeat_vector (RepeatVector)   (None, 550, 300)     0           ['dense[0][0]']
#
#  embedding_1 (Embedding)        (None, 550, 300)     5493900     ['input_2[0][0]']
#
#  add (Add)                      (None, 550, 300)     0           ['repeat_vector[0][0]',
#                                                                   'embedding_1[0][0]']
#
#  bidirectional_1 (Bidirectional  (None, 550, 300)    406800      ['add[0][0]']
#  )
#
#  dropout_1 (Dropout)            (None, 550, 300)     0           ['bidirectional_1[0][0]']
#
#  bidirectional_2 (Bidirectional  (None, 550, 150)    169650      ['dropout_1[0][0]']
#  )
#
#  dropout_2 (Dropout)            (None, 550, 150)     0           ['bidirectional_2[0][0]']
#
#  dense_1 (Dense)                (None, 550, 150)     22650       ['dropout_2[0][0]']
#
#  dropout_3 (Dropout)            (None, 550, 150)     0           ['dense_1[0][0]']
#
#  time_distributed (TimeDistribu  (None, 550, 3)      453         ['dropout_3[0][0]']
#  ted)
#
# ==================================================================================================
# Total params: 12,084,453
# Trainable params: 1,096,653
# Non-trainable params: 10,987,800
# __________________________________________________________________________________________________
# None
# Epoch 1/41
# 32/32 [==============================] - ETA: 0s - loss: 0.7572 - accuracy: 0.7551
# ###   Validation Scores   ###
# ###
# ### Epoch     : 1
# ### Precision : 0.0712
# ### Recall    : 0.3711
# ### F1        : 0.1195
# ###                       ###
# 32/32 [==============================] - 71s 2s/step - loss: 0.7572 - accuracy: 0.7551 - val_loss: 0.3406 - val_accuracy: 0.8766
# Epoch 2/41
# 32/32 [==============================] - ETA: 0s - loss: 0.4045 - accuracy: 0.8843
# ###   Validation Scores   ###
# ###
# ### Epoch     : 2
# ### Precision : 0.1592
# ### Recall    : 0.6297
# ### F1        : 0.2542
# ###                       ###
# 32/32 [==============================] - 62s 2s/step - loss: 0.4045 - accuracy: 0.8843 - val_loss: 0.2719 - val_accuracy: 0.9113
# Epoch 3/41
# 32/32 [==============================] - ETA: 0s - loss: 0.3211 - accuracy: 0.8928
# ###   Validation Scores   ###
# ###
# ### Epoch     : 3
# ### Precision : 0.1840
# ### Recall    : 0.6454
# ### F1        : 0.2863
# ###                       ###
# 32/32 [==============================] - 62s 2s/step - loss: 0.3211 - accuracy: 0.8928 - val_loss: 0.1949 - val_accuracy: 0.9274
# Epoch 4/41
# 32/32 [==============================] - ETA: 0s - loss: 0.2947 - accuracy: 0.9035
# ###   Validation Scores   ###
# ###
# ### Epoch     : 4
# ### Precision : 0.1890
# ### Recall    : 0.6600
# ### F1        : 0.2939
# ###                       ###
# 32/32 [==============================] - 61s 2s/step - loss: 0.2947 - accuracy: 0.9035 - val_loss: 0.2532 - val_accuracy: 0.9165
# Epoch 5/41
# 32/32 [==============================] - ETA: 0s - loss: 0.2639 - accuracy: 0.9110
# ###   Validation Scores   ###
# ###
# ### Epoch     : 5
# ### Precision : 0.1458
# ### Recall    : 0.6172
# ### F1        : 0.2359
# ###                       ###
# 32/32 [==============================] - 61s 2s/step - loss: 0.2639 - accuracy: 0.9110 - val_loss: 0.3518 - val_accuracy: 0.8926
# Epoch 6/41
# 32/32 [==============================] - ETA: 0s - loss: 0.2487 - accuracy: 0.9146
# ###   Validation Scores   ###
# ###
# ### Epoch     : 6
# ### Precision : 0.0476
# ### Recall    : 0.6869
# ### F1        : 0.0890
# ###                       ###
# 32/32 [==============================] - 61s 2s/step - loss: 0.2487 - accuracy: 0.9146 - val_loss: 0.8898 - val_accuracy: 0.6557
# Epoch 7/41
# 32/32 [==============================] - ETA: 0s - loss: 0.2364 - accuracy: 0.9074
# ###   Validation Scores   ###
# ###
# ### Epoch     : 7
# ### Precision : 0.1933
# ### Recall    : 0.7048
# ### F1        : 0.3034
# ###                       ###
# 32/32 [==============================] - 61s 2s/step - loss: 0.2364 - accuracy: 0.9074 - val_loss: 0.2206 - val_accuracy: 0.9245
# Epoch 8/41
# 32/32 [==============================] - ETA: 0s - loss: 0.2193 - accuracy: 0.9199
# ###   Validation Scores   ###
# ###
# ### Epoch     : 8
# ### Precision : 0.2039
# ### Recall    : 0.6776
# ### F1        : 0.3134
# ###                       ###
# 32/32 [==============================] - 61s 2s/step - loss: 0.2193 - accuracy: 0.9199 - val_loss: 0.2524 - val_accuracy: 0.9219
# Epoch 9/41
# 32/32 [==============================] - ETA: 0s - loss: 0.2109 - accuracy: 0.9224
# ###   Validation Scores   ###
# ###
# ### Epoch     : 9
# ### Precision : 0.2236
# ### Recall    : 0.7090
# ### F1        : 0.3400
# ###                       ###
# 32/32 [==============================] - 61s 2s/step - loss: 0.2109 - accuracy: 0.9224 - val_loss: 0.2161 - val_accuracy: 0.9314
# Epoch 10/41
# 32/32 [==============================] - ETA: 0s - loss: 0.1954 - accuracy: 0.9255
# ###   Validation Scores   ###
# ###
# ### Epoch     : 10
# ### Precision : 0.2187
# ### Recall    : 0.6809
# ### F1        : 0.3311
# ###                       ###
# 32/32 [==============================] - 61s 2s/step - loss: 0.1954 - accuracy: 0.9255 - val_loss: 0.2463 - val_accuracy: 0.9252
# Epoch 11/41
# 32/32 [==============================] - ETA: 0s - loss: 0.1857 - accuracy: 0.9280
# ###   Validation Scores   ###
# ###
# ### Epoch     : 11
# ### Precision : 0.2299
# ### Recall    : 0.6818
# ### F1        : 0.3438
# ###                       ###
# 32/32 [==============================] - 62s 2s/step - loss: 0.1857 - accuracy: 0.9280 - val_loss: 0.2195 - val_accuracy: 0.9321
# Epoch 12/41
# 32/32 [==============================] - ETA: 0s - loss: 0.1733 - accuracy: 0.9295
# ###   Validation Scores   ###
# ###
# ### Epoch     : 12
# ### Precision : 0.2365
# ### Recall    : 0.6778
# ### F1        : 0.3507
# ###                       ###
# 32/32 [==============================] - 61s 2s/step - loss: 0.1733 - accuracy: 0.9295 - val_loss: 0.1634 - val_accuracy: 0.9444
# Epoch 13/41
# 32/32 [==============================] - ETA: 0s - loss: 0.1587 - accuracy: 0.9330
# ###   Validation Scores   ###
# ###
# ### Epoch     : 13
# ### Precision : 0.2722
# ### Recall    : 0.7129
# ### F1        : 0.3939
# ###                       ###
# 32/32 [==============================] - 62s 2s/step - loss: 0.1587 - accuracy: 0.9330 - val_loss: 0.1883 - val_accuracy: 0.9428
# Epoch 14/41
# 32/32 [==============================] - ETA: 0s - loss: 0.1488 - accuracy: 0.9350
# ###   Validation Scores   ###
# ###
# ### Epoch     : 14
# ### Precision : 0.2074
# ### Recall    : 0.6454
# ### F1        : 0.3139
# ###                       ###
# 32/32 [==============================] - 61s 2s/step - loss: 0.1488 - accuracy: 0.9350 - val_loss: 0.2518 - val_accuracy: 0.9257
# Epoch 15/41
# 32/32 [==============================] - ETA: 0s - loss: 0.1419 - accuracy: 0.9348
# ###   Validation Scores   ###
# ###
# ### Epoch     : 15
# ### Precision : 0.2425
# ### Recall    : 0.7231
# ### F1        : 0.3632
# ###                       ###
# 32/32 [==============================] - 62s 2s/step - loss: 0.1419 - accuracy: 0.9348 - val_loss: 0.2213 - val_accuracy: 0.9382
# Epoch 16/41
# 32/32 [==============================] - ETA: 0s - loss: 0.1292 - accuracy: 0.9376
# ###   Validation Scores   ###
# ###
# ### Epoch     : 16
# ### Precision : 0.2859
# ### Recall    : 0.6913
# ### F1        : 0.4045
# ###                       ###
# 32/32 [==============================] - 62s 2s/step - loss: 0.1292 - accuracy: 0.9376 - val_loss: 0.1947 - val_accuracy: 0.9446
# Epoch 17/41
# 32/32 [==============================] - ETA: 0s - loss: 0.1205 - accuracy: 0.9407
# ###   Validation Scores   ###
# ###
# ### Epoch     : 17
# ### Precision : 0.2609
# ### Recall    : 0.7065
# ### F1        : 0.3811
# ###                       ###
# 32/32 [==============================] - 62s 2s/step - loss: 0.1205 - accuracy: 0.9407 - val_loss: 0.1835 - val_accuracy: 0.9443
# Epoch 18/41
# 32/32 [==============================] - ETA: 0s - loss: 0.1244 - accuracy: 0.9377
# ###   Validation Scores   ###
# ###
# ### Epoch     : 18
# ### Precision : 0.2387
# ### Recall    : 0.7178
# ### F1        : 0.3582
# ###                       ###
# 32/32 [==============================] - 62s 2s/step - loss: 0.1244 - accuracy: 0.9377 - val_loss: 0.2165 - val_accuracy: 0.9364
# Epoch 19/41
# 32/32 [==============================] - ETA: 0s - loss: 0.1073 - accuracy: 0.9418
# ###   Validation Scores   ###
# ###
# ### Epoch     : 19
# ### Precision : 0.2359
# ### Recall    : 0.6789
# ### F1        : 0.3501
# ###                       ###
# 32/32 [==============================] - 62s 2s/step - loss: 0.1073 - accuracy: 0.9418 - val_loss: 0.2226 - val_accuracy: 0.9401
# Epoch 20/41
# 32/32 [==============================] - ETA: 0s - loss: 0.1049 - accuracy: 0.9450
# ###   Validation Scores   ###
# ###
# ### Epoch     : 20
# ### Precision : 0.2750
# ### Recall    : 0.7222
# ### F1        : 0.3983
# ###                       ###
# 32/32 [==============================] - 62s 2s/step - loss: 0.1049 - accuracy: 0.9450 - val_loss: 0.1885 - val_accuracy: 0.9444
# Epoch 21/41
# 32/32 [==============================] - ETA: 0s - loss: 0.0979 - accuracy: 0.9458
# ###   Validation Scores   ###
# ###
# ### Epoch     : 21
# ### Precision : 0.2768
# ### Recall    : 0.7187
# ### F1        : 0.3997
# ###                       ###
# 32/32 [==============================] - 61s 2s/step - loss: 0.0979 - accuracy: 0.9458 - val_loss: 0.1747 - val_accuracy: 0.9462
# Epoch 22/41
# 32/32 [==============================] - ETA: 0s - loss: 0.0933 - accuracy: 0.9485
# ###   Validation Scores   ###
# ###
# ### Epoch     : 22
# ### Precision : 0.2260
# ### Recall    : 0.7293
# ### F1        : 0.3450
# ###                       ###
# 32/32 [==============================] - 62s 2s/step - loss: 0.0933 - accuracy: 0.9485 - val_loss: 0.2800 - val_accuracy: 0.9328
# Epoch 23/41
# 32/32 [==============================] - ETA: 0s - loss: 0.0889 - accuracy: 0.9479
# ###   Validation Scores   ###
# ###
# ### Epoch     : 23
# ### Precision : 0.3035
# ### Recall    : 0.6951
# ### F1        : 0.4225
# ###                       ###
# 32/32 [==============================] - 62s 2s/step - loss: 0.0889 - accuracy: 0.9479 - val_loss: 0.1605 - val_accuracy: 0.9526
# Epoch 24/41
# 32/32 [==============================] - ETA: 0s - loss: 0.0845 - accuracy: 0.9499
# ###   Validation Scores   ###
# ###
# ### Epoch     : 24
# ### Precision : 0.2976
# ### Recall    : 0.6957
# ### F1        : 0.4169
# ###                       ###
# 32/32 [==============================] - 62s 2s/step - loss: 0.0845 - accuracy: 0.9499 - val_loss: 0.1782 - val_accuracy: 0.9495
# Epoch 25/41
# 32/32 [==============================] - ETA: 0s - loss: 0.0845 - accuracy: 0.9498
# ###   Validation Scores   ###
# ###
# ### Epoch     : 25
# ### Precision : 0.2830
# ### Recall    : 0.7171
# ### F1        : 0.4058
# ###                       ###
# 32/32 [==============================] - 62s 2s/step - loss: 0.0845 - accuracy: 0.9498 - val_loss: 0.1971 - val_accuracy: 0.9487
# Epoch 26/41
# 32/32 [==============================] - ETA: 0s - loss: 0.0792 - accuracy: 0.9525
# ###   Validation Scores   ###
# ###
# ### Epoch     : 26
# ### Precision : 0.3271
# ### Recall    : 0.6679
# ### F1        : 0.4392
# ###                       ###
# 32/32 [==============================] - 61s 2s/step - loss: 0.0792 - accuracy: 0.9525 - val_loss: 0.1324 - val_accuracy: 0.9574
# Epoch 27/41
# 32/32 [==============================] - ETA: 0s - loss: 0.0793 - accuracy: 0.9520
# ###   Validation Scores   ###
# ###
# ### Epoch     : 27
# ### Precision : 0.3106
# ### Recall    : 0.7015
# ### F1        : 0.4305
# ###                       ###
# 32/32 [==============================] - 61s 2s/step - loss: 0.0793 - accuracy: 0.9520 - val_loss: 0.1599 - val_accuracy: 0.9516
# Epoch 28/41
# 32/32 [==============================] - ETA: 0s - loss: 0.0744 - accuracy: 0.9548
# ###   Validation Scores   ###
# ###
# ### Epoch     : 28
# ### Precision : 0.2956
# ### Recall    : 0.6814
# ### F1        : 0.4124
# ###                       ###
# 32/32 [==============================] - 62s 2s/step - loss: 0.0744 - accuracy: 0.9548 - val_loss: 0.1790 - val_accuracy: 0.9504
# Epoch 29/41
# 32/32 [==============================] - ETA: 0s - loss: 0.0732 - accuracy: 0.9555
# ###   Validation Scores   ###
# ###
# ### Epoch     : 29
# ### Precision : 0.2676
# ### Recall    : 0.7092
# ### F1        : 0.3886
# ###                       ###
# 32/32 [==============================] - 61s 2s/step - loss: 0.0732 - accuracy: 0.9555 - val_loss: 0.1899 - val_accuracy: 0.9477
# Epoch 30/41
# 32/32 [==============================] - ETA: 0s - loss: 0.0723 - accuracy: 0.9564
# ###   Validation Scores   ###
# ###
# ### Epoch     : 30
# ### Precision : 0.2854
# ### Recall    : 0.6772
# ### F1        : 0.4015
# ###                       ###
# 32/32 [==============================] - 62s 2s/step - loss: 0.0723 - accuracy: 0.9564 - val_loss: 0.2008 - val_accuracy: 0.9460
# Epoch 31/41
# 32/32 [==============================] - ETA: 0s - loss: 0.0690 - accuracy: 0.9575
# ###   Validation Scores   ###
# ###
# ### Epoch     : 31
# ### Precision : 0.3128
# ### Recall    : 0.6834
# ### F1        : 0.4291
# ###                       ###
# 32/32 [==============================] - 61s 2s/step - loss: 0.0690 - accuracy: 0.9575 - val_loss: 0.1668 - val_accuracy: 0.9545
# Epoch 32/41
# 32/32 [==============================] - ETA: 0s - loss: 0.0655 - accuracy: 0.9597
# ###   Validation Scores   ###
# ###
# ### Epoch     : 32
# ### Precision : 0.2706
# ### Recall    : 0.6728
# ### F1        : 0.3860
# ###                       ###
# 32/32 [==============================] - 62s 2s/step - loss: 0.0655 - accuracy: 0.9597 - val_loss: 0.1948 - val_accuracy: 0.9497
# Epoch 33/41
# 32/32 [==============================] - ETA: 0s - loss: 0.0665 - accuracy: 0.9595
# ###   Validation Scores   ###
# ###
# ### Epoch     : 33
# ### Precision : 0.3075
# ### Recall    : 0.6891
# ### F1        : 0.4252
# ###                       ###
# 32/32 [==============================] - 61s 2s/step - loss: 0.0665 - accuracy: 0.9595 - val_loss: 0.2012 - val_accuracy: 0.9510
# Epoch 34/41
# 32/32 [==============================] - ETA: 0s - loss: 0.0637 - accuracy: 0.9608
# ###   Validation Scores   ###
# ###
# ### Epoch     : 34
# ### Precision : 0.3468
# ### Recall    : 0.6595
# ### F1        : 0.4545
# ###                       ###
# 32/32 [==============================] - 61s 2s/step - loss: 0.0637 - accuracy: 0.9608 - val_loss: 0.1512 - val_accuracy: 0.9578
# Epoch 35/41
# 32/32 [==============================] - ETA: 0s - loss: 0.0607 - accuracy: 0.9624
# ###   Validation Scores   ###
# ###
# ### Epoch     : 35
# ### Precision : 0.3393
# ### Recall    : 0.6507
# ### F1        : 0.4460
# ###                       ###
# 32/32 [==============================] - 61s 2s/step - loss: 0.0607 - accuracy: 0.9624 - val_loss: 0.1463 - val_accuracy: 0.9598
# Epoch 36/41
# 32/32 [==============================] - ETA: 0s - loss: 0.0602 - accuracy: 0.9630
# ###   Validation Scores   ###
# ###
# ### Epoch     : 36
# ### Precision : 0.3035
# ### Recall    : 0.6789
# ### F1        : 0.4194
# ###                       ###
# 32/32 [==============================] - 61s 2s/step - loss: 0.0602 - accuracy: 0.9630 - val_loss: 0.1644 - val_accuracy: 0.9554
# Epoch 37/41
# 32/32 [==============================] - ETA: 0s - loss: 0.0573 - accuracy: 0.9644
# ###   Validation Scores   ###
# ###
# ### Epoch     : 37
# ### Precision : 0.3491
# ### Recall    : 0.6432
# ### F1        : 0.4526
# ###                       ###
# 32/32 [==============================] - 61s 2s/step - loss: 0.0573 - accuracy: 0.9644 - val_loss: 0.1430 - val_accuracy: 0.9601
# Epoch 38/41
# 32/32 [==============================] - ETA: 0s - loss: 0.0549 - accuracy: 0.9658
# ###   Validation Scores   ###
# ###
# ### Epoch     : 38
# ### Precision : 0.3474
# ### Recall    : 0.6253
# ### F1        : 0.4467
# ###                       ###
# 32/32 [==============================] - 61s 2s/step - loss: 0.0549 - accuracy: 0.9658 - val_loss: 0.1527 - val_accuracy: 0.9608
# Epoch 39/41
# 32/32 [==============================] - ETA: 0s - loss: 0.0560 - accuracy: 0.9658
# ###   Validation Scores   ###
# ###
# ### Epoch     : 39
# ### Precision : 0.3388
# ### Recall    : 0.6507
# ### F1        : 0.4456
# ###                       ###
# 32/32 [==============================] - 61s 2s/step - loss: 0.0560 - accuracy: 0.9658 - val_loss: 0.1548 - val_accuracy: 0.9589
# Epoch 40/41
# 32/32 [==============================] - ETA: 0s - loss: 0.0527 - accuracy: 0.9672
# ###   Validation Scores   ###
# ###
# ### Epoch     : 40
# ### Precision : 0.3753
# ### Recall    : 0.5938
# ### F1        : 0.4599
# ###                       ###
# 32/32 [==============================] - 61s 2s/step - loss: 0.0527 - accuracy: 0.9672 - val_loss: 0.1367 - val_accuracy: 0.9639
# Epoch 41/41
# 32/32 [==============================] - ETA: 0s - loss: 0.0529 - accuracy: 0.9679
# ###   Validation Scores   ###
# ###
# ### Epoch     : 41
# ### Precision : 0.3168
# ### Recall    : 0.6225
# ### F1        : 0.4199
# ###                       ###
# 32/32 [==============================] - 61s 2s/step - loss: 0.0529 - accuracy: 0.9679 - val_loss: 0.1519 - val_accuracy: 0.9591
# 2021-12-03 22:27:09,495	INFO	Predicting on test set...
# 16/16 [==============================] - 7s 429ms/step
# 2021-12-03 22:27:16,424	DEBUG	Shape of output array: (500, 550, 3)
# ###    Obtained Scores    ###
# ###     (full dataset)    ###
# ###
# ### Precision : 0.3124
# ### Recall    : 0.5168
# ### F1        : 0.3894
# ###                       ###
# ###    Obtained Scores    ###
# ###    (fixed dataset)    ###
# ###
# ### Precision : 0.3310
# ### Recall    : 0.6314
# ### F1        : 0.4343
# ###                       ###
# ###    Obtained Scores    ###
# ### (full dataset,        ###
# ###  pos patterns filter) ###
# ###
# ### Precision : 0.3078
# ### Recall    : 0.4936
# ### F1        : 0.3791
# ###                       ###
# ###    Obtained Scores    ###
# ### (full dataset, top 5) ###
# ###
# ### Precision : 0.4642
# ### Recall    : 0.2339
# ### F1        : 0.3110
# ###                       ###
# ###    Obtained Scores    ###
# ### (full dataset, top 10)###
# ###
# ### Precision : 0.4030
# ### Recall    : 0.3808
# ### F1        : 0.3916
# ###                       ###
# ###    Obtained Scores    ###
# ### (full dataset, top 15)###
# ###
# ### Precision : 0.3575
# ### Recall    : 0.4555
# ### F1        : 0.4006
# ###                       ###
# ###                       ###
# ###                       ###
# ###       STEMMING        ###
# ###                       ###
# ###                       ###
# ###    Obtained Scores    ###
# ###     (full dataset)    ###
# ###
# ### Precision : 0.3206
# ### Recall    : 0.5225
# ### F1        : 0.3974
# ###                       ###
# ###    Obtained Scores    ###
# ###    (fixed dataset)    ###
# ###
# ### Precision : 0.3310
# ### Recall    : 0.6314
# ### F1        : 0.4343
# ###                       ###
# ###    Obtained Scores    ###
# ### (full dataset,        ###
# ###  pos patterns filter) ###
# ###
# ### Precision : 0.3165
# ### Recall    : 0.4987
# ### F1        : 0.3872
# ###                       ###
# ###    Obtained Scores    ###
# ### (full dataset, top 5) ###
# ###
# ### Precision : 0.4741
# ### Recall    : 0.2371
# ### F1        : 0.3161
# ###                       ###
# ###    Obtained Scores    ###
# ### (full dataset, top 10)###
# ###
# ### Precision : 0.4119
# ### Recall    : 0.3851
# ### F1        : 0.3980
# ###                       ###
# ###    Obtained Scores    ###
# ### (full dataset, top 15)###
# ###
# ### Precision : 0.3662
# ### Recall    : 0.4604
# ### F1        : 0.4079
# ###                       ###

# %%
print("###                       ###")
print("###                       ###")
print("###       STEMMING        ###")
print("###                       ###")
print("###                       ###")

STEM_MODE = metrics.stemMode.both

precision = metrics.precision(test_answer, obtained_words,STEM_MODE)
recall = metrics.recall(test_answer, obtained_words,STEM_MODE)
f1 = metrics.f1(precision, recall)

print("###    Obtained Scores    ###")
print("###     (full dataset)    ###")
print("###")
print("### Precision : %.4f" % precision)
print("### Recall    : %.4f" % recall)
print("### F1        : %.4f" % f1)
print("###                       ###")

keras_precision = keras_metrics.keras_precision(test_y, output)
keras_recall = keras_metrics.keras_recall(test_y, output)
keras_f1 = keras_metrics.keras_f1(test_y, output)

print("###    Obtained Scores    ###")
print("###    (fixed dataset)    ###")
print("###")
print("### Precision : %.4f" % keras_precision)
print("### Recall    : %.4f" % keras_recall)
print("### F1        : %.4f" % keras_f1)
print("###                       ###")

clean_words = postprocessing.get_valid_patterns(obtained_words)

precision = metrics.precision(test_answer, clean_words,STEM_MODE)
recall = metrics.recall(test_answer, clean_words,STEM_MODE)
f1 = metrics.f1(precision, recall)

print("###    Obtained Scores    ###")
print("### (full dataset,        ###")
print("###  pos patterns filter) ###")
print("###")
print("### Precision : %.4f" % precision)
print("### Recall    : %.4f" % recall)
print("### F1        : %.4f" % f1)
print("###                       ###")


obtained_words_top = postprocessing.get_top_words(test_doc, output, 1)

precision_top = metrics.precision(test_answer, obtained_words_top,STEM_MODE)
recall_top = metrics.recall(test_answer, obtained_words_top,STEM_MODE)
f1_top = metrics.f1(precision_top, recall_top)

print("###    Obtained Scores    ###")
print("### (full dataset, top 1) ###")
print("###")
print("### Precision : %.4f" % precision_top)
print("### Recall    : %.4f" % recall_top)
print("### F1        : %.4f" % f1_top)
print("###                       ###")


obtained_words_top = postprocessing.get_top_words(test_doc, output, 3)

precision_top = metrics.precision(test_answer, obtained_words_top,STEM_MODE)
recall_top = metrics.recall(test_answer, obtained_words_top,STEM_MODE)
f1_top = metrics.f1(precision_top, recall_top)

print("###    Obtained Scores    ###")
print("### (full dataset, top 3) ###")
print("###")
print("### Precision : %.4f" % precision_top)
print("### Recall    : %.4f" % recall_top)
print("### F1        : %.4f" % f1_top)
print("###                       ###")


obtained_words_top = postprocessing.get_top_words(test_doc, output, 5)

precision_top = metrics.precision(test_answer, obtained_words_top,STEM_MODE)
recall_top = metrics.recall(test_answer, obtained_words_top,STEM_MODE)
f1_top = metrics.f1(precision_top, recall_top)

print("###    Obtained Scores    ###")
print("### (full dataset, top 5) ###")
print("###")
print("### Precision : %.4f" % precision_top)
print("### Recall    : %.4f" % recall_top)
print("### F1        : %.4f" % f1_top)
print("###                       ###")

obtained_words_top = postprocessing.get_top_words(test_doc, output, 10)

precision_top = metrics.precision(test_answer, obtained_words_top,STEM_MODE)
recall_top = metrics.recall(test_answer, obtained_words_top,STEM_MODE)
f1_top = metrics.f1(precision_top, recall_top)

print("###    Obtained Scores    ###")
print("### (full dataset, top 10)###")
print("###")
print("### Precision : %.4f" % precision_top)
print("### Recall    : %.4f" % recall_top)
print("### F1        : %.4f" % f1_top)
print("###                       ###")

obtained_words_top = postprocessing.get_top_words(test_doc, output, 15)

precision_top = metrics.precision(test_answer, obtained_words_top,STEM_MODE)
recall_top = metrics.recall(test_answer, obtained_words_top,STEM_MODE)
f1_top = metrics.f1(precision_top, recall_top)

print("###    Obtained Scores    ###")
print("### (full dataset, top 15)###")
print("###")
print("### Precision : %.4f" % precision_top)
print("### Recall    : %.4f" % recall_top)
print("### F1        : %.4f" % f1_top)
print("###                       ###")

obtained_words_top = postprocessing.get_top_words(test_doc, output, 15)

precision_top = metrics.precision(test_answer, obtained_words_top,STEM_MODE)
recall_top = metrics.recall(test_answer, obtained_words_top,STEM_MODE)
f1_top = metrics.f1(precision_top, recall_top)

print("###    Obtained Scores    ###")
print("### (full dataset, top 20)###")
print("###")
print("### Precision : %.4f" % precision_top)
print("### Recall    : %.4f" % recall_top)
print("### F1        : %.4f" % f1_top)
print("###                       ###")
# Out:
# ###                       ###
# ###                       ###
# ###       STEMMING        ###
# ###                       ###
# ###                       ###
# ###    Obtained Scores    ###
# ###     (full dataset)    ###
# ###
# ### Precision : 0.3206
# ### Recall    : 0.5225
# ### F1        : 0.3974
# ###                       ###
# ###    Obtained Scores    ###
# ###    (fixed dataset)    ###
# ###
# ### Precision : 0.3310
# ### Recall    : 0.6314
# ### F1        : 0.4343
# ###                       ###
# ###    Obtained Scores    ###
# ### (full dataset,        ###
# ###  pos patterns filter) ###
# ###
# ### Precision : 0.3165
# ### Recall    : 0.4987
# ### F1        : 0.3872
# ###                       ###
# ###    Obtained Scores    ###
# ### (full dataset, top 1) ###
# ###
# ### Precision : 0.5620
# ### Recall    : 0.0572
# ### F1        : 0.1038
# ###                       ###
# ###    Obtained Scores    ###
# ### (full dataset, top 3) ###
# ###
# ### Precision : 0.5138
# ### Recall    : 0.1559
# ### F1        : 0.2392
# ###                       ###
# ###    Obtained Scores    ###
# ### (full dataset, top 5) ###
# ###
# ### Precision : 0.4741
# ### Recall    : 0.2371
# ### F1        : 0.3161
# ###                       ###
# ###    Obtained Scores    ###
# ### (full dataset, top 10)###
# ###
# ### Precision : 0.4119
# ### Recall    : 0.3851
# ### F1        : 0.3980
# ###                       ###
# ###    Obtained Scores    ###
# ### (full dataset, top 15)###
# ###
# ### Precision : 0.3662
# ### Recall    : 0.4604
# ### F1        : 0.4079
# ###                       ###
# ###    Obtained Scores    ###
# ### (full dataset, top 20)###
# ###
# ### Precision : 0.3662
# ### Recall    : 0.4604
# ### F1        : 0.4079
# ###                       ###

# %%
test_answer_length1 = {}
test_answer_length2 = {}
test_answer_length3 = {}
test_answer_length4 = {}
test_answer_length5 = {}
for key in test_answer:
    temp = test_answer[key]
    test_answer_length1[key] = []
    test_answer_length2[key] = []
    test_answer_length3[key] = []
    test_answer_length4[key] = []
    test_answer_length5[key] = []
#     print(key)
#     print(test_answer_length1[key])
    for val in temp:
        if len(val) == 1:
            test_answer_length1[key].append(val)
        elif len(val) == 2:
            test_answer_length2[key].append(val)
        elif len(val) == 3:
            test_answer_length3[key].append(val)
        elif len(val) == 4:
            test_answer_length4[key].append(val)
        elif len(val) == 5:
            test_answer_length5[key].append(val)
        else:
            continue

# %%
print(test_answer_length1['25'], '\n')
print(test_answer_length2['25'], '\n')
print(test_answer_length3['25'], '\n')
print(test_answer_length4['25'], '\n')
print(test_answer_length5['25'], '\n')
test_answer['25']
# Out:
# [['identification'], ['ranking'], ['forecasting'], ['robotics']]
#
# [['noniterative', 'update'], ['rule-base', 'structure'], ['informative', 'potential'], ['fuzzy', 'rules'], ['complex', 'processes'], ['fault', 'detection'], ['fault', 'diagnostics'], ['performance', 'analysis'], ['knowledge', 'extraction'], ['behavior', 'modeling']]
#
# [['incremental', 'unsupervised', 'learning'], ['air-conditioning', 'component', 'modeling'], ['adaptive', 'nonlinear', 'control']]
#
# [['evolving', 'fuzzy', 'rule-based', 'models']]
#
# []
# [['identification'],
#  ['ranking'],
#  ['forecasting'],
#  ['robotics'],
#  ['noniterative', 'update'],
#  ['rule-base', 'structure'],
#  ['informative', 'potential'],
#  ['fuzzy', 'rules'],
#  ['complex', 'processes'],
#  ['fault', 'detection'],
#  ['fault', 'diagnostics'],
#  ['performance', 'analysis'],
#  ['knowledge', 'extraction'],
#  ['behavior', 'modeling'],
#  ['incremental', 'unsupervised', 'learning'],
#  ['air-conditioning', 'component', 'modeling'],
#  ['adaptive', 'nonlinear', 'control'],
#  ['evolving', 'fuzzy', 'rule-based', 'models']]

# %%
print(test_answer['255'])
print(obtained_words['255'])
obtained_words['25']
# Out:
# [['web', 'site'], ['usability', 'testing', 'program']]
# [['breaking', 'tests'], ['integral', 'investment'], ['online'], ['site', 'development'], ['usability'], ['usability', 'testing'], ['usability', 'testing', 'in-house']]
# [['air-conditioning'],
#  ['benchmark', 'problem'],
#  ['complex', 'processes'],
#  ['er', 'models'],
#  ['evolving', 'fuzzy', 'rule-based', 'models'],
#  ['fuzzy', 'rules'],
#  ['incremental', 'unsupervised', 'learning'],
#  ['informative'],
#  ['informative', 'rules'],
#  ['modeling'],
#  ['neural', 'networks'],
#  ['noniterative', 'update'],
#  ['rule-base', 'structure'],
#  ['rule-based', 'models'],
#  ['viability']]

# %%
temp_test_answer = test_answer
test_answer = test_answer_length1

print("###                       ###")
print("###                       ###")
print("###       STEMMING        ###")
print("###                       ###")
print("###                       ###")

STEM_MODE = metrics.stemMode.both

precision = metrics.precision(test_answer, obtained_words,STEM_MODE)
recall = metrics.recall(test_answer, obtained_words,STEM_MODE)
f1 = metrics.f1(precision, recall)

print("###    Obtained Scores    ###")
print("###     (full dataset)    ###")
print("###")
print("### Precision : %.4f" % precision)
print("### Recall    : %.4f" % recall)
print("### F1        : %.4f" % f1)
print("###                       ###")

keras_precision = keras_metrics.keras_precision(test_y, output)
keras_recall = keras_metrics.keras_recall(test_y, output)
keras_f1 = keras_metrics.keras_f1(test_y, output)

print("###    Obtained Scores    ###")
print("###    (fixed dataset)    ###")
print("###")
print("### Precision : %.4f" % keras_precision)
print("### Recall    : %.4f" % keras_recall)
print("### F1        : %.4f" % keras_f1)
print("###                       ###")

clean_words = postprocessing.get_valid_patterns(obtained_words)

precision = metrics.precision(test_answer, clean_words,STEM_MODE)
recall = metrics.recall(test_answer, clean_words,STEM_MODE)
f1 = metrics.f1(precision, recall)

print("###    Obtained Scores    ###")
print("### (full dataset,        ###")
print("###  pos patterns filter) ###")
print("###")
print("### Precision : %.4f" % precision)
print("### Recall    : %.4f" % recall)
print("### F1        : %.4f" % f1)
print("###                       ###")


obtained_words_top = postprocessing.get_top_words(test_doc, output, 1)

precision_top = metrics.precision(test_answer, obtained_words_top,STEM_MODE)
recall_top = metrics.recall(test_answer, obtained_words_top,STEM_MODE)
f1_top = metrics.f1(precision_top, recall_top)

print("###    Obtained Scores    ###")
print("### (full dataset, top 1) ###")
print("###")
print("### Precision : %.4f" % precision_top)
print("### Recall    : %.4f" % recall_top)
print("### F1        : %.4f" % f1_top)
print("###                       ###")


obtained_words_top = postprocessing.get_top_words(test_doc, output, 3)

precision_top = metrics.precision(test_answer, obtained_words_top,STEM_MODE)
recall_top = metrics.recall(test_answer, obtained_words_top,STEM_MODE)
f1_top = metrics.f1(precision_top, recall_top)

print("###    Obtained Scores    ###")
print("### (full dataset, top 3) ###")
print("###")
print("### Precision : %.4f" % precision_top)
print("### Recall    : %.4f" % recall_top)
print("### F1        : %.4f" % f1_top)
print("###                       ###")


obtained_words_top = postprocessing.get_top_words(test_doc, output, 5)

precision_top = metrics.precision(test_answer, obtained_words_top,STEM_MODE)
recall_top = metrics.recall(test_answer, obtained_words_top,STEM_MODE)
f1_top = metrics.f1(precision_top, recall_top)

print("###    Obtained Scores    ###")
print("### (full dataset, top 5) ###")
print("###")
print("### Precision : %.4f" % precision_top)
print("### Recall    : %.4f" % recall_top)
print("### F1        : %.4f" % f1_top)
print("###                       ###")

obtained_words_top = postprocessing.get_top_words(test_doc, output, 10)

precision_top = metrics.precision(test_answer, obtained_words_top,STEM_MODE)
recall_top = metrics.recall(test_answer, obtained_words_top,STEM_MODE)
f1_top = metrics.f1(precision_top, recall_top)

print("###    Obtained Scores    ###")
print("### (full dataset, top 10)###")
print("###")
print("### Precision : %.4f" % precision_top)
print("### Recall    : %.4f" % recall_top)
print("### F1        : %.4f" % f1_top)
print("###                       ###")

obtained_words_top = postprocessing.get_top_words(test_doc, output, 15)

precision_top = metrics.precision(test_answer, obtained_words_top,STEM_MODE)
recall_top = metrics.recall(test_answer, obtained_words_top,STEM_MODE)
f1_top = metrics.f1(precision_top, recall_top)

print("###    Obtained Scores    ###")
print("### (full dataset, top 15)###")
print("###")
print("### Precision : %.4f" % precision_top)
print("### Recall    : %.4f" % recall_top)
print("### F1        : %.4f" % f1_top)
print("###                       ###")

obtained_words_top = postprocessing.get_top_words(test_doc, output, 15)

precision_top = metrics.precision(test_answer, obtained_words_top,STEM_MODE)
recall_top = metrics.recall(test_answer, obtained_words_top,STEM_MODE)
f1_top = metrics.f1(precision_top, recall_top)

print("###    Obtained Scores    ###")
print("### (full dataset, top 20)###")
print("###")
print("### Precision : %.4f" % precision_top)
print("### Recall    : %.4f" % recall_top)
print("### F1        : %.4f" % f1_top)
print("###                       ###")

test_answer = temp_test_answer
# Out:
# ###                       ###
# ###                       ###
# ###       STEMMING        ###
# ###                       ###
# ###                       ###
# ###    Obtained Scores    ###
# ###     (full dataset)    ###
# ###
# ### Precision : 0.0429
# ### Recall    : 0.5197
# ### F1        : 0.0793
# ###                       ###
# ###    Obtained Scores    ###
# ###    (fixed dataset)    ###
# ###
# ### Precision : 0.3310
# ### Recall    : 0.6314
# ### F1        : 0.4343
# ###                       ###
# ###    Obtained Scores    ###
# ### (full dataset,        ###
# ###  pos patterns filter) ###
# ###
# ### Precision : 0.0464
# ### Recall    : 0.5424
# ### F1        : 0.0855
# ###                       ###
# ###    Obtained Scores    ###
# ### (full dataset, top 1) ###
# ###
# ### Precision : 0.0440
# ### Recall    : 0.0333
# ### F1        : 0.0379
# ###                       ###
# ###    Obtained Scores    ###
# ### (full dataset, top 3) ###
# ###
# ### Precision : 0.0403
# ### Recall    : 0.0909
# ### F1        : 0.0558
# ###                       ###
# ###    Obtained Scores    ###
# ### (full dataset, top 5) ###
# ###
# ### Precision : 0.0428
# ### Recall    : 0.1591
# ### F1        : 0.0675
# ###                       ###
# ###    Obtained Scores    ###
# ### (full dataset, top 10)###
# ###
# ### Precision : 0.0456
# ### Recall    : 0.3167
# ### F1        : 0.0797
# ###                       ###
# ###    Obtained Scores    ###
# ### (full dataset, top 15)###
# ###
# ### Precision : 0.0459
# ### Recall    : 0.4288
# ### F1        : 0.0830
# ###                       ###
# ###    Obtained Scores    ###
# ### (full dataset, top 20)###
# ###
# ### Precision : 0.0459
# ### Recall    : 0.4288
# ### F1        : 0.0830
# ###                       ###

# %%
temp_test_answer = test_answer
test_answer = test_answer_length2

print("###                       ###")
print("###                       ###")
print("###       STEMMING        ###")
print("###                       ###")
print("###                       ###")

STEM_MODE = metrics.stemMode.both

precision = metrics.precision(test_answer, obtained_words,STEM_MODE)
recall = metrics.recall(test_answer, obtained_words,STEM_MODE)
f1 = metrics.f1(precision, recall)

print("###    Obtained Scores    ###")
print("###     (full dataset)    ###")
print("###")
print("### Precision : %.4f" % precision)
print("### Recall    : %.4f" % recall)
print("### F1        : %.4f" % f1)
print("###                       ###")

keras_precision = keras_metrics.keras_precision(test_y, output)
keras_recall = keras_metrics.keras_recall(test_y, output)
keras_f1 = keras_metrics.keras_f1(test_y, output)

print("###    Obtained Scores    ###")
print("###    (fixed dataset)    ###")
print("###")
print("### Precision : %.4f" % keras_precision)
print("### Recall    : %.4f" % keras_recall)
print("### F1        : %.4f" % keras_f1)
print("###                       ###")

clean_words = postprocessing.get_valid_patterns(obtained_words)

precision = metrics.precision(test_answer, clean_words,STEM_MODE)
recall = metrics.recall(test_answer, clean_words,STEM_MODE)
f1 = metrics.f1(precision, recall)

print("###    Obtained Scores    ###")
print("### (full dataset,        ###")
print("###  pos patterns filter) ###")
print("###")
print("### Precision : %.4f" % precision)
print("### Recall    : %.4f" % recall)
print("### F1        : %.4f" % f1)
print("###                       ###")


obtained_words_top = postprocessing.get_top_words(test_doc, output, 1)

precision_top = metrics.precision(test_answer, obtained_words_top,STEM_MODE)
recall_top = metrics.recall(test_answer, obtained_words_top,STEM_MODE)
f1_top = metrics.f1(precision_top, recall_top)

print("###    Obtained Scores    ###")
print("### (full dataset, top 1) ###")
print("###")
print("### Precision : %.4f" % precision_top)
print("### Recall    : %.4f" % recall_top)
print("### F1        : %.4f" % f1_top)
print("###                       ###")


obtained_words_top = postprocessing.get_top_words(test_doc, output, 3)

precision_top = metrics.precision(test_answer, obtained_words_top,STEM_MODE)
recall_top = metrics.recall(test_answer, obtained_words_top,STEM_MODE)
f1_top = metrics.f1(precision_top, recall_top)

print("###    Obtained Scores    ###")
print("### (full dataset, top 3) ###")
print("###")
print("### Precision : %.4f" % precision_top)
print("### Recall    : %.4f" % recall_top)
print("### F1        : %.4f" % f1_top)
print("###                       ###")


obtained_words_top = postprocessing.get_top_words(test_doc, output, 5)

precision_top = metrics.precision(test_answer, obtained_words_top,STEM_MODE)
recall_top = metrics.recall(test_answer, obtained_words_top,STEM_MODE)
f1_top = metrics.f1(precision_top, recall_top)

print("###    Obtained Scores    ###")
print("### (full dataset, top 5) ###")
print("###")
print("### Precision : %.4f" % precision_top)
print("### Recall    : %.4f" % recall_top)
print("### F1        : %.4f" % f1_top)
print("###                       ###")

obtained_words_top = postprocessing.get_top_words(test_doc, output, 10)

precision_top = metrics.precision(test_answer, obtained_words_top,STEM_MODE)
recall_top = metrics.recall(test_answer, obtained_words_top,STEM_MODE)
f1_top = metrics.f1(precision_top, recall_top)

print("###    Obtained Scores    ###")
print("### (full dataset, top 10)###")
print("###")
print("### Precision : %.4f" % precision_top)
print("### Recall    : %.4f" % recall_top)
print("### F1        : %.4f" % f1_top)
print("###                       ###")

obtained_words_top = postprocessing.get_top_words(test_doc, output, 15)

precision_top = metrics.precision(test_answer, obtained_words_top,STEM_MODE)
recall_top = metrics.recall(test_answer, obtained_words_top,STEM_MODE)
f1_top = metrics.f1(precision_top, recall_top)

print("###    Obtained Scores    ###")
print("### (full dataset, top 15)###")
print("###")
print("### Precision : %.4f" % precision_top)
print("### Recall    : %.4f" % recall_top)
print("### F1        : %.4f" % f1_top)
print("###                       ###")

obtained_words_top = postprocessing.get_top_words(test_doc, output, 15)

precision_top = metrics.precision(test_answer, obtained_words_top,STEM_MODE)
recall_top = metrics.recall(test_answer, obtained_words_top,STEM_MODE)
f1_top = metrics.f1(precision_top, recall_top)

print("###    Obtained Scores    ###")
print("### (full dataset, top 20)###")
print("###")
print("### Precision : %.4f" % precision_top)
print("### Recall    : %.4f" % recall_top)
print("### F1        : %.4f" % f1_top)
print("###                       ###")

test_answer = temp_test_answer
# Out:
# ###                       ###
# ###                       ###
# ###       STEMMING        ###
# ###                       ###
# ###                       ###
# ###    Obtained Scores    ###
# ###     (full dataset)    ###
# ###
# ### Precision : 0.1922
# ### Recall    : 0.5964
# ### F1        : 0.2907
# ###                       ###
# ###    Obtained Scores    ###
# ###    (fixed dataset)    ###
# ###
# ### Precision : 0.3310
# ### Recall    : 0.6314
# ### F1        : 0.4343
# ###                       ###
# ###    Obtained Scores    ###
# ### (full dataset,        ###
# ###  pos patterns filter) ###
# ###
# ### Precision : 0.1942
# ### Recall    : 0.5828
# ### F1        : 0.2913
# ###                       ###
# ###    Obtained Scores    ###
# ### (full dataset, top 1) ###
# ###
# ### Precision : 0.2960
# ### Recall    : 0.0573
# ### F1        : 0.0960
# ###                       ###
# ###    Obtained Scores    ###
# ### (full dataset, top 3) ###
# ###
# ### Precision : 0.3056
# ### Recall    : 0.1765
# ### F1        : 0.2237
# ###                       ###
# ###    Obtained Scores    ###
# ### (full dataset, top 5) ###
# ###
# ### Precision : 0.2901
# ### Recall    : 0.2763
# ### F1        : 0.2830
# ###                       ###
# ###    Obtained Scores    ###
# ### (full dataset, top 10)###
# ###
# ### Precision : 0.2541
# ### Recall    : 0.4524
# ### F1        : 0.3255
# ###                       ###
# ###    Obtained Scores    ###
# ### (full dataset, top 15)###
# ###
# ### Precision : 0.2229
# ### Recall    : 0.5337
# ### F1        : 0.3145
# ###                       ###
# ###    Obtained Scores    ###
# ### (full dataset, top 20)###
# ###
# ### Precision : 0.2229
# ### Recall    : 0.5337
# ### F1        : 0.3145
# ###                       ###

# %%
temp_test_answer = test_answer
test_answer = test_answer_length3

print("###                       ###")
print("###                       ###")
print("###       STEMMING        ###")
print("###                       ###")
print("###                       ###")

STEM_MODE = metrics.stemMode.both

precision = metrics.precision(test_answer, obtained_words,STEM_MODE)
recall = metrics.recall(test_answer, obtained_words,STEM_MODE)
f1 = metrics.f1(precision, recall)

print("###    Obtained Scores    ###")
print("###     (full dataset)    ###")
print("###")
print("### Precision : %.4f" % precision)
print("### Recall    : %.4f" % recall)
print("### F1        : %.4f" % f1)
print("###                       ###")

keras_precision = keras_metrics.keras_precision(test_y, output)
keras_recall = keras_metrics.keras_recall(test_y, output)
keras_f1 = keras_metrics.keras_f1(test_y, output)

print("###    Obtained Scores    ###")
print("###    (fixed dataset)    ###")
print("###")
print("### Precision : %.4f" % keras_precision)
print("### Recall    : %.4f" % keras_recall)
print("### F1        : %.4f" % keras_f1)
print("###                       ###")

clean_words = postprocessing.get_valid_patterns(obtained_words)

precision = metrics.precision(test_answer, clean_words,STEM_MODE)
recall = metrics.recall(test_answer, clean_words,STEM_MODE)
f1 = metrics.f1(precision, recall)

print("###    Obtained Scores    ###")
print("### (full dataset,        ###")
print("###  pos patterns filter) ###")
print("###")
print("### Precision : %.4f" % precision)
print("### Recall    : %.4f" % recall)
print("### F1        : %.4f" % f1)
print("###                       ###")


obtained_words_top = postprocessing.get_top_words(test_doc, output, 1)

precision_top = metrics.precision(test_answer, obtained_words_top,STEM_MODE)
recall_top = metrics.recall(test_answer, obtained_words_top,STEM_MODE)
f1_top = metrics.f1(precision_top, recall_top)

print("###    Obtained Scores    ###")
print("### (full dataset, top 1) ###")
print("###")
print("### Precision : %.4f" % precision_top)
print("### Recall    : %.4f" % recall_top)
print("### F1        : %.4f" % f1_top)
print("###                       ###")


obtained_words_top = postprocessing.get_top_words(test_doc, output, 3)

precision_top = metrics.precision(test_answer, obtained_words_top,STEM_MODE)
recall_top = metrics.recall(test_answer, obtained_words_top,STEM_MODE)
f1_top = metrics.f1(precision_top, recall_top)

print("###    Obtained Scores    ###")
print("### (full dataset, top 3) ###")
print("###")
print("### Precision : %.4f" % precision_top)
print("### Recall    : %.4f" % recall_top)
print("### F1        : %.4f" % f1_top)
print("###                       ###")


obtained_words_top = postprocessing.get_top_words(test_doc, output, 5)

precision_top = metrics.precision(test_answer, obtained_words_top,STEM_MODE)
recall_top = metrics.recall(test_answer, obtained_words_top,STEM_MODE)
f1_top = metrics.f1(precision_top, recall_top)

print("###    Obtained Scores    ###")
print("### (full dataset, top 5) ###")
print("###")
print("### Precision : %.4f" % precision_top)
print("### Recall    : %.4f" % recall_top)
print("### F1        : %.4f" % f1_top)
print("###                       ###")

obtained_words_top = postprocessing.get_top_words(test_doc, output, 10)

precision_top = metrics.precision(test_answer, obtained_words_top,STEM_MODE)
recall_top = metrics.recall(test_answer, obtained_words_top,STEM_MODE)
f1_top = metrics.f1(precision_top, recall_top)

print("###    Obtained Scores    ###")
print("### (full dataset, top 10)###")
print("###")
print("### Precision : %.4f" % precision_top)
print("### Recall    : %.4f" % recall_top)
print("### F1        : %.4f" % f1_top)
print("###                       ###")

obtained_words_top = postprocessing.get_top_words(test_doc, output, 15)

precision_top = metrics.precision(test_answer, obtained_words_top,STEM_MODE)
recall_top = metrics.recall(test_answer, obtained_words_top,STEM_MODE)
f1_top = metrics.f1(precision_top, recall_top)

print("###    Obtained Scores    ###")
print("### (full dataset, top 15)###")
print("###")
print("### Precision : %.4f" % precision_top)
print("### Recall    : %.4f" % recall_top)
print("### F1        : %.4f" % f1_top)
print("###                       ###")

obtained_words_top = postprocessing.get_top_words(test_doc, output, 15)

precision_top = metrics.precision(test_answer, obtained_words_top,STEM_MODE)
recall_top = metrics.recall(test_answer, obtained_words_top,STEM_MODE)
f1_top = metrics.f1(precision_top, recall_top)

print("###    Obtained Scores    ###")
print("### (full dataset, top 20)###")
print("###")
print("### Precision : %.4f" % precision_top)
print("### Recall    : %.4f" % recall_top)
print("### F1        : %.4f" % f1_top)
print("###                       ###")

test_answer = temp_test_answer
# Out:
# ###                       ###
# ###                       ###
# ###       STEMMING        ###
# ###                       ###
# ###                       ###
# ###    Obtained Scores    ###
# ###     (full dataset)    ###
# ###
# ### Precision : 0.0701
# ### Recall    : 0.4590
# ### F1        : 0.1216
# ###                       ###
# ###    Obtained Scores    ###
# ###    (fixed dataset)    ###
# ###
# ### Precision : 0.3310
# ### Recall    : 0.6314
# ### F1        : 0.4343
# ###                       ###
# ###    Obtained Scores    ###
# ### (full dataset,        ###
# ###  pos patterns filter) ###
# ###
# ### Precision : 0.0643
# ### Recall    : 0.4066
# ### F1        : 0.1110
# ###                       ###
# ###    Obtained Scores    ###
# ### (full dataset, top 1) ###
# ###
# ### Precision : 0.1960
# ### Recall    : 0.0803
# ### F1        : 0.1140
# ###                       ###
# ###    Obtained Scores    ###
# ### (full dataset, top 3) ###
# ###
# ### Precision : 0.1457
# ### Recall    : 0.1779
# ### F1        : 0.1602
# ###                       ###
# ###    Obtained Scores    ###
# ### (full dataset, top 5) ###
# ###
# ### Precision : 0.1212
# ### Recall    : 0.2434
# ### F1        : 0.1618
# ###                       ###
# ###    Obtained Scores    ###
# ### (full dataset, top 10)###
# ###
# ### Precision : 0.0940
# ### Recall    : 0.3533
# ### F1        : 0.1485
# ###                       ###
# ###    Obtained Scores    ###
# ### (full dataset, top 15)###
# ###
# ### Precision : 0.0795
# ### Recall    : 0.4016
# ### F1        : 0.1327
# ###                       ###
# ###    Obtained Scores    ###
# ### (full dataset, top 20)###
# ###
# ### Precision : 0.0795
# ### Recall    : 0.4016
# ### F1        : 0.1327
# ###                       ###

# %%
temp_test_answer = test_answer
test_answer = test_answer_length4

print("###                       ###")
print("###                       ###")
print("###       STEMMING        ###")
print("###                       ###")
print("###                       ###")

STEM_MODE = metrics.stemMode.both

precision = metrics.precision(test_answer, obtained_words,STEM_MODE)
recall = metrics.recall(test_answer, obtained_words,STEM_MODE)
f1 = metrics.f1(precision, recall)

print("###    Obtained Scores    ###")
print("###     (full dataset)    ###")
print("###")
print("### Precision : %.4f" % precision)
print("### Recall    : %.4f" % recall)
print("### F1        : %.4f" % f1)
print("###                       ###")

keras_precision = keras_metrics.keras_precision(test_y, output)
keras_recall = keras_metrics.keras_recall(test_y, output)
keras_f1 = keras_metrics.keras_f1(test_y, output)

print("###    Obtained Scores    ###")
print("###    (fixed dataset)    ###")
print("###")
print("### Precision : %.4f" % keras_precision)
print("### Recall    : %.4f" % keras_recall)
print("### F1        : %.4f" % keras_f1)
print("###                       ###")

clean_words = postprocessing.get_valid_patterns(obtained_words)

precision = metrics.precision(test_answer, clean_words,STEM_MODE)
recall = metrics.recall(test_answer, clean_words,STEM_MODE)
f1 = metrics.f1(precision, recall)

print("###    Obtained Scores    ###")
print("### (full dataset,        ###")
print("###  pos patterns filter) ###")
print("###")
print("### Precision : %.4f" % precision)
print("### Recall    : %.4f" % recall)
print("### F1        : %.4f" % f1)
print("###                       ###")


obtained_words_top = postprocessing.get_top_words(test_doc, output, 1)

precision_top = metrics.precision(test_answer, obtained_words_top,STEM_MODE)
recall_top = metrics.recall(test_answer, obtained_words_top,STEM_MODE)
f1_top = metrics.f1(precision_top, recall_top)

print("###    Obtained Scores    ###")
print("### (full dataset, top 1) ###")
print("###")
print("### Precision : %.4f" % precision_top)
print("### Recall    : %.4f" % recall_top)
print("### F1        : %.4f" % f1_top)
print("###                       ###")


obtained_words_top = postprocessing.get_top_words(test_doc, output, 3)

precision_top = metrics.precision(test_answer, obtained_words_top,STEM_MODE)
recall_top = metrics.recall(test_answer, obtained_words_top,STEM_MODE)
f1_top = metrics.f1(precision_top, recall_top)

print("###    Obtained Scores    ###")
print("### (full dataset, top 3) ###")
print("###")
print("### Precision : %.4f" % precision_top)
print("### Recall    : %.4f" % recall_top)
print("### F1        : %.4f" % f1_top)
print("###                       ###")


obtained_words_top = postprocessing.get_top_words(test_doc, output, 5)

precision_top = metrics.precision(test_answer, obtained_words_top,STEM_MODE)
recall_top = metrics.recall(test_answer, obtained_words_top,STEM_MODE)
f1_top = metrics.f1(precision_top, recall_top)

print("###    Obtained Scores    ###")
print("### (full dataset, top 5) ###")
print("###")
print("### Precision : %.4f" % precision_top)
print("### Recall    : %.4f" % recall_top)
print("### F1        : %.4f" % f1_top)
print("###                       ###")

obtained_words_top = postprocessing.get_top_words(test_doc, output, 10)

precision_top = metrics.precision(test_answer, obtained_words_top,STEM_MODE)
recall_top = metrics.recall(test_answer, obtained_words_top,STEM_MODE)
f1_top = metrics.f1(precision_top, recall_top)

print("###    Obtained Scores    ###")
print("### (full dataset, top 10)###")
print("###")
print("### Precision : %.4f" % precision_top)
print("### Recall    : %.4f" % recall_top)
print("### F1        : %.4f" % f1_top)
print("###                       ###")

obtained_words_top = postprocessing.get_top_words(test_doc, output, 15)

precision_top = metrics.precision(test_answer, obtained_words_top,STEM_MODE)
recall_top = metrics.recall(test_answer, obtained_words_top,STEM_MODE)
f1_top = metrics.f1(precision_top, recall_top)

print("###    Obtained Scores    ###")
print("### (full dataset, top 15)###")
print("###")
print("### Precision : %.4f" % precision_top)
print("### Recall    : %.4f" % recall_top)
print("### F1        : %.4f" % f1_top)
print("###                       ###")

obtained_words_top = postprocessing.get_top_words(test_doc, output, 15)

precision_top = metrics.precision(test_answer, obtained_words_top,STEM_MODE)
recall_top = metrics.recall(test_answer, obtained_words_top,STEM_MODE)
f1_top = metrics.f1(precision_top, recall_top)

print("###    Obtained Scores    ###")
print("### (full dataset, top 20)###")
print("###")
print("### Precision : %.4f" % precision_top)
print("### Recall    : %.4f" % recall_top)
print("### F1        : %.4f" % f1_top)
print("###                       ###")

test_answer = temp_test_answer
# Out:
# ###                       ###
# ###                       ###
# ###       STEMMING        ###
# ###                       ###
# ###                       ###
# ###    Obtained Scores    ###
# ###     (full dataset)    ###
# ###
# ### Precision : 0.0124
# ### Recall    : 0.2955
# ### F1        : 0.0238
# ###                       ###
# ###    Obtained Scores    ###
# ###    (fixed dataset)    ###
# ###
# ### Precision : 0.3310
# ### Recall    : 0.6314
# ### F1        : 0.4343
# ###                       ###
# ###    Obtained Scores    ###
# ### (full dataset,        ###
# ###  pos patterns filter) ###
# ###
# ### Precision : 0.0100
# ### Recall    : 0.2299
# ### F1        : 0.0191
# ###                       ###
# ###    Obtained Scores    ###
# ### (full dataset, top 1) ###
# ###
# ### Precision : 0.0220
# ### Recall    : 0.0328
# ### F1        : 0.0263
# ###                       ###
# ###    Obtained Scores    ###
# ### (full dataset, top 3) ###
# ###
# ### Precision : 0.0181
# ### Recall    : 0.0806
# ### F1        : 0.0296
# ###                       ###
# ###    Obtained Scores    ###
# ### (full dataset, top 5) ###
# ###
# ### Precision : 0.0167
# ### Recall    : 0.1224
# ### F1        : 0.0294
# ###                       ###
# ###    Obtained Scores    ###
# ### (full dataset, top 10)###
# ###
# ### Precision : 0.0155
# ### Recall    : 0.2119
# ### F1        : 0.0289
# ###                       ###
# ###    Obtained Scores    ###
# ### (full dataset, top 15)###
# ###
# ### Precision : 0.0143
# ### Recall    : 0.2627
# ### F1        : 0.0271
# ###                       ###
# ###    Obtained Scores    ###
# ### (full dataset, top 20)###
# ###
# ### Precision : 0.0143
# ### Recall    : 0.2627
# ### F1        : 0.0271
# ###                       ###

# %%
temp_test_answer = test_answer
test_answer = test_answer_length5

print("###                       ###")
print("###                       ###")
print("###       STEMMING        ###")
print("###                       ###")
print("###                       ###")

STEM_MODE = metrics.stemMode.both

precision = metrics.precision(test_answer, obtained_words,STEM_MODE)
recall = metrics.recall(test_answer, obtained_words,STEM_MODE)
f1 = metrics.f1(precision, recall)

print("###    Obtained Scores    ###")
print("###     (full dataset)    ###")
print("###")
print("### Precision : %.4f" % precision)
print("### Recall    : %.4f" % recall)
print("### F1        : %.4f" % f1)
print("###                       ###")

keras_precision = keras_metrics.keras_precision(test_y, output)
keras_recall = keras_metrics.keras_recall(test_y, output)
keras_f1 = keras_metrics.keras_f1(test_y, output)

print("###    Obtained Scores    ###")
print("###    (fixed dataset)    ###")
print("###")
print("### Precision : %.4f" % keras_precision)
print("### Recall    : %.4f" % keras_recall)
print("### F1        : %.4f" % keras_f1)
print("###                       ###")

clean_words = postprocessing.get_valid_patterns(obtained_words)

precision = metrics.precision(test_answer, clean_words,STEM_MODE)
recall = metrics.recall(test_answer, clean_words,STEM_MODE)
f1 = metrics.f1(precision, recall)

print("###    Obtained Scores    ###")
print("### (full dataset,        ###")
print("###  pos patterns filter) ###")
print("###")
print("### Precision : %.4f" % precision)
print("### Recall    : %.4f" % recall)
print("### F1        : %.4f" % f1)
print("###                       ###")


obtained_words_top = postprocessing.get_top_words(test_doc, output, 1)

precision_top = metrics.precision(test_answer, obtained_words_top,STEM_MODE)
recall_top = metrics.recall(test_answer, obtained_words_top,STEM_MODE)
f1_top = metrics.f1(precision_top, recall_top)

print("###    Obtained Scores    ###")
print("### (full dataset, top 1) ###")
print("###")
print("### Precision : %.4f" % precision_top)
print("### Recall    : %.4f" % recall_top)
print("### F1        : %.4f" % f1_top)
print("###                       ###")


obtained_words_top = postprocessing.get_top_words(test_doc, output, 3)

precision_top = metrics.precision(test_answer, obtained_words_top,STEM_MODE)
recall_top = metrics.recall(test_answer, obtained_words_top,STEM_MODE)
f1_top = metrics.f1(precision_top, recall_top)

print("###    Obtained Scores    ###")
print("### (full dataset, top 3) ###")
print("###")
print("### Precision : %.4f" % precision_top)
print("### Recall    : %.4f" % recall_top)
print("### F1        : %.4f" % f1_top)
print("###                       ###")


obtained_words_top = postprocessing.get_top_words(test_doc, output, 5)

precision_top = metrics.precision(test_answer, obtained_words_top,STEM_MODE)
recall_top = metrics.recall(test_answer, obtained_words_top,STEM_MODE)
f1_top = metrics.f1(precision_top, recall_top)

print("###    Obtained Scores    ###")
print("### (full dataset, top 5) ###")
print("###")
print("### Precision : %.4f" % precision_top)
print("### Recall    : %.4f" % recall_top)
print("### F1        : %.4f" % f1_top)
print("###                       ###")

obtained_words_top = postprocessing.get_top_words(test_doc, output, 10)

precision_top = metrics.precision(test_answer, obtained_words_top,STEM_MODE)
recall_top = metrics.recall(test_answer, obtained_words_top,STEM_MODE)
f1_top = metrics.f1(precision_top, recall_top)

print("###    Obtained Scores    ###")
print("### (full dataset, top 10)###")
print("###")
print("### Precision : %.4f" % precision_top)
print("### Recall    : %.4f" % recall_top)
print("### F1        : %.4f" % f1_top)
print("###                       ###")

obtained_words_top = postprocessing.get_top_words(test_doc, output, 15)

precision_top = metrics.precision(test_answer, obtained_words_top,STEM_MODE)
recall_top = metrics.recall(test_answer, obtained_words_top,STEM_MODE)
f1_top = metrics.f1(precision_top, recall_top)

print("###    Obtained Scores    ###")
print("### (full dataset, top 15)###")
print("###")
print("### Precision : %.4f" % precision_top)
print("### Recall    : %.4f" % recall_top)
print("### F1        : %.4f" % f1_top)
print("###                       ###")

obtained_words_top = postprocessing.get_top_words(test_doc, output, 15)

precision_top = metrics.precision(test_answer, obtained_words_top,STEM_MODE)
recall_top = metrics.recall(test_answer, obtained_words_top,STEM_MODE)
f1_top = metrics.f1(precision_top, recall_top)

print("###    Obtained Scores    ###")
print("### (full dataset, top 20)###")
print("###")
print("### Precision : %.4f" % precision_top)
print("### Recall    : %.4f" % recall_top)
print("### F1        : %.4f" % f1_top)
print("###                       ###")

test_answer = temp_test_answer
# Out:
# ###                       ###
# ###                       ###
# ###       STEMMING        ###
# ###                       ###
# ###                       ###
# ###    Obtained Scores    ###
# ###     (full dataset)    ###
# ###
# ### Precision : 0.0021
# ### Recall    : 0.2237
# ### F1        : 0.0042
# ###                       ###
# ###    Obtained Scores    ###
# ###    (fixed dataset)    ###
# ###
# ### Precision : 0.3310
# ### Recall    : 0.6314
# ### F1        : 0.4343
# ###                       ###
# ###    Obtained Scores    ###
# ### (full dataset,        ###
# ###  pos patterns filter) ###
# ###
# ### Precision : 0.0014
# ### Recall    : 0.1447
# ### F1        : 0.0028
# ###                       ###
# ###    Obtained Scores    ###
# ### (full dataset, top 1) ###
# ###
# ### Precision : 0.0040
# ### Recall    : 0.0263
# ### F1        : 0.0069
# ###                       ###
# ###    Obtained Scores    ###
# ### (full dataset, top 3) ###
# ###
# ### Precision : 0.0040
# ### Recall    : 0.0789
# ### F1        : 0.0077
# ###                       ###
# ###    Obtained Scores    ###
# ### (full dataset, top 5) ###
# ###
# ### Precision : 0.0029
# ### Recall    : 0.0921
# ### F1        : 0.0055
# ###                       ###
# ###    Obtained Scores    ###
# ### (full dataset, top 10)###
# ###
# ### Precision : 0.0020
# ### Recall    : 0.1184
# ### F1        : 0.0039
# ###                       ###
# ###    Obtained Scores    ###
# ### (full dataset, top 15)###
# ###
# ### Precision : 0.0024
# ### Recall    : 0.1974
# ### F1        : 0.0048
# ###                       ###
# ###    Obtained Scores    ###
# ### (full dataset, top 20)###
# ###
# ### Precision : 0.0024
# ### Recall    : 0.1974
# ### F1        : 0.0048
# ###                       ###

# %%
test_answer
# Out:
# {'25': [['identification'],
#   ['ranking'],
#   ['forecasting'],
#   ['robotics'],
#   ['noniterative', 'update'],
#   ['rule-base', 'structure'],
#   ['informative', 'potential'],
#   ['fuzzy', 'rules'],
#   ['complex', 'processes'],
#   ['fault', 'detection'],
#   ['fault', 'diagnostics'],
#   ['performance', 'analysis'],
#   ['knowledge', 'extraction'],
#   ['behavior', 'modeling'],
#   ['incremental', 'unsupervised', 'learning'],
#   ['air-conditioning', 'component', 'modeling'],
#   ['adaptive', 'nonlinear', 'control'],
#   ['evolving', 'fuzzy', 'rule-based', 'models']],
#  '35': [['genetic', 'algorithms'],
#   ['fault', 'diagnosis'],
#   ['fault', 'components'],
#   ['qualitative', 'equations'],
#   ['engineering', 'systems'],
#   ['mechatronic', 'systems'],
#   ['floating', 'disc'],
#   ['qualitative', 'bond', 'graph'],
#   ['measured', 'abnormal', 'behavior'],
#   ['predicted', 'system', 'behavior']],
#  '2050': [['classroom'],
#   ['classroom', 'version'],
#   ['student', 'contestants'],
#   ['undergraduate', 'business', 'students'],
#   ['who', 'wants', 'to', 'be', 'a', 'millionaire', '(', 'r', ')']],
#  '2128': [['linearization'],
#   ['regularization'],
#   ['determinate', 'systems'],
#   ['terminal', 'functional'],
#   ['variational', 'system'],
#   ['local', 'approximation'],
#   ['relaxation', 'properties'],
#   ['optimal', 'control', 'algorithm'],
#   ['reachability', 'set', 'approximation'],
#   ['sequential', 'refinement', 'method']],
#  '2040': [['inverse', 'problems'],
#   ['mathematical', 'model'],
#   ['ion', 'exchange'],
#   ['unique', 'solvability'],
#   ['compressible', 'ion', 'exchanger'],
#   ['ion', 'exchanger', 'compression'],
#   ['numerical', 'solution', 'methods']],
#  '2138': [['reachability', 'sets'],
#   ['discrete', 'systems'],
#   ['upper', 'estimate'],
#   ['optimal', 'control'],
#   ['multistep', 'control', 'processes'],
#   ['iterative', 'restriction', 'algorithm']],
#  '2191': [['wearable', 'computing'],
#   ['speech', 'input'],
#   ['speech', 'recognition'],
#   ['wearable', 'computer'],
#   ['speech', 'recognizers'],
#   ['background', 'noise'],
#   ['speech', 'interfaces'],
#   ['mobile', 'speech', 'recognition']],
#  '2181': [['questionnaire'],
#   ['smoking'],
#   ['exercise'],
#   ['sleep'],
#   ['snacks'],
#   ['alcohol'],
#   ['triglycerides'],
#   ['lifestyle', 'improvement'],
#   ['medical', 'examination'],
#   ['weight', 'gain'],
#   ['eating', 'habits'],
#   ['salt', 'intake'],
#   ['oral', 'hygiene'],
#   ['total', 'cholesterol'],
#   ['uric', 'acid'],
#   ['health', 'checkup', 'data'],
#   ['animal', 'fat', 'intake'],
#   ['body', 'mass', 'index'],
#   ['resting', 'blood', 'pressure'],
#   ['fasting', 'blood', 'sugar'],
#   ['liver', 'function', 'tests'],
#   ['health', 'guidance', 'support', 'system']],
#  '360': [['threshold'],
#   ['error'],
#   ['semiorder'],
#   ['numerical', 'representation'],
#   ['binary', 'relations'],
#   ['numerical', 'function'],
#   ['interval', 'order'],
#   ['multiplicative', 'error', 'function']],
#  '218': [['iscsi'],
#   ['san', 'costs'],
#   ['ip', 'systems'],
#   ['storage', 'area', 'networks']],
#  '370': [['lawsuits'],
#   ['national', 'governments'],
#   ['internet', 'activity'],
#   ['online', 'activities'],
#   ['legal', 'jurisdiction'],
#   ['internet', 'treaties'],
#   ['public', 'order', 'protection'],
#   ['commercial', 'laws', 'enforcement'],
#   ['consumer', 'interests', 'protection'],
#   ['internet', 'sites', 'blocking']],
#  '208': [['internet'],
#   ['communities'],
#   ['web', 'site'],
#   ['information', 'architects'],
#   ['networked', 'environments'],
#   ['private-public', 'sector', 'cooperation'],
#   ['global', 'information', 'networks'],
#   ['networked', 'electronic', 'environment', 'design']],
#  '302': [['linguistic', 'corpus'],
#   ['large', 'databases'],
#   ['internet', 'search', 'engines'],
#   ['word', 'frequency', 'estimation'],
#   ['participant', 'familiarity', 'ratings'],
#   ['celex', 'english', 'linguistic', 'database']],
#  '312': [['information', 'architecture'],
#   ['target', 'user'],
#   ['target', 'content'],
#   ['museum', 'information'],
#   ['children', "'s", 'web', 'portal']],
#  '2032': [['copyright', 'protection'],
#   ['digital', 'society'],
#   ['local', 'characteristics'],
#   ['imperceptible', 'watermark'],
#   ['robust', 'watermark'],
#   ['image', 'processing'],
#   ['adaptive', 'digital', 'watermarking'],
#   ['fuzzy', 'logic', 'techniques'],
#   ['human', 'visual', 'system', 'model']],
#  '2022': [['lclv'],
#   ['display', 'device'],
#   ['two-step', 'integral', 'imaging'],
#   ['resolution', 'improved', 'viewing'],
#   ['nonstationary', 'micro-optics', 'technique'],
#   ['3-d', 'image', 'reconstruction'],
#   ['pickup', 'lenslet', 'array'],
#   ['two-step', 'integral', 'imaging', 'system'],
#   ['3-d', 'orthoscopic', 'real', 'images'],
#   ['liquid', 'crystal', 'light', 'valve']],
#  '1943': [['i-wap'],
#   ['readability'],
#   ['wireless', 'communication'],
#   ['html', 'pages'],
#   ['mobile', 'phone'],
#   ['communication', 'cost'],
#   ['wireless', 'markup', 'language'],
#   ['hypertext', 'markup', 'language'],
#   ['wireless', 'mobile', 'internet'],
#   ['intelligent', 'wap', 'site', 'management', 'system']],
#  '1953': [['customers'],
#   ['cinema'],
#   ['social', 'percolation'],
#   ['quality', 'expectations'],
#   ['ghost', 'field'],
#   ['stationary', 'state'],
#   ['external', 'field'],
#   ['mass', 'media', 'influence'],
#   ['solomon-weisbuch', 'marketing', 'model'],
#   ['percolative', 'phase', 'transition']],
#  '227': [['observer'],
#   ['relativistic', 'constraints'],
#   ['special', 'relativity'],
#   ['time', 'interval'],
#   ['quantum-state', 'distinguishability'],
#   ['orthogonal', 'quantum', 'states'],
#   ['orthogonal', 'single-photon', 'states'],
#   ['quantum', 'communication', 'channels'],
#   ['nonrelativistic', 'quantum', 'information', 'theory']],
#  '237': [['consortial', 'purchasing', 'models'],
#   ['international', 'library', 'consortia']],
#  '2117': [['failure-tolerance'],
#   ['commutators'],
#   ['p-p', 'rearrangement'],
#   ['generalized', 'hypercubes'],
#   ['p-element', 'permutation'],
#   ['conflict-free', 'implementation'],
#   ['single-element', 'permutations'],
#   ['double', 'p-ary', 'multirings']],
#  '2107': [['psychology'],
#   ['deindividuation'],
#   ['internet'],
#   ['group', 'processes'],
#   ['social', 'issues'],
#   ['personal', 'identifiability'],
#   ['group', 'identity'],
#   ['e-mail', 'discussions'],
#   ['group', 'polarization'],
#   ['group', 'cohesion'],
#   ['social', 'identity', 'theory'],
#   ['asynchronous', 'computer-mediated', 'group', 'interaction'],
#   ['geographically', 'dispersed', 'computer', 'users']],
#  '384': [['reliability'],
#   ['star', 'trackers'],
#   ['on-board', 'database'],
#   ['gyroless', 'spacecraft'],
#   ['boresight', 'axis'],
#   ['brightness-independent', 'start-up', 'routine'],
#   ['initial', 'attitude', 'acquisition'],
#   ['minimum', 'star', 'brightness'],
#   ['star', 'catalog', 'generation', 'preprocessing'],
#   ['charge', 'coupled', 'device', 'photodetector']],
#  '394': [['human', 'intestines'],
#   ['intestinal', 'microflora'],
#   ['molecular', 'methods'],
#   ['observing', 'power'],
#   ['system', 'complexity'],
#   ['microbial', 'ecology'],
#   ['parallel', 'computing'],
#   ['host-microflora', 'interactions'],
#   ['quantitative', 'theory'],
#   ['mimics', 'project'],
#   ['complex', 'microbial', 'ecosystem']],
#  '1998': [['friction', 'compensator'],
#   ['stiction', 'compensation'],
#   ['industrial', 'controllers'],
#   ['stick-slip', 'motion'],
#   ['standard', 'control'],
#   ['pneumatic', 'control', 'valves'],
#   ['static', 'friction', 'compensation'],
#   ['control', 'error', 'reduction']],
#  '1988': [['imark', 'communications'],
#   ['enterprise', 'application', 'integration']],
#  '2175': [['web', 'site'],
#   ['customer', 'service'],
#   ['proactive', 'updating'],
#   ['legal', 'firms'],
#   ['technical', 'skills'],
#   ['business', 'experience'],
#   ['return', 'on', 'investment']],
#  '2165': [['drugs'],
#   ['distress'],
#   ['naomi', 'campbell'],
#   ['online', 'publishers'],
#   ['data', 'protection', 'act']],
#  '245': [['svm'],
#   ['data-training', 'algorithm'],
#   ['error', 'pattern'],
#   ['thermal', 'error', 'classification'],
#   ['critical', 'element', 'temperature'],
#   ['online', 'error', 'assessment'],
#   ['online', 'calibration', 'system'],
#   ['support', 'vector', 'machines', 'model'],
#   ['pc-based', 'open-architecture', 'controller', 'environment'],
#   ['machine', 'tool', 'thermal', 'error', 'prediction']],
#  '255': [['web', 'site'], ['usability', 'testing', 'program']],
#  '410': [['damping', 'effects'],
#   ['ohmic', 'losses'],
#   ['lossy', 'spice', 'models'],
#   ['realistic', 'averaged', 'simulations'],
#   ['state-space', 'averaging', 'technique'],
#   ['switch', 'waveforms', 'analysis'],
#   ['boost', 'voltage-mode', 'application'],
#   ['dc', 'transfer', 'function']],
#  '1931': [['mathematical', 'fundamentals'],
#   ['decision', 'making'],
#   ['pseudofuzzy', 'quantities'],
#   ['modus-ponens', 'rule'],
#   ['fuzzy', 'bayesian', 'inference', 'techniques']],
#  '400': [['reconfigurable', 'bus'],
#   ['polygon-dependent', 'access'],
#   ['line-block', 'mapping'],
#   ['120', 'mw'],
#   ['6', 'mbit'],
#   ['3.2', 'gb/s'],
#   ['0.18', 'micron'],
#   ['three-dimensional', 'rendering', 'engine'],
#   ['mobile', 'pda', 'chip'],
#   ['embedded', 'dram', 'macros'],
#   ['8-pixel-parallel', 'rendering', 'logic'],
#   ['low', 'power', 'consumption'],
#   ['read-modify-write', 'data', 'transaction'],
#   ['3d', 'graphics', 'rendering'],
#   ['low-power', '3d', 'rendering', 'engine'],
#   ['mobile', 'personal', 'digital', 'assistant', 'chip'],
#   ['cmos', 'embedded', 'memory', 'logic', 'technology']],
#  '263': [['k-12', 'instruction'],
#   ['digital', 'access'],
#   ['archival', 'materials'],
#   ['student', 'learning'],
#   ['archival', 'practice'],
#   ['electronic', 'projects'],
#   ['nonelectronic', 'projects'],
#   ['historiographical', 'approaches'],
#   ['pedagogical', 'approaches'],
#   ['archival', 'web'],
#   ['educational', 'sites'],
#   ['primary', 'source', 'materials'],
#   ['direct', 'physical', 'access'],
#   ['library', 'of', 'congress'],
#   ['national', 'archives', 'and', 'records', 'administration']],
#  '273': [['databases'],
#   ['bioavailability'],
#   ['outliers'],
#   ['library', 'design'],
#   ['library', 'analysis'],
#   ['molecular', 'descriptors'],
#   ['molecular', 'topology'],
#   ['chemical', 'properties'],
#   ['diversity', 'analyses'],
#   ['similarity', 'analyses'],
#   ['data', 'sets'],
#   ['descriptor', 'boundaries'],
#   ['drug-like', 'characteristics'],
#   ['biological', 'activity'],
#   ['universal', 'chemical', 'scale'],
#   ['chemical', 'information', 'based', 'scaling']],
#  '2092': [['head'],
#   ['neck'],
#   ['patients'],
#   ['errors'],
#   ['tumor', 'biology'],
#   ['anatomical', 'information'],
#   ['nonrigid', 'motions'],
#   ['bed', 'positions'],
#   ['transmission', 'scan'],
#   ['registration', 'technique'],
#   ['scanner', 'bed'],
#   ['image', 'enhancements'],
#   ['automatic', 'registration', 'method'],
#   ['computerised', 'tomography', 'scans'],
#   ['radiotherapy', 'treatment', 'mask'],
#   ['mutual', 'information-based', 'algorithm'],
#   ['positron', 'emission', 'tomography', 'scans'],
#   ['automatic', 'ridged', 'body', 'transformations'],
#   ['standard', 'image', 'fusion', 'methods'],
#   ['full', 'circle', 'consistency', 'test'],
#   ['user-independent', 'automatic', 'validation', 'technique']],
#  '2082': [['mrp'],
#   ['market', 'demand'],
#   ['strategic', 'stocks'],
#   ['safety', 'stocks'],
#   ['inventory', 'management'],
#   ['variance', 'control'],
#   ['stock', 'replenishment'],
#   ['service', 'level'],
#   ['peak', 'demand'],
#   ['materials', 'requirements', 'planning']],
#  '2153': [['usa'],
#   ['abb', 'robots'],
#   ['mail', 'sorting'],
#   ['packages', 'sorting'],
#   ['mail', 'sorting', 'center'],
#   ['robotic', 'containerization', 'system'],
#   ['united', 'states', 'postal', 'service']],
#  '2143': [['quantum', 'computers'], ['solid-state', 'devices']],
#  '2049': [['optimisation'],
#   ['decision', 'analysis'],
#   ['operations', 'research'],
#   ['management', 'science'],
#   ['probability', 'distribution'],
#   ['expected', 'value', 'of', 'perfect', 'information']],
#  '2131': [['step-by-step', 'diagnosis'],
#   ['operational', 'mode', 'disturbance'],
#   ['heat', 'system', 'technical', 'state', 'diagnosis'],
#   ['closed', 'heat', 'consumption', 'system', 'diagnosis']],
#  '2059': [['science'],
#   ['technology'],
#   ['medicine'],
#   ['out-of-print', 'books'],
#   ['special', 'collections'],
#   ['library', 'acquisitions'],
#   ['rare', 'materials'],
#   ['policy', 'formation'],
#   ['collection', 'development'],
#   ['basic', 'reference', 'tools']],
#  '2121': [['flexibility', 'analysis'],
#   ['partial', 'uncertainty'],
#   ['control', 'system'],
#   ['structural', 'flexibility'],
#   ['optimal', 'design'],
#   ['complex', 'technical', 'systems'],
#   ['fuzzy', 'mathematical', 'models']],
#  '2188': [['inverter'],
#   ['transient', 'stability'],
#   ['dc', 'links'],
#   ['hvdc', 'systems'],
#   ['variable', 'admittance'],
#   ['affine', 'form'],
#   ['local', 'feedback'],
#   ['adjacent', 'generators'],
#   ['nonlinear', 'control', 'strategy'],
#   ['nonlinear', 'modulation', 'strategy'],
#   ['differential', 'geometric', 'theory'],
#   ['rectifier', 'ac', 'bus'],
#   ['active', 'power', 'flows'],
#   ['generator', 'dynamic', 'equations'],
#   ['global', 'linearization', 'method'],
#   ['multi-machine', 'ac', 'power', 'system'],
#   ['hybrid', 'ac/dc', 'power', 'systems'],
#   ['dual-infeed', 'hybrid', 'ac/dc', 'system']],
#  '2198': [['middleware'],
#   ['pervasive', 'computing'],
#   ['context-sensitive', 'applications'],
#   ['reconfigurable', 'context-sensitive', 'middleware'],
#   ['context-sensitive', 'pervasive', 'computing']],
#  '1965': [['econophysics'],
#   ['invariant', 'measures'],
#   ['statistical', 'quantities'],
#   ['brazilian', 'stock'],
#   ['stock', 'market', 'returns'],
#   ['empirical', 'statistical', 'observations'],
#   ['low-dimensional', 'dynamical', 'systems'],
#   ['low-dimensional', 'chaotic', 'trajectory'],
#   ['first', 'poincare', 'return', 'time']],
#  '1975': [['local', 'features'],
#   ['edge', 'detection'],
#   ['texture', 'segmentation'],
#   ['integral-based', 'features'],
#   ['neighborhood', 'operation'],
#   ['image', 'convolution'],
#   ['overlapping', 'windows'],
#   ['matrix', 'formulation'],
#   ['accumulation', 'moments'],
#   ['image', 'analysis'],
#   ['computationally', 'efficient', 'algorithm'],
#   ['local', 'geometric', 'moments', 'computation']],
#  '379': [['pv', 'systems'],
#   ['fuzzy', 'controller'],
#   ['photovoltaic', 'system'],
#   ['tracking', 'algorithm'],
#   ['duty', 'ratio'],
#   ['solar', 'insolation'],
#   ['feedforward', 'loop'],
#   ['error', 'signal'],
#   ['reference', 'voltage'],
#   ['back-propagation', 'algorithm'],
#   ['instantaneous', 'array', 'voltage'],
#   ['solar', 'cell', 'array', 'voltage'],
#   ['off-line', 'trained', 'neural', 'network'],
#   ['feedforward', 'maximum', 'power', 'point', 'tracking'],
#   ['interleaved', 'dual', 'boost', 'converter', 'feed'],
#   ['fuzzy', 'feedforward', 'peak', 'power', 'tracking', 'effectiveness']],
#  '201': [['global', 'alignment'],
#   ['local', 'alignment'],
#   ['resampled', 'image'],
#   ['panoramic', 'image', 'mosaics']],
#  '369': [['trademark', 'dispute'],
#   ['uzi', 'nissan'],
#   ['global', 'internet'],
#   ['trademark', 'law'],
#   ['nissan.com', 'internet', 'domain', 'name'],
#   ['nissan', 'motor', 'company', 'trademark']],
#  '211': [['paperless', 'office'],
#   ['pervasive', 'clients'],
#   ['multiple', 'servers'],
#   ['mobile', 'workers'],
#   ['data', 'warehousing'],
#   ['enterprise', 'resource', 'planning']],
#  '1981': [['pss', 'design'],
#   ['mu', '-synthesis', 'approach'],
#   ['optimal', 'linear', 'control'],
#   ['turbine', 'control', 'system', 'synthesis'],
#   ['synchronous', 'generator', 'control', 'system', 'synthesis']],
#  '1991': [['watermarking'],
#   ['data-hiding', 'capacity'],
#   ['image', 'sources'],
#   ['information-theoretic', 'model'],
#   ['capacity', 'limits'],
#   ['statistical', 'model'],
#   ['distortion', 'constraints'],
#   ['closed-form', 'expressions'],
#   ['sparse-model', 'approximations'],
#   ['geometric', 'attacks'],
#   ['distortion', 'measures'],
#   ['autoregressive', 'statistical', 'models'],
#   ['block-dct', 'statistical', 'models'],
#   ['wavelet', 'statistical', 'models'],
#   ['compressed', 'host-image', 'sources'],
#   ['uncompressed', 'host-image', 'sources']],
#  '2014': [['nonuniformity'],
#   ['pixel'],
#   ['saturation'],
#   ['intensity'],
#   ['adaptive', 'filtering'],
#   ['noise', 'reduction'],
#   ['noise', 'variance'],
#   ['filter', 'kernel'],
#   ['color', 'gradients'],
#   ['edge', 'detection'],
#   ['color', 'image', 'processing'],
#   ['color', 'image', 'analysis'],
#   ['rgb', 'color', 'model'],
#   ['random', 'gaussian', 'noise'],
#   ['nonuniform', 'noise', 'distribution'],
#   ['accurate', 'image', 'analysis'],
#   ['hsi', 'color', 'space'],
#   ['generated', 'edge', 'maps'],
#   ['minimum', 'error', 'rate'],
#   ['adaptive', 'spatial', 'filtering', 'method'],
#   ['hue', 'saturation', 'intensity', 'color', 'space']],
#  '2004': [['mouse'],
#   ['virtual', 'reality'],
#   ['interaction', 'metaphor'],
#   ['deformable', 'surfaces'],
#   ['interactive', 'segmentation'],
#   ['multi-modal', 'system'],
#   ['sensory', 'feedback'],
#   ['tubular', 'structure'],
#   ['deformable', 'surface'],
#   ['haptic', 'interaction'],
#   ['medical', 'image', 'segmentation'],
#   ['3d', 'haptic', 'device'],
#   ['varying', 'diameter', 'cylinder'],
#   ['interactive', '3d', 'volume', 'segmentation']],
#  '193': [['acquisition'],
#   ['out-of-print', 'materials'],
#   ['recurring', 'issues'],
#   ['changing', 'practices'],
#   ['out-of-print', 'books'],
#   ['library', 'materials']],
#  '324': [['netcloak'],
#   ['java'],
#   ['perl'],
#   ['html'],
#   ['internet'],
#   ['psychology'],
#   ['cgi', 'programs'],
#   ['web', 'server'],
#   ['random', 'assignment'],
#   ['client-side', 'applications'],
#   ['c++', 'language'],
#   ['probability', 'estimation'],
#   ['ip', 'addresses'],
#   ['quality', 'control'],
#   ['graduate', 'students'],
#   ['behavioral', 'data'],
#   ['server-side', 'web-based', 'experiments'],
#   ['common', 'gateway', 'interface', 'scripts']],
#  '334': [['last-mile', 'access'],
#   ['copper', 'cables'],
#   ['niche', 'markets'],
#   ['twisted', 'copper', 'pair'],
#   ['network', 'edge', 'devices']],
#  '1938': [['numerical', 'system'],
#   ['linear', 'algebraic', 'equations'],
#   ['m-dimensional', 'lambda', '-matrices']],
#  '346': [['optimization'],
#   ['lp'],
#   ['pennant', 'race'],
#   ['games', 'back'],
#   ['magic', 'number'],
#   ['game', 'schedule'],
#   ['linear', 'programming'],
#   ['world', 'wide', 'web'],
#   ['play-off', 'race', 'statistics'],
#   ['minimum', 'win', 'threshold'],
#   ['baseball', 'play-off', 'spot', 'competition'],
#   ['riot', 'baseball', 'play-off', 'races', 'web', 'site']],
#  '356': [['gaussian', 'noise'],
#   ['quantum', 'teleportation'],
#   ['continuous', 'variables'],
#   ['quantum', 'communication', 'theory'],
#   ['quantum', 'mechanical', 'systems'],
#   ['extended', 'phase-space', 'formalism'],
#   ['operational', 'phase-space', 'probability', 'distribution'],
#   ['quantum', 'information', 'processing', 'systems']],
#  '2066': [['microelectronics'],
#   ['technological', 'change'],
#   ['life-cycle', 'models'],
#   ['industry', 'dynamics'],
#   ['equilibrium', 'model'],
#   ['industry', 'evolution'],
#   ['pc', 'industry'],
#   ['production', 'cost'],
#   ['personal', 'computer', 'market']],
#  '287': [['spice'],
#   ['circuit', 'models'],
#   ['parameter', 'estimation'],
#   ['frequency', 'response'],
#   ['series', 'resistance'],
#   ['small-signal', 'operation'],
#   ['linear', 'regression'],
#   ['lossy', 'inductance'],
#   ['loudspeaker', 'driver'],
#   ['lossless', 'inductor'],
#   ['loudspeaker', 'voice-coil', 'inductance', 'losses'],
#   ['core', 'flux', 'to', 'mmf', 'ratio']],
#  '297': [['internet'],
#   ['systems', 'librarianship'],
#   ['service', 'side'],
#   ['online', 'catalogs'],
#   ['small', 'academic', 'library']],
#  '2142': [['spectral', 'characteristics'],
#   ['singular', 'characteristics'],
#   ['partial', 'spectra'],
#   ['singular', 'functions'],
#   ['frequency', 'characteristic'],
#   ['bounded', 'time', 'interval'],
#   ['linear', 'dynamic', 'systems'],
#   ['standard', 'dynamic', 'blocks'],
#   ['transcendental', 'characteristic', 'equations']],
#  '2152': [['state-of-the-art'],
#   ['business'],
#   ['abb'],
#   ['cad', 'system'],
#   ['virtual', 'engineering', 'office'],
#   ['engineering', 'collaboration', 'platform'],
#   ['global', 'manufacturing', 'companies'],
#   ['globally', 'distributed', 'engineering', 'teams']],
#  '272': [['molecules'],
#   ['median', 'partitioning'],
#   ['molecular', 'descriptors'],
#   ['database', 'compounds'],
#   ['entropy', 'formulation'],
#   ['genetic', 'algorithm'],
#   ['cell-based', 'partitioning'],
#   ['large', 'compound', 'pools'],
#   ['representative', 'subset', 'selection'],
#   ['time', 'limiting', 'step'],
#   ['property', 'descriptor', 'array'],
#   ['available', 'chemicals', 'directory']],
#  '262': [['funding'],
#   ['staffing'],
#   ['ead', 'adoption'],
#   ['archival', 'programs'],
#   ['ead', 'programs'],
#   ['institutional', 'goals'],
#   ['ead', 'implementation'],
#   ['encoded', 'archival', 'description'],
#   ['regular', 'repository', 'functions'],
#   ['archival', 'descriptive', 'standards'],
#   ['diffusion', 'of', 'innovation']],
#  '2083': [['cad/cam'],
#   ['manufacturing'],
#   ['rapid', 'prototyping'],
#   ['concurrent', 'engineering'],
#   ['solid', 'modelling'],
#   ['impulse', 'turbine', 'blades'],
#   ['fused', 'decomposition', 'modelling'],
#   ['university', 'of', 'limerick'],
#   ['finite', 'element', 'analysis'],
#   ['wave', 'energy', 'power', 'conversion']],
#  '2093': [['food', 'processing'],
#   ['wireless', 'terminals'],
#   ['farmland', 'foods'],
#   ['intermec', 'technologies'],
#   ['bar', 'code', 'labels'],
#   ['automatic', 'data', 'capture']],
#  '2199': [['transitions'],
#   ['sitting'],
#   ['standing'],
#   ['walking'],
#   ['measured', 'acceleration'],
#   ['angular', 'velocity'],
#   ['wearable', 'sensors'],
#   ['dead-reckoning', 'method'],
#   ['preselected', 'locations'],
#   ['user', "'s", 'location']],
#  '2189': [['motorola'],
#   ['mobile', 'computing'],
#   ['smart', 'phone'],
#   ['design', 'competitions']],
#  '210': [['rms'],
#   ['copnet'],
#   ['information', 'architecture'],
#   ['simplified', 'navigation'],
#   ['law', 'enforcement', 'agency'],
#   ['legacy', 'text-based', 'system'],
#   ['graphical', 'user', 'interface'],
#   ['law', 'enforcement', 'users']],
#  '368': [['robot'],
#   ['animat'],
#   ['tuning'],
#   ['tests'],
#   ['architecture'],
#   ['links'],
#   ['autonomous', 'system'],
#   ['autonomous', 'behavior'],
#   ['intelligent', 'behavior'],
#   ['robust', 'system'],
#   ['biological', 'model'],
#   ['cortex-like', 'automata'],
#   ['elementary', 'functions'],
#   ['perceptive', 'domain'],
#   ['associative', 'domain'],
#   ['motor', 'domain'],
#   ['learning', 'rules'],
#   ['computational', 'model'],
#   ['variable', 'computation'],
#   ['variable', 'exchange'],
#   ['regularity', 'learning'],
#   ['simple', 'environment'],
#   ['internal', 'drives']],
#  '200': [['competition'],
#   ['neural', 'network'],
#   ['unsupervised', 'learning'],
#   ['neural', 'network', 'architectures'],
#   ['postintegration', 'lateral', 'inhibition'],
#   ['preintegration', 'lateral', 'inhibition']],
#  '378': [['field-oriented', 'control'],
#   ['motor', 'dynamics'],
#   ['incremental', 'motion', 'control'],
#   ['linear', 'synchronous', 'motor'],
#   ['trapezoidal', 'velocity', 'profile'],
#   ['permanent', 'magnet', 'motor'],
#   ['servo', 'drive', 'system'],
#   ['multisegment', 'switching', 'surfaces'],
#   ['multisegment', 'sliding', 'mode', 'control']],
#  '1974': [['codec'],
#   ['spiht', 'algorithm'],
#   ['real-time', 'implementation'],
#   ['wavelet', 'transform'],
#   ['zerotree', 'quantization'],
#   ['wavelet', 'decomposition'],
#   ['absolute', 'zerotree'],
#   ['dsp', 'chip'],
#   ['video', 'coding'],
#   ['memory', 'cost', 'reduction'],
#   ['number', 'of', 'error', 'bits'],
#   ['set', 'partitioning', 'in', 'hierarchical', 'trees']],
#  '1964': [['efficiency'],
#   ['forecasting'],
#   ['us', 'dollar'],
#   ['deutsche', 'mark'],
#   ['exchange', 'rates'],
#   ['high-frequency', 'data'],
#   ['log-price', 'fluctuations'],
#   ['statistical', 'forecast'],
#   ['quote', 'sequence'],
#   ['trading', 'rule'],
#   ['shannon', 'entropy'],
#   ['antipersistent', 'markov', 'behavior'],
#   ['foreign', 'exchange', 'markets']],
#  '2120': [['goal', 'functions'],
#   ['inter-agent', 'transfers'],
#   ['criteria-based', 'control'],
#   ['motivation-based', 'control'],
#   ['linear', 'active', 'systems']],
#  '2058': [['pricing'],
#   ['out-of-print', 'books'],
#   ['economic', 'principles'],
#   ['fair', 'market', 'value']],
#  '2130': [['controllability'],
#   ['synchronizing', 'experiments'],
#   ['real', 'numbers'],
#   ['linear', 'inequalities'],
#   ['linear', 'interval', 'systems'],
#   ['generalized', 'control', 'problems'],
#   ['minimal', 'synchronizing', 'sequence', 'construction']],
#  '2048': [['simlib'],
#   ['object-oriented', 'version'],
#   ['discrete-event', 'simulation'],
#   ['teach', 'simulation']],
#  '408': [['.net', 'obfuscation'],
#   ['intellectual', 'property'],
#   ['reverse', 'engineering']],
#  '1939': [['linear', 'constraints'],
#   ['strict', 'inequations'],
#   ['nonstrict', 'inequations'],
#   ['upper', 'bounds'],
#   ['linear', 'diophantine', 'equations'],
#   ['minimal', 'generating', 'sets'],
#   ['set', 'of', 'natural', 'numbers']],
#  '335': [['patents'],
#   ['internship', 'program'],
#   ['computer-science', 'students'],
#   ['ibm', 'business', 'managers'],
#   ['mba', 'college', 'students']],
#  '325': [['college'],
#   ['university'],
#   ['ethics'],
#   ['internet'],
#   ['open', 'courseware'],
#   ['shared', 'knowledge'],
#   ['higher', 'education'],
#   ['commercial', 'products'],
#   ['open-source', 'software'],
#   ['learning', 'management', 'systems'],
#   ['web', 'courseware', 'management', 'systems']],
#  '1990': [['tokyo'],
#   ['sewage', 'conduits'],
#   ['communications', 'infrastructure'],
#   ['atm', 'switches'],
#   ['information', 'network', 'structuring'],
#   ['information', 'control', 'facilities'],
#   ['treatment', 'site', 's'],
#   ['information', 'transmission', 'network'],
#   ['bureau', 'of', 'sewerage'],
#   ['electrical', 'facility', 'construction', 'work'],
#   ['asynchronous', 'transmission', 'mode', 'switches'],
#   ['sewer', 'optical', 'fiber', 'teleway', 'network', 'plan']],
#  '1980': [['bitstream'],
#   ['ezw-3d'],
#   ['nmzq'],
#   ['diagnostic', 'relevance'],
#   ['volumetric', 'data'],
#   ['rate', 'allocation'],
#   ['integer-to-integer', 'values'],
#   ['disjoint', 'segments'],
#   ['roi-based', 'processing'],
#   ['region', 'boundaries'],
#   ['filter', 'length'],
#   ['decomposition', 'depth'],
#   ['lossy', 'object-based', 'coding'],
#   ['lossless', 'object-based', 'coding'],
#   ['3-d', 'mri', 'data'],
#   ['lifting', 'steps', 'scheme'],
#   ['object-based', 'inverse', 'transform'],
#   ['embedded', 'zerotree', 'coding'],
#   ['3-d', 'discrete', 'wavelet', 'transform'],
#   ['multidimensional', 'layered', 'zero', 'coding'],
#   ['region', 'of', 'interest-based', 'processing'],
#   ['head', 'magnetic', 'resonance', 'images']],
#  '2005': [['surgical', 'education'],
#   ['surgical', 'instruments'],
#   ['graphical', 'overlays'],
#   ['computer', 'monitor'],
#   ['surgeon-defined', 'anatomy'],
#   ['bony', 'structures'],
#   ['image', 'registration'],
#   ['orthopaedic', 'surgical', 'navigation'],
#   ['medical', 'image', 'modalities'],
#   ['surgical', 'action', 'visualization'],
#   ['medical', 'image', 'processing'],
#   ['image-guided', 'surgery', 'systems'],
#   ['computed', 'tomography', 'scans'],
#   ['abstract', 'geometrical', 'model'],
#   ['intra', 'operatively', 'generated', 'images']],
#  '2015': [['invariant'],
#   ['optical', 'recognition'],
#   ['scale', 'invariance'],
#   ['real-time', 'method'],
#   ['3-d', 'information'],
#   ['scale', 'factors'],
#   ['3d', 'object', 'recognition'],
#   ['classical', 'convergent', 'correlator'],
#   ['deformed', 'fringe', 'patterns'],
#   ['scale', 'invariance', 'property'],
#   ['fourier', 'transform', 'profilometry', 'technique'],
#   ['mellin', 'radial', 'harmonic', 'decomposition'],
#   ['logarithmic', 'radial', 'harmonic', 'filter']],
#  '2067': [['intertemporal', 'preferences'],
#   ['health', 'outcomes'],
#   ['private', 'decisions'],
#   ['social', 'decisions'],
#   ['discounted', 'utility', 'model'],
#   ['hyperbolic', 'discounting', 'models']],
#  '296': [['nonlaw', 'librarians'],
#   ['case', 'law'],
#   ['attorney', 'directories'],
#   ['world', 'wide', 'web'],
#   ['legal', 'reference', 'questions']],
#  '286': [['grams'],
#   ['matlab'],
#   ['array-based', 'calculations'],
#   ['modular', 'design'],
#   ['clinical', 'diagnosis'],
#   ['dedicated', 'software'],
#   ['real-time', 'tissue', 'characterization'],
#   ['computationally', 'demanding', 'application'],
#   ['data', 'analysis', 'software'],
#   ['multivariate', 'data', 'analysis'],
#   ['automatic', 'data', 'exchange'],
#   ['linear', 'discriminant', 'analysis'],
#   ['skin', 'spectra', 'classification'],
#   ['clinically', 'relevant', 'parameters', 'extraction']],
#  '357': [['isometric', 'embedding'],
#   ['cartesian', 'product'],
#   ['unit', 'ball'],
#   ['dual', 'space'],
#   ['cauchy', 'problem'],
#   ['level-continuous', 'fuzzy', 'sets'],
#   ['compact-convex', 'fuzzy', 'sets'],
#   ['real', 'continuous', 'functions'],
#   ['ascoli-arzela', 'type', 'theorem'],
#   ['real', 'separable', 'banach', 'space']],
#  '347': [['inc'],
#   ['oas'],
#   ['or/ms'],
#   ['software', 'systems'],
#   ['rm', 'systems'],
#   ['consulting', 'practices'],
#   ['revenue', 'management', 'concepts'],
#   ['pros', 'revenue', 'management'],
#   ['opportunity', 'analysis', 'study'],
#   ['software', 'development', 'practices']],
#  '2180': [['sgml'],
#   ['summary', 'findings'],
#   ['data', 'interchange', 'model'],
#   ['numerical', 'lab', 'data'],
#   ['health', 'status', 'assessment'],
#   ['health', 'checkup', 'data', 'exchange'],
#   ['health-checkup', 'data', 'markup', 'language']],
#  '2190': [['jini'],
#   ['salutation'],
#   ['service', 'discovery'],
#   ['mobile', 'computing'],
#   ['pervasive', 'computing'],
#   ['service', 'location', 'protocol'],
#   ['universal', 'plug', 'and', 'play']],
#  '209': [['information', 'interaction'],
#   ['navigational', 'aid'],
#   ['information-rich', 'systems'],
#   ['information', 'interactivity']],
#  '371': [['ballot', 'box'],
#   ['mark-sense', 'balloting'],
#   ['electronic', 'voting'],
#   ['online', 'voting'],
#   ['automatic', 'teller', 'machine', 'computer-based', 'voting', 'system'],
#   ['atm', 'kiosk', 'style', 'computer-based', 'voting', 'systems']],
#  '219': [['security'],
#   ['pci', 'card'],
#   ['large', 'networks'],
#   ['slotshield', '3000', 'firewall']],
#  '361': [['pseudoclosure'],
#   ['connections'],
#   ['pretopological', 'approach'],
#   ['structural', 'analysis'],
#   ['economic', 'study'],
#   ['geographic', 'proximity'],
#   ['scientific', 'collaborations'],
#   ['minimal', 'closed', 'subsets']],
#  '34': [['pid-type', 'controllers'],
#   ['feedback', 'interconnection'],
#   ['tuning', 'methods'],
#   ['multiobjective', 'genetic', 'algorithms'],
#   ['decentralized', 'pid', 'loops'],
#   ['multiobjective', 'robust', 'control', 'design'],
#   ['multivariable', 'coupled', 'pid', 'loops']],
#  '24': [['tuning'],
#   ['t-norm'],
#   ['fuzzy', 'modeling'],
#   ['function', 'approximation'],
#   ['approximation', 'performances'],
#   ['membership', 'functions'],
#   ['generalized', 'conjunction', 'operations'],
#   ['fuzzy', 'inference', 'systems']],
#  '2139': [['distribution', 'parameters'],
#   ['generalized', 'confidence', 'sets'],
#   ['statistically', 'indeterminate', 'random', 'vector'],
#   ['normally', 'distributed', 'random', 'vector']],
#  '2041': [['multiprocessor', 'systems'],
#   ['gas-dynamic', 'problems'],
#   ['cluster', 'systems'],
#   ['data-transfer', 'interface'],
#   ['low-pressure', 'region'],
#   ['computation', 'of', 'jets'],
#   ['message', 'passing', 'interface']],
#  '2129': [['polynomials'],
#   ['exponential', 'functions'],
#   ['nontrigonometrical', 'polynomials'],
#   ['even', 'functions'],
#   ['integration', 'range', 'decomposition'],
#   ['integration', 'range', 'universal', 'decomposition']],
#  '2051': [['statistics'],
#   ['operations', 'research'],
#   ['game', 'theory'],
#   ['decision', 'analysis'],
#   ['educational', 'course'],
#   ['probabilistic', 'models'],
#   ['stochastic', 'dynamic', 'programming']],
#  '2023': [['mask'],
#   ['convolution'],
#   ['diffraction', 'limit'],
#   ['circular', 'mask'],
#   ['pinhole', 'cameras'],
#   ['high', 'resolution'],
#   ['visible', 'light'],
#   ['x', 'rays'],
#   ['gamma', 'rays'],
#   ['periodic', 'apertures'],
#   ['far-field', 'diffraction'],
#   ['single', 'aperture'],
#   ['multiaperture', 'mask'],
#   ['near-field', 'diffraction'],
#   ['coded', 'imaging', 'systems'],
#   ['optical', 'information', 'processing'],
#   ['broad', 'frequency', 'spectra'],
#   ['far-field', 'diffraction', 'formula'],
#   ['periodic', 'rectangular', 'apertures'],
#   ['circular', 'mask', 'diffraction'],
#   ['arbitrarily', 'shaped', 'apertures'],
#   ['periodic', 'rectangular', 'apertures', 'array'],
#   ['infinite', 'depth', 'of', 'focus']],
#  '2033': [['optical', 'encoding'],
#   ['3d', 'correlation'],
#   ['color', 'images'],
#   ['color', 'distribution'],
#   ['optical', 'correlator'],
#   ['fourier', 'transform'],
#   ['color', 'three-dimensional', 'correlation'],
#   ['3d', 'function', 'encoding'],
#   ['3d', 'fourier', 'transform'],
#   ['color', 'pattern', 'recognition', 'tasks']],
#  '313': [['professional', 'practice'],
#   ['information', 'organization'],
#   ['graphic', 'design'],
#   ['computer', 'science'],
#   ['usability', 'studies'],
#   ['information', 'architects'],
#   ['professional', 'education'],
#   ['pedagogical', 'approaches'],
#   ['information', 'architecture', 'education']],
#  '303': [['spanish'],
#   ['fragmented', 'words'],
#   ['word', 'difficulty'],
#   ['verbal', 'stimuli'],
#   ['screen-fragmented', 'words'],
#   ['turbo', 'pascal'],
#   ['pc', 'microcomputer'],
#   ['psycholinguistic', 'variables'],
#   ['word', 'identification'],
#   ['visual-word', 'identification', 'thresholds'],
#   ['mean', 'identification', 'thresholds'],
#   ['controlled', 'time', 'procedure'],
#   ['unspecific', 'learning', 'effect'],
#   ['snodgrass', 'and', 'vanderwart', 'pictures']],
#  '2106': [['internet'],
#   ['psychology'],
#   ['virtual', 'community'],
#   ['identity', 'deception'],
#   ['online', 'community'],
#   ['psychiatric', 'illness'],
#   ['group', 'processes'],
#   ['social', 'processes'],
#   ['web', 'sites'],
#   ['bulletin', 'boards'],
#   ['information', 'technology', 'professionals']],
#  '2116': [['computational', 'processes'],
#   ['scalable', 'resources'],
#   ['dynamic', 'characteristics'],
#   ['communication', 'medium'],
#   ['software', 'applications'],
#   ['optimal', 'strategies'],
#   ['vector', 'criterion'],
#   ['computational', 'clusters'],
#   ['metacomputational', 'media'],
#   ['dynamic', 'control'],
#   ['static', 'scaling']],
#  '236': [['netherlands'],
#   ['web'],
#   ['licensing', 'strategy'],
#   ['university', 'libraries'],
#   ['university', 'policies'],
#   ['document', 'servers'],
#   ['research', 'publications'],
#   ['elsevier', 'science'],
#   ['kluwer', 'academic'],
#   ['scientific', 'information'],
#   ['business', 'models']],
#  '226': [['e-mail'], ['viruses'], ['vulnerabilities'], ['klez', 'worm']],
#  '1952': [['decoherence'],
#   ['engineering', 'constraints'],
#   ['exchange', 'hamiltonian'],
#   ['solid-state', 'quantum', 'computing'],
#   ['logical', 'qubit', 'encoding'],
#   ['pulse', 'sequence', 'decoupling'],
#   ['decoupling', 'pulse', 'optimization'],
#   ['scalable', 'quantum', 'computing', 'devices']],
#  '1942': [['robustness'],
#   ['precoded', 'ofdm'],
#   ['isi', 'channel'],
#   ['lower', 'layers'],
#   ['critical', 'layers'],
#   ['channel', 'quality'],
#   ['channel', 'estimation'],
#   ['control', 'channel'],
#   ['scalable', 'video', 'transmission'],
#   ['frequency-selective', 'fading', 'channels'],
#   ['channel', 'spectral', 'nulls'],
#   ['isi-free', 'vector', 'channels'],
#   ['frobenius', 'norm', 'metrics'],
#   ['channel', 'allocation', 'information'],
#   ['orthogonal', 'frequency', 'division', 'multiplexing'],
#   ['heavy', 'data', 'rate', 'overhead'],
#   ['adaptive', 'vector', 'channel', 'allocation'],
#   ['layered', 'bit', 'stream', 'structure']],
#  '401': [['snr'],
#   ['high-conversion-rate', 'dac'],
#   ['high-resolution', 'dac'],
#   ['oversampling', 'dac'],
#   ['digital-to-analog', 'converter'],
#   ['cmos', 'technology'],
#   ['differential-quad', 'switching'],
#   ['signal-to-noise', 'ratio'],
#   ['1.5', 'v'],
#   ['0.8', 'micron'],
#   ['direct', 'digital', 'modulation']],
#  '1930': [['axiomatics'],
#   ['systemological', 'analysis'],
#   ['object-oriented', 'design'],
#   ['case', 'tools'],
#   ['complex', 'systems', 'design'],
#   ['formal', 'system', 'representation'],
#   ['functional', 'flow-type', 'objects'],
#   ['formalized', 'nfo/ufo', 'analysis', 'algorithm']],
#  '411': [['electronic', 'components'],
#   ['magnetic', 'components'],
#   ['cad/cae', 'software'],
#   ['prototyping', 'costs'],
#   ['power', 'supply', 'design'],
#   ['dc/dc', 'power', 'convertor', 'design'],
#   ['flyback', 'power', 'convertor', 'topology']],
#  '254': [['networking'],
#   ['reliability'],
#   ['web', 'performance'],
#   ['web', 'sites'],
#   ['web', 'infrastructure']],
#  '244': [['economics'],
#   ['information', 'policy'],
#   ['electronic', 'publishing'],
#   ['electronic', 'scholarly', 'communication'],
#   ['university', 'press/research', 'library', 'relationship']],
#  '1989': [['it', 'projects'],
#   ['risk', 'management', 'framework'],
#   ['commercial', 'security', 'standards']],
#  '1999': [['iae'],
#   ['dtc'],
#   ['performance', 'comparison'],
#   ['pid', 'controllers'],
#   ['performance', 'criterion'],
#   ['pi', 'controllers'],
#   ['dead-time', 'compensator'],
#   ['stable', 'processes'],
#   ['integrating', 'processes'],
#   ['equal', 'robustness'],
#   ['dead-time', 'margin'],
#   ['dead-time', 'compensating', 'controllers'],
#   ['integrated', 'absolute', 'error'],
#   ['step', 'load', 'disturbance'],
#   ['complementary', 'sensitivity', 'function'],
#   ['absolute', 'value', 'sum', 'h/sub', 'infinity', '/', 'norm']],
#  '395': [['coaxial', 'couplers'],
#   ['coaxial', 'waveguides'],
#   ['schwarz-christoffel', 'toolbox'],
#   ['symmetrical', 'couplers'],
#   ['external', 'shields'],
#   ['metallic', 'diaphragms'],
#   ['nonsymmetrical', 'couplers'],
#   ['complex', 'cross', 'section'],
#   ['public-domain', 'matlab', 'package'],
#   ['slotted', 'coaxial', 'cables'],
#   ['circular', 'inner', 'conductors'],
#   ['polygonal', 'inner', 'conductors'],
#   ['numerical', 'conformal', 'transformations'],
#   ['conformal', 'mapping', 'design', 'tools']],
#  '385': [['calspan'],
#   ['mmae'],
#   ['filter', 'spawning'],
#   ['vista', 'f-16'],
#   ['truth', 'model'],
#   ['six-degree-of-freedom', 'simulation'],
#   ['in-flight', 'simulator'],
#   ['test', 'aircraft'],
#   ['general', 'dynamics'],
#   ['linearized', 'models'],
#   ['partial', 'failures'],
#   ['conditional', 'probability'],
#   ['no-failure', 'hypothesis'],
#   ['partial', 'actuator', 'failures'],
#   ['flight', 'control', 'systems'],
#   ['multiple', 'model', 'adaptive', 'estimation']],
#  '2164': [['e-commerce'],
#   ['legal', 'framework'],
#   ['electronic', 'signatures', 'regulations', '2002'],
#   ['european', 'electronic', 'signatures', 'directive']],
#  '2174': [['mailshell'],
#   ['spam', 'e-mails'],
#   ['web-based', 'e-mail'],
#   ['disposable', 'e-mail', 'addresses']],
#  '1966': [['stationarity'],
#   ['econophysics'],
#   ['exchange', 'rates'],
#   ['us', 'dollar'],
#   ['foreign', 'currencies'],
#   ['euro', 'zone'],
#   ['recurrence', 'plots'],
#   ['japanese', 'yen'],
#   ['canadian', 'dollar'],
#   ['british', 'pound'],
#   ['historical', 'events'],
#   ['nonlinear', 'dynamics'],
#   ['nonlinear', 'time', 'series'],
#   ['recurrence', 'quantification', 'analysis'],
#   ['european', 'monetary', 'system'],
#   ['high-frequency', 'currency', 'exchange', 'data']],
#  '1976': [['scale', 'consistency'],
#   ['space', 'consistency'],
#   ['edge', 'preservation'],
#   ['image', 'edges'],
#   ['gradient', 'magnitudes'],
#   ['shrinkage', 'function'],
#   ['geometric', 'constraints'],
#   ['edge', 'enhancement'],
#   ['adaptive', 'image', 'denoising'],
#   ['image', 'multiresolution', 'decomposition'],
#   ['redundant', 'wavelet', 'transform']],
#  '202': [['convolutions'],
#   ['local', 'parametrisations'],
#   ['surface', 'noise'],
#   ['evolution', 'properties'],
#   ['semigeodesic', 'coordinates'],
#   ['underlying', 'triangulation'],
#   ['multi-scale', 'curvature', 'computation'],
#   ['free-form', '3d', 'surface'],
#   ['2d', 'gaussian', 'filters'],
#   ['surface', 'gaussian', 'values'],
#   ['mean', 'curvature', 'values'],
#   ['volumetric', 'diffusion', 'techniques'],
#   ['mpeg-7', 'evaluation', 'framework'],
#   ['curvature', 'scale', 'space', 'method']],
#  '212': [['brain-drain'],
#   ['eskom'],
#   ['power', 'industry'],
#   ['key', 'performers'],
#   ['knowledge', 'management'],
#   ['skills', 'capture'],
#   ['computer-based', 'programme'],
#   ['south', 'africa'],
#   ['personnel', 'management']],
#  '2132': [['architecture'],
#   ['multiversion-threshold', 'adaptation'],
#   ['reliability', 'estimation'],
#   ['hardware', 'failure', 'stability'],
#   ['software', 'failure', 'stability'],
#   ['event', 'graph', 'model'],
#   ['fault-tolerant', 'computer-aided', 'control', 'systems'],
#   ['multiversion',
#    'majority-redundant',
#    'computer-aided',
#    'control',
#    'systems']],
#  '2122': [['stability'],
#   ['control', 'systems'],
#   ['discreteness', 'period'],
#   ['digital', 'modeling'],
#   ['deformable', 'space', 'vehicles'],
#   ['elastic', 'structural', 'vibrations'],
#   ['fuzzy', 'logic', 'adaptation', 'circuit']],
#  '2150': [['abb'],
#   ['installation'],
#   ['commissioning'],
#   ['building', 'management'],
#   ['data', 'centers'],
#   ['building', 'infrastructure'],
#   ['mission-critical', 'facilities'],
#   ['engineering', 'management'],
#   ['project', 'management'],
#   ['security', 'system'],
#   ['redundant', 'power', 'supply'],
#   ['redundant', 'air', 'conditioning']],
#  '2028': [['centroids'],
#   ['position'],
#   ['orientation'],
#   ['scale'],
#   ['optical', 'correlation'],
#   ['centroid', 'detection'],
#   ['correlation-based', 'methods'],
#   ['multiple', 'objects'],
#   ['input', 'scene'],
#   ['noise-smoothing', 'performance'],
#   ['digital-moment-based', 'methods'],
#   ['optical', 'correlator'],
#   ['moment', 'function', 'modulus'],
#   ['moment', 'function', 'squaring'],
#   ['single', 'intensity', 'filter'],
#   ['spatial', 'light', 'modulators']],
#  '2140': [['noncooperative', 'games'],
#   ['strong', 'active', 'solution'],
#   ['static', 'game', 'problems'],
#   ['dynamic', 'game', 'problems']],
#  '2038': [['three-element', 'set'],
#   ['plurality', 'voting'],
#   ['approval', 'voting'],
#   ['borda', 'count'],
#   ['self-consistent', 'choice'],
#   ['2000', 'presidential', 'campaign']],
#  '2091': [['brachytherapy'],
#   ['noise'],
#   ['scatter'],
#   ['object-constrained', 'ct'],
#   ['iterative', 'algorithm'],
#   ['alternating', 'minimization'],
#   ['polyenergetic', 'spectra'],
#   ['clinical', 'possibility'],
#   ['filtered', 'backprojection'],
#   ['foreign', 'metal', 'bodies'],
#   ['statistical', 'image', 'reconstruction'],
#   ['metal', 'artifact', 'reduction'],
#   ['medical', 'diagnostic', 'imaging'],
#   ['ct', 'detector', 'model'],
#   ['deterministic', 'iterative', 'deblurring'],
#   ['quantitative', 'computed', 'tomography', 'imaging'],
#   ['signal', 'acquisition', 'physical', 'process']],
#  '2081': [['optimization'],
#   ['injection', 'moulding'],
#   ['cooling', 'stage'],
#   ['iterative', 'algorithm'],
#   ['heat', 'conduction'],
#   ['objective', 'function'],
#   ['3d', 'numerical', 'simulation'],
#   ['boundary', 'element', 'method'],
#   ['cavity', 'temperature', 'distributions'],
#   ['boundary', 'integral', 'sensitivity', 'analysis']],
#  '260': [['archivists'],
#   ['curators'],
#   ['digitization'],
#   ['virtual', 'collections'],
#   ['digital', 'collections'],
#   ['digital', 'archives'],
#   ['descriptive', 'standards'],
#   ['end', 'users']],
#  '318': [['inflation'],
#   ['fluctuating', 'demand'],
#   ['optimal', 'replenishment', 'schedule'],
#   ['optimal', 'policy', 'algorithm'],
#   ['optimal', 'scheduling', 'parameters'],
#   ['deterministic', 'inventory', 'lot-size', 'models']],
#  '270': [['molecule', 'classification'],
#   ['structural', 'features'],
#   ['topological', 'shapes'],
#   ['cyclic', 'system'],
#   ['functional', 'groups'],
#   ['chemical', 'libraries'],
#   ['molecular', 'equivalence', 'number'],
#   ['nonoverlapping', 'relatable', 'classes'],
#   ['available', 'chemical', 'directory'],
#   ['molecular', 'equivalence', 'indices'],
#   ['mdl', 'drug', 'data', 'report']],
#  '308': [['images'],
#   ['feedback'],
#   ['database', 'connectivity'],
#   ['multiple-choice', 'questions'],
#   ['question', 'editing'],
#   ['question', 'creation'],
#   ['menu', 'selections'],
#   ['button', 'presses'],
#   ['typing', 'content'],
#   ['online', 'homework/quiz/exam', 'applet'],
#   ['teacher', 'authored', 'content'],
#   ['detailed', 'story', 'problems'],
#   ['randomized', 'question', 'sequence'],
#   ['individual', 'pedagogical', 'needs'],
#   ['freely', 'available', 'java', 'software'],
#   ['online', 'student', 'performance', 'evaluation'],
#   ['automatic', 'student', 'score', 'recording']],
#  '284': [['teachers'],
#   ['director'],
#   ['macromedia'],
#   ['project-based', 'learning'],
#   ['cajun', 'culture'],
#   ['inservice', 'teachers'],
#   ['acadian', 'traditions'],
#   ['new', 'technologies'],
#   ['local', 'culture'],
#   ['school', 'teachers'],
#   ['computer', 'multimedia'],
#   ['project-based', 'learning', 'pedagogy'],
#   ['regional', 'state', 'university'],
#   ['local', 'cultural', 'heritage'],
#   ['advanced', 'computer', 'multimedia', 'program'],
#   ['edtc', '658', 'advances', 'in', 'educational', 'technology']],
#  '294': [['shelving'],
#   ['patrons'],
#   ['circulation'],
#   ['stored', 'materials'],
#   ['remote', 'location'],
#   ['courier', 'deliveries'],
#   ['high-density', 'remote', 'storage'],
#   ['climate', 'control', 'system'],
#   ['online', 'catalog', 'record'],
#   ['ohio', 'state', 'university', 'libraries'],
#   ['high-density', 'off-site', 'book', 'storage', 'facility']],
#  '2065': [['inhibition'],
#   ['learning'],
#   ['self-control'],
#   ['emotion'],
#   ['choice', 'model'],
#   ['time-inconsistent', 'preferences'],
#   ['emotional', 'choice', 'systems']],
#  '1959': [['economics'],
#   ['quantum', 'strategies'],
#   ['financial', 'markets'],
#   ['quantum', 'market', 'games'],
#   ['quantum', 'game', 'theory']],
#  '1949': [['radionuclides'],
#   ['tissues'],
#   ['worker'],
#   ['brightness'],
#   ['calibration'],
#   ['th'],
#   ['u'],
#   ['pu'],
#   ['signal'],
#   ['detector'],
#   ['plastic'],
#   ['anatomy'],
#   ['actinides'],
#   ['software'],
#   ['computational', 'phantoms'],
#   ['scanning', 'data'],
#   ['computed', 'tomography'],
#   ['computation', 'phantoms'],
#   ['individual', 'voxels'],
#   ['memory', 'demand'],
#   ['calculational', 'speed'],
#   ['biological', 'tissues'],
#   ['automatic', 'creation'],
#   ['monte', 'carlo', 'calculations'],
#   ['in', 'vivo', 'measurements'],
#   ['precise', 'geometric', 'representation'],
#   ['graphical', 'user', 'interface'],
#   ['mcnp', 'input', 'data', 'file'],
#   ['in', 'vivo', 'measurement', 'systems'],
#   ['magnetic', 'resonance', 'imaging', 'scanning', 'information'],
#   ['low', 'energy', 'gamma', 'ray', 'emitting', 'sources']],
#  '345': [['sis'],
#   ['operations', 'research'],
#   ['management', 'science'],
#   ['strategic', 'or/ms'],
#   ['strategic', 'information', 'systems']],
#  '355': [['anonymous', 'signers'],
#   ['signature', 'verification'],
#   ['identity-based', 'society', 'oriented', 'signature', 'scheme']],
#  '327': [['elaboration'],
#   ['computer-based', 'procedure'],
#   ['verbal', 'protocols'],
#   ['self-explanation-reading', 'training'],
#   ['world', 'knowledge'],
#   ['human', 'judgments'],
#   ['latent', 'semantic', 'analysis'],
#   ['reader', 'strategy', 'assessment'],
#   ['text', 'sentence', 'bridging']],
#  '2017': [['microprocessor'],
#   ['autofocus', 'system'],
#   ['microscope', 'autofocusing'],
#   ['object', 'lens'],
#   ['objective', 'plane'],
#   ['semiconductor', 'laser'],
#   ['defocused', 'signal'],
#   ['differential', 'amplification'],
#   ['dc', 'motor'],
#   ['high', 'reliability'],
#   ['main', 'light', 'axis'],
#   ['symmetrical', 'silicon', 'photocell'],
#   ['reflected', 'light', 'position'],
#   ['power-amplified', 'electric', 'signal'],
#   ['fine', 'working', 'platform'],
#   ['micro', 'measurement', 'systems'],
#   ['eccentric', 'light', 'beam', 'approach']],
#  '2007': [['kidney'],
#   ['nurbs'],
#   ['trauma', 'research'],
#   ['image', 'segmentation'],
#   ['organ', 'reconstruction'],
#   ['software', 'package'],
#   ['polygonal', 'surfaces'],
#   ['viscoelastic', 'model'],
#   ['biomechanical', 'research'],
#   ['medical', 'data', 'set'],
#   ['physically', 'based', 'animation'],
#   ['3d', 'polygonal', 'representation'],
#   ['2d', 'vhf', 'images'],
#   ['hyperelastic', 'material', 'model'],
#   ['biological', 'soft', 'tissues'],
#   ['high-fidelity', 'finite', 'element', 'model'],
#   ['national', 'library', 'of', 'medicine'],
#   ['visible', 'human', 'female', 'project'],
#   ['nonuniform', 'rational', 'b-spline', 'surfaces'],
# ...
#   ['macrocyclic', 'effect'],
#   ['computational', 'models'],
#   ['cyclicity', 'descriptor'],
#   ['open-chain', 'analogues'],
#   ['data', 'mining'],
#   ['structure-property', 'tool'],
#   ['augmented', 'atom'],
#   ['trail', 'program'],
#   ['statistical', 'parameters'],
#   ['thermodynamic', 'parameters'],
#   ['different', 'fragment', 'sets'],
#   ['nonlinear', 'fitting', 'equations'],
#   ['linear', 'fitting', 'equations'],
#   ['molecular', 'graph', 'decomposition'],
#   ['quantitative', 'structure-properties', 'relationship'],
#   ['substructural', 'molecular', 'fragments', 'method']],
#  '266': [['lipophilicity'],
#   ['hydrophilicity'],
#   ['molecular', 'surfaces'],
#   ['pattern', 'generation'],
#   ['model', 'approach'],
#   ['topographical', 'properties'],
#   ['electrostatic', 'potential'],
#   ['local', 'lipophilicity/hydrophilicity'],
#   ['segmented', 'surface'],
#   ['overlapping', 'patches'],
#   ['molecular', 'properties'],
#   ['local', 'features'],
#   ['atomistic', 'resolution'],
#   ['partial', 'similarities'],
#   ['molecular', 'complementarity'],
#   ['patch', 'representation'],
#   ['pattern', 'recognition', 'strategies'],
#   ['fuzzy', 'set', 'theory'],
#   ['hydrogen', 'bond', 'density']],
#  '2146': [['microcomputer'],
#   ['multics'],
#   ['education'],
#   ['web'],
#   ['computer', 'security'],
#   ['network', 'security'],
#   ['trusted', 'systems'],
#   ['trustworthy', 'systems'],
#   ['international', 'standards'],
#   ['is', '15408'],
#   ['is', '17799'],
#   ['it', 'manufacturers'],
#   ['personal', 'computer'],
#   ['business', 'risk', 'management'],
#   ['internet-based', 'information', 'services'],
#   ['information', 'systems', 'management'],
#   ['information', 'systems', 'control'],
#   ['large', 'scale', 'information', 'systems'],
#   ['fourth', 'generation', 'computer', 'professionals']],
#  '2156': [['production'],
#   ['abb'],
#   ['manufacturing', 'expertise'],
#   ['cost', 'efficiency'],
#   ['car', 'production', 'line'],
#   ['compact', 'assembling', 'system'],
#   ['car', 'windshield', 'assembly', 'robots'],
#   ['laminated', 'windshields', 'assembly', 'automation']],
#  '2124': [['geometry'],
#   ['stable', 'polynomials'],
#   ['kharitonov', 'theorem'],
#   ['characteristic', 'polynomial'],
#   ['linear', 'discrete', 'systems'],
#   ['multidimensional', 'stability', 'domain']],
#  '2134': [['linearization'],
#   ['planarization'],
#   ['submicron', 'technologies'],
#   ['vlsi', 'circuits'],
#   ['lineardesignmv', 'algorithm'],
#   ['linear', 'circuit', 'model'],
#   ['linear', 'arithmetic', 'polynomials'],
#   ['circuit', 'representation', 'complexity'],
#   ['linear', 'planar', 'decision', 'diagrams'],
#   ['lgsynth', '93', 'multivalued', 'components']],
#  '29': [['gmdh'],
#   ['learning'],
#   ['hybrid', 'architectures'],
#   ['fuzzy', 'modeling'],
#   ['computational', 'intelligence'],
#   ['fuzzy', 'sets'],
#   ['genetic', 'algorithms'],
#   ['dynamic', 'topology'],
#   ['standard', 'backpropagation'],
#   ['membership', 'functions'],
#   ['learning', 'rates'],
#   ['momentum', 'coefficients'],
#   ['genetic', 'optimization'],
#   ['fuzzy', 'inference', 'method'],
#   ['fuzzy', 'polynomial', 'neural', 'networks'],
#   ['highly', 'nonlinear', 'rule-based', 'models'],
#   ['group', 'method', 'of', 'data', 'handling']],
#  '39': [['hybrid', 'systems'],
#   ['oxichlorination', 'reactor'],
#   ['linguistic', 'model'],
#   ['complex', 'relations'],
#   ['process', 'variables'],
#   ['process', 'events'],
#   ['expert', 'knowledge'],
#   ['process', 'operation'],
#   ['control', 'actions'],
#   ['membership', 'functions'],
#   ['reactor', 'stability'],
#   ['reactive', 'systems'],
#   ['supervisory', 'control', 'design'],
#   ['vinyl', 'monomer', 'plant'],
#   ['raw', 'material', 'consumption'],
#   ['discrete', 'events', 'systems'],
#   ['finite', 'state', 'machines'],
#   ['events', 'detection', '.', 'fuzzy']],
#  '1970': [['e-marketing'],
#   ['revenues'],
#   ['profitability'],
#   ['electronic', 'commerce'],
#   ['internet', 'presence'],
#   ['restaurant', 'web', 'sites'],
#   ['food', 'service', 'companies']],
#  '1960': [['streaming'],
#   ['jamming'],
#   ['cellular', 'automata'],
#   ['iteration', 'time'],
#   ['arching', 'signatures'],
#   ['collective', 'slow-down'],
#   ['self-organised', 'criticality'],
#   ['disruptive', 'interference'],
#   ['power-law', 'behavior'],
#   ['exit', 'dynamics'],
#   ['confined', 'pedestrians'],
#   ['adjacent', 'cell', 'vacancy'],
#   ['burst-size', 'frequency', 'distribution']],
#  '214': [['usa'],
#   ['competition'],
#   ['supercomputing'],
#   ['historical', 'analysis'],
#   ['strategic', 'analysis'],
#   ['computer', 'industry'],
#   ['government', 'research'],
#   ['development', 'spending'],
#   ['technology', 'strategy'],
#   ['new', 'product', 'innovation'],
#   ['parallel', 'computing', 'architectures'],
#   ['high-end', 'computing', 'market', 'evolution'],
#   ['low-end', 'personal', 'computer', 'market']],
#  '204': [['image', 'formation'],
#   ['calibration', 'parameters'],
#   ['image', 'measurements'],
#   ['translational', 'components'],
#   ['rotational', 'components'],
#   ['optical', 'flow'],
#   ['point', 'correspondences'],
#   ['image', 'sequences'],
#   ['depth', 'distortion'],
#   ['camera', 'calibration', 'parameters'],
#   ['image', 'motion', 'fields'],
#   ['rigidly', 'moving', 'camera'],
#   ['linear', 'pinhole-camera', 'model'],
#   ['direct', 'self-calibration', 'method'],
#   ['normal', 'flow', 'measurements'],
#   ['active', 'vision', 'systems'],
#   ['large', 'video', 'databases']],
#  '1956': [['nonstops'],
#   ['attractor'],
#   ['dynamical', 'transition'],
#   ['periodic', 'motions'],
#   ['recurrent', 'bus'],
#   ['circular', 'route'],
#   ['recurrent', 'time'],
#   ['nonlinear', 'map'],
#   ['complex', 'periodic', 'behaviors']],
#  '1946': [['intranet'],
#   ['bms'],
#   ['fms'],
#   ['dcom'],
#   ['web-based', 'access'],
#   ['database', 'integration'],
#   ['internet', 'protocols'],
#   ['building', 'management', 'systems'],
#   ['facilities', 'management', 'systems'],
#   ['embedded', 'web', 'server'],
#   ['pc', 'web', 'server'],
#   ['software', 'development', 'technology'],
#   ['open', 'control', 'network'],
#   ['local', 'network', 'interconnection'],
#   ['distributed', 'component', 'object', 'model']],
#  '232': [['ilumina'],
#   ['internet'],
#   ['metadata'],
#   ['librarians'],
#   ['standards'],
#   ['interoperability'],
#   ['digital', 'library'],
#   ['information', 'resources'],
#   ['community-sharing', 'library'],
#   ['professional', 'roles'],
#   ['academic', 'library'],
#   ['quality', 'assurance'],
#   ['peer', 'review'],
#   ['library', 'automation'],
#   ['reusable', 'software'],
#   ['distributed', 'systems'],
#   ['user', 'issues'],
#   ['teaching', 'resource', 'sharing']],
#  '2102': [['internet'],
#   ['survey'],
#   ['personalization'],
#   ['predictability'],
#   ['e-commerce'],
#   ['web', 'design'],
#   ['source', 'credibility'],
#   ['online', 'advice', 'trust'],
#   ['online', 'mortgage', 'advice'],
#   ['house', 'buying', 'advice']],
#  '2112': [['allan', 'variance'],
#   ['noise', 'filtering'],
#   ['radio', 'engineering'],
#   ['frequency', 'response'],
#   ['statistical', 'analysis'],
#   ['white', 'noise'],
#   ['fractal', 'brownian', 'motion'],
#   ['usa', 'metrology', 'community']],
#  '2018': [['semiconductor', 'manufacturing'],
#   ['robotic', 'system'],
#   ['sampling', 'frequency'],
#   ['packing', 'algorithm'],
#   ['3d', 'mapping', 'system'],
#   ['polycrystalline', 'silicon', 'nuggets'],
#   ['optical', 'nugget', 'placement'],
#   ['irregular', 'shaped', 'objects'],
#   ['commercial', 'manufacturing', 'processes'],
#   ['active', 'laser', 'triangulation'],
#   ['highly', 'irregular', 'shaped', 'objects'],
#   ['fragile', 'fused', 'silica', 'crucible'],
#   ['robust', '3-d', 'imaging', 'system'],
#   ['czochralski', 'semiconductor', 'wafer', 'production'],
#   ['highly', 'irregular', 'polycrystalline', 'silicon', 'nuggets'],
#   ['dual', 'optical', '3d', 'surface', 'mapping', 'system']],
#  '2160': [['challenges'],
#   ['trends'],
#   ['discrete', 'manufacturing'],
#   ['automobile', 'factory'],
#   ['technology', 'revolution'],
#   ['technology', 'evolution'],
#   ['business', 'practices'],
#   ['production', 'practices'],
#   ['industrial', 'relations'],
#   ['seamless', 'manufacturing', 'process']],
#  '2008': [['database'],
#   ['java'],
#   ['visualization'],
#   ['web', 'server'],
#   ['visible', 'human'],
#   ['volume', 'visualization'],
#   ['surface', 'reconstruction'],
#   ['scene', 'construction'],
#   ['3d', 'anatomical', 'scenes'],
#   ['world', 'wide', 'web'],
#   ['3d', 'anatomical', 'models'],
#   ['planar', 'oblique', 'slices'],
#   ['structured', 'anatomical', 'scenes'],
#   ['applet-based', 'rendering', 'engine'],
#   ['high-quality', 'video', 'animation'],
#   ['user-defined', '3d', 'anatomical', 'structures']],
#  '2170': [['e-mail'], ['legal', 'team'], ['litigation', 'support', 'systems']],
#  '391': [['vefs'],
#   ['goodness-of-fit'],
#   ['model', 'selection'],
#   ['noise', 'settings'],
#   ['residual', 'variance'],
#   ['wald', 'test'],
#   ['empirical', 'data'],
#   ['source', 'localization'],
#   ['electromagnetic', 'source', 'analysis'],
#   ['meg', 'source', 'analysis'],
#   ['eeg', 'source', 'analysis'],
#   ['visual', 'evoked', 'fields'],
#   ['adjusted', 'hotelling', "'s", 'test']],
#  '381': [['microcontroller'],
#   ['adaptivity'],
#   ['feasibility'],
#   ['taguchi', 'method'],
#   ['transient', 'response'],
#   ['steady-state', 'error'],
#   ['system', 'robustness'],
#   ['grid-connection', 'mode'],
#   ['stand-alone', 'mode'],
#   ['load', 'variations'],
#   ['tuned', 'scaling', 'factors'],
#   ['output', 'scaling', 'factors'],
#   ['robust', 'fuzzy', 'controlled', 'photovoltaic', 'power', 'inverter']],
#  '328': [['internet'],
#   ['administration'],
#   ['personality', 'research'],
#   ['web-based', 'instruments'],
#   ['data', 'collection'],
#   ['response', 'rates'],
#   ['subject', 'attrition'],
#   ['in-class', 'web', 'survey'],
#   ['in-class', 'paper-and-pencil', 'survey'],
#   ['take-home', 'web', 'survey'],
#   ['take-home', 'paper-and-pencil', 'survey'],
#   ['visions', 'of', 'morality', 'scale']],
#  '250': [['scalability'],
#   ['workgroups'],
#   ['budgets'],
#   ['olap', 'support'],
#   ['microsoft', 'project', '2002'],
#   ['web-based', 'collaboration', 'tools'],
#   ['multiple', 'web', 'project', 'management']],
#  '338': [['walgreen'],
#   ['ford'],
#   ['caterpillar'],
#   ['staples'],
#   ['morgan', 'stanley'],
#   ['strategic', 'technology', 'projects'],
#   ['victoria', "'s", 'secret']],
#  '240': [['mathematics'],
#   ['partnerships'],
#   ['project', 'euclid'],
#   ['scholarly', 'communication'],
#   ['economic', 'model'],
#   ['scholarly', 'publishing'],
#   ['research', 'libraries'],
#   ['cornell', 'university', 'library'],
#   ['duke', 'university', 'press'],
#   ['joint', 'electronic', 'journal', 'publishing', 'initiative']],
#  '1934': [['distributed', 'systems'],
#   ['elliptic', 'equations'],
#   ['conjugate', 'conditions'],
#   ['optimal', 'control', 'problems'],
#   ['quadratic', 'minimized', 'function'],
#   ['computational', 'discretization', 'schemes']],
#  '405': [['spatial', 'relations'],
#   ['spatial', 'relations', 'learning'],
#   ['function-free', 'horn-clause', 'descriptions'],
#   ['inductive', 'logic', 'programming', 'system']],
#  '2045': [['dynamic', 'programming'],
#   ['flip', 'analysis'],
#   ['operations', 'research'],
#   ['craft', 'woodworkers'],
#   ['managerial', 'decision', 'making'],
#   ['solitaire', 'board', 'game']],
#  '2055': [['profession'],
#   ['mba', 'programs'],
#   ['mba', 'students'],
#   ['management', 'science'],
#   ['business', 'school', 'management', 'science', 'course']],
#  '30': [['qualitative', 'modeling'],
#   ['fuzzy', 'modeling'],
#   ['trapezoid', 'approximation'],
#   ['membership', 'functions'],
#   ['rule', 'creation'],
#   ['sugeno-yasukawa', 'method'],
#   ['parameter', 'identification', 'algorithm'],
#   ['rule', 'base', 'reduction']],
#  '20': [['robust', 'stabilization'],
#   ['adaptive', 'stabilization'],
#   ['nonlinear', 'uncertainties'],
#   ['closed-loop', 'systems'],
#   ['state', 'feedback'],
#   ['adaptive', 'controller'],
#   ['robust', 'control'],
#   ['uncertain', 'systems'],
#   ['linear', 'time-varying', 'systems'],
#   ['uncertain', 'dynamical', 'systems']],
#  '1969': [['road', 'users'],
#   ['car-following', 'theory'],
#   ['dynamic', 'evolution'],
#   ['variance', 'equation'],
#   ['motion', 'equation'],
#   ['poisson', 'equation'],
#   ['multilane', 'traffic', 'model'],
#   ['vehicular', 'boltzmann', 'equation'],
#   ['traffic', 'dispersion', 'model'],
#   ['nonlinear', 'poisson', 'equation'],
#   ['self-consistent', 'multiclass', 'dynamic', 'traffic', 'flow', 'modeling']],
#  '1979': [['spatial', 'techniques'],
#   ['scale-space', 'techniques'],
#   ['edge', 'detection'],
#   ['geometrical', 'characteristics'],
#   ['probability', 'factor'],
#   ['pixel', 'similarity'],
#   ['gradient', 'amplitudes'],
#   ['gradient', 'phases'],
#   ['edge', 'connectivity'],
#   ['wavelet', 'correlation'],
#   ['probabilistic', 'formulation'],
#   ['adaptive', 'filters'],
#   ['approximation', 'images'],
#   ['matched', 'filters'],
#   ['image', 'noise'],
#   ['noise', 'suppression'],
#   ['a', 'priori', 'knowledge'],
#   ['double', 'thresholding', 'technique'],
#   ['spatial', 'domain', 'filtering'],
#   ['dynamic', 'range', 'compression'],
#   ['final', 'edge', 'probability', 'image'],
#   ['spatially', 'adaptive', 'wavelet', 'noise-filtering', 'algorithm'],
#   ['spatially',
#    'adaptive',
#    'wavelet-based',
#    'noise',
#    'filtering',
#    'algorithm']],
#  '375': [['uncorrelated', 'sources'],
#   ['preprocessing', 'stage'],
#   ['signal-to-noise', 'ratio'],
#   ['snr', 'maximization'],
#   ['maximum', 'snr'],
#   ['parallel', 'implementation'],
#   ['electromagnetic', 'vector', 'sensor'],
#   ['parallel', 'spatial', 'processors'],
#   ['adaptive', 'second', 'stage'],
#   ['signal', 'source', 'location'],
#   ['adaptive', 'source', 'enhancement'],
#   ['multiple', 'broadband', 'sources', 'separation'],
#   ['multiple', 'broadband', 'sources', 'tracking'],
#   ['single', 'em', 'vector', 'sensor']],
#  '365': [['neurons'],
#   ['u-matrices'],
#   ['visualization'],
#   ['supervised', 'learning'],
#   ['kohonen', 'networks'],
#   ['hydrodynamic', 'models'],
#   ['statistical', 'model'],
#   ['persistence', 'model'],
#   ['verbal', 'forecasts'],
#   ['oceanographic', 'situation'],
#   ['meteorological', 'situation'],
#   ['learning', 'vectors'],
#   ['self-organizing', 'feature', 'maps'],
#   ['sea', 'level', 'prediction'],
#   ['nearest', 'neighbor', 'model'],
#   ['sea', 'level', 'forecast', 'service'],
#   ['federal', 'maritime', 'and', 'hydrography', 'agency']],
#  '2184': [['information', 'systems', 'evolution'],
#   ['information', 'system', 'architectures']],
#  '2194': [['news'],
#   ['weather'],
#   ['wireless', 'networks'],
#   ['pervasive', 'computing'],
#   ['mobile', 'computing'],
#   ['traffic', 'reports'],
#   ['data', 'management'],
#   ['directory', 'services'],
#   ['location-dependent', 'information', 'services']],
#  '317': [['digital', 'democracy'],
#   ['majority', 'opinion'],
#   ['search', 'results'],
#   ['digital', 'ochlocracy'],
#   ['linear', 'programming'],
#   ['internet', 'search', 'systems'],
#   ['citation', 'index', 'usage'],
#   ['internet', 'query', 'statistics'],
#   ['ghosts', 'consensus', 'method'],
#   ['world', 'wide', 'web']],
#  '307': [['computer', 'program'],
#   ['nonhuman', 'subjects'],
#   ['animal', 'subjects'],
#   ['human', 'subjects'],
#   ['operant', 'schedule', 'generation'],
#   ['reinforcement', 'schedule', 'programming'],
#   ['fixed', 'ratio', 'schedules'],
#   ['variable', 'ratio', 'schedules'],
#   ['fixed', 'interval', 'schedules'],
#   ['variable', 'interval', 'schedules'],
#   ['cumulative', 'student', 'response', 'recording']],
#  '2027': [['algorithm'],
#   ['motion', 'estimation'],
#   ['precise', 'estimates'],
#   ['moving', 'objects'],
#   ['image', 'sequence'],
#   ['vector-field', 'computation'],
#   ['heuristic', 'modification'],
#   ['dynamic', 'programming'],
#   ['modified', 'dynamic', 'programming'],
#   ['motion', 'vector', 'field'],
#   ['matching', 'optimization', 'problem'],
#   ['multiple', 'dynamic', 'images'],
#   ['2-d', 'optimization', 'problem'],
#   ['real', 'movie', 'images'],
#   ['dynamic', 'motion', 'analysis'],
#   ['motion', 'vector', 'field', 'estimates']],
#  '2037': [['pseudoinversion'],
#   ['blue'],
#   ['robust', 'estimation'],
#   ['pseudoinverse', 'method'],
#   ['bayesian', 'method'],
#   ['bayesian', 'approach'],
#   ['linear', 'regression', 'parameters'],
#   ['linear', 'regression', 'problems', 'regularization']]}
