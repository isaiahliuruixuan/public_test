# %%
import numpy as np
import random as rn

# The below is necessary in Python 3.2.3 onwards to
# have reproducible behavior for certain hash-based operations.
# See these references for further details:
# https://docs.python.org/3.4/using/cmdline.html#envvar-PYTHONHASHSEED
# https://github.com/fchollet/keras/issues/2280#issuecomment-306959926

import os
os.environ['PYTHONHASHSEED'] = '01'

# The below is necessary for starting Numpy generated random numbers
# in a well-defined initial state.

np.random.seed(421)

# The below is necessary for starting core Python generated random numbers
# in a well-defined state.

rn.seed(123451)


import logging

import numpy as np
from keras import layers
from keras.models import Model, load_model

from data.datasets import *
from eval import keras_metrics, metrics
from nlp import tokenizer as tk
from utils import info, preprocessing, postprocessing, plots

# %%
# LOGGING CONFIGURATION

logging.basicConfig(
    format='%(asctime)s\t%(levelname)s\t%(message)s',
    level=logging.DEBUG)

info.log_versions()

# END LOGGING CONFIGURATION

# GLOBAL VARIABLES

SAVE_MODEL = False
MODEL_PATH = "models/mergernn.h5"
SHOW_PLOTS = False

# END GLOBAL VARIABLES

# Dataset and hyperparameters for each dataset

DATASET = Hulth

if DATASET == Semeval2017:
    tokenizer = tk.tokenizers.nltk
    DATASET_FOLDER = "data/Semeval2017"
    MAX_DOCUMENT_LENGTH = 400
    MAX_VOCABULARY_SIZE = 20000
    EMBEDDINGS_SIZE = 300
    BATCH_SIZE = 32
    EPOCHS = 10
elif DATASET == Hulth:
    tokenizer = tk.tokenizers.nltk
    DATASET_FOLDER = "data/Hulth2003"
    MAX_DOCUMENT_LENGTH = 800
    MAX_VOCABULARY_SIZE = 20000
    EMBEDDINGS_SIZE = 300
    BATCH_SIZE = 32
    EPOCHS = 41
else:
    raise NotImplementedError("Can't set the hyperparameters: unknown dataset")


# END PARAMETERS

logging.info("Loading dataset...")

data = DATASET(DATASET_FOLDER)

train_doc_str, train_answer_str = data.load_train()
test_doc_str, test_answer_str = data.load_test()
val_doc_str, val_answer_str = data.load_validation()

train_doc, train_answer = tk.tokenize_set(train_doc_str,train_answer_str,tokenizer)
test_doc, test_answer = tk.tokenize_set(test_doc_str,test_answer_str,tokenizer)
val_doc, val_answer = tk.tokenize_set(val_doc_str,val_answer_str,tokenizer)

# Sanity check
# logging.info("Sanity check: %s",metrics.precision(test_answer,test_answer))

logging.info("Dataset loaded. Preprocessing data...")
# Out:
# 2021-12-12 04:17:48,940	INFO	Keras version 2.7.0
# 2021-12-12 04:17:48,942	INFO	Numpy version 1.20.1
# 2021-12-12 04:17:48,943	INFO	Tensorflow version 2.7.0
# 2021-12-12 04:17:48,945	INFO	Loading dataset...
# 2021-12-12 04:17:48,945	DEBUG	Initialized dataset Hulth, 2003 from folder data/Hulth2003
# 2021-12-12 04:17:49,760	DEBUG	Loaded training set for dataset Hulth, 2003
# 2021-12-12 04:17:50,141	DEBUG	Loaded test set for dataset Hulth, 2003
# 2021-12-12 04:17:50,529	DEBUG	Loaded validation set for dataset Hulth, 2003
# 2021-12-12 04:17:53,126	INFO	Dataset loaded. Preprocessing data...

# %%
train_x,train_y,test_x,test_y,val_x,val_y,embedding_matrix = preprocessing.\
    prepare_sequential(train_doc, train_answer, test_doc, test_answer,val_doc,val_answer,
                       max_document_length=MAX_DOCUMENT_LENGTH,
                       max_vocabulary_size=MAX_VOCABULARY_SIZE,
                       embeddings_size=EMBEDDINGS_SIZE)

# weigh training examples: everything that's not class 0 (not kp)
# gets a heavier score
#train_y_weights = np.argmax(train_y,axis=2) # this removes the one-hot representation
#train_y_weights[train_y_weights > 0] = 20
#train_y_weights[train_y_weights < 1] = 1

from sklearn.utils import class_weight
train_y_weights = np.argmax(train_y, axis=2)
train_y_weights = np.reshape(class_weight.compute_sample_weight('balanced', train_y_weights.flatten()),
                             np.shape(train_y_weights))


logging.info("Data preprocessing complete.")
logging.info("Maximum possible recall: %s",
             metrics.recall(test_answer,
                               postprocessing.get_words(test_doc,postprocessing.undo_sequential(test_y))))
# Out:
# 2021-12-12 04:17:53,339	DEBUG	Fitting dictionary on 2000 documents...
# 2021-12-12 04:17:53,422	DEBUG	Dictionary fitting completed. Found 18312 unique tokens
# 2021-12-12 04:17:53,499	DEBUG	Longest training document : 556 tokens
# 2021-12-12 04:17:53,500	DEBUG	Longest test document :     380 tokens
# 2021-12-12 04:17:53,500	DEBUG	Longest validation document : 314 tokens
# 2021-12-12 04:17:53,743	DEBUG	Training set samples size   : (1000, 800)
# 2021-12-12 04:17:53,744	DEBUG	Training set answers size   : (1000, 800, 3)
# 2021-12-12 04:17:53,744	DEBUG	Test set samples size       : (500, 800)
# 2021-12-12 04:17:53,745	DEBUG	Test set answers size       : (500, 800, 3)
# 2021-12-12 04:17:53,745	DEBUG	Validation set samples size : (500, 800)
# 2021-12-12 04:17:53,745	DEBUG	Validation set answers size : (500, 800, 3)
# 2021-12-12 04:17:53,746	DEBUG	Loading GloVe pre-trained embeddings from glove.6B.300d.txt
# 2021-12-12 04:18:12,799	DEBUG	Total embeddings found: 400000.
# 2021-12-12 04:18:12,800	DEBUG	Building embedding matrix of size [18313,300]...
# 2021-12-12 04:18:13,136	INFO	Data preprocessing complete.
# 2021-12-12 04:18:13,270	INFO	Maximum possible recall: 0.7691837980867088

# %%
MODEL_PATH = './model/new_kp20k_mergebigru_1_8_epoch_10'

logging.info("Loading existing model from %s...",MODEL_PATH)
model = load_model(MODEL_PATH)
logging.info("Completed loading model from file")


logging.info("Predicting on test set...")
output = model.predict(x=[test_x,test_x], verbose=1)
logging.debug("Shape of output array: %s",np.shape(output))

obtained_tokens = postprocessing.undo_sequential(output)
obtained_words = postprocessing.get_words(test_doc,obtained_tokens)

precision = metrics.precision(test_answer,obtained_words)
recall = metrics.recall(test_answer,obtained_words)
f1 = metrics.f1(precision,recall)

print("###    Obtained Scores    ###")
print("###     (full dataset)    ###")
print("###")
print("### Precision : %.4f" % precision)
print("### Recall    : %.4f" % recall)
print("### F1        : %.4f" % f1)
print("###                       ###")

keras_precision = keras_metrics.keras_precision(test_y,output)
keras_recall = keras_metrics.keras_recall(test_y,output)
keras_f1 = keras_metrics.keras_f1(test_y,output)

print("###    Obtained Scores    ###")
print("###    (fixed dataset)    ###")
print("###")
print("### Precision : %.4f" % keras_precision)
print("### Recall    : %.4f" % keras_recall)
print("### F1        : %.4f" % keras_f1)
print("###                       ###")

clean_words = postprocessing.get_valid_patterns(obtained_words)

precision = metrics.precision(test_answer,clean_words)
recall = metrics.recall(test_answer,clean_words)
f1 = metrics.f1(precision,recall)

print("###    Obtained Scores    ###")
print("### (full dataset,        ###")
print("###  pos patterns filter) ###")
print("###")
print("### Precision : %.4f" % precision)
print("### Recall    : %.4f" % recall)
print("### F1        : %.4f" % f1)
print("###                       ###")


obtained_words_top = postprocessing.get_top_words(test_doc, output, 5)

precision_top = metrics.precision(test_answer, obtained_words_top)
recall_top = metrics.recall(test_answer, obtained_words_top)
f1_top = metrics.f1(precision_top, recall_top)

print("###    Obtained Scores    ###")
print("### (full dataset, top 5) ###")
print("###")
print("### Precision : %.4f" % precision_top)
print("### Recall    : %.4f" % recall_top)
print("### F1        : %.4f" % f1_top)
print("###                       ###")

obtained_words_top = postprocessing.get_top_words(test_doc, output, 10)

precision_top = metrics.precision(test_answer, obtained_words_top)
recall_top = metrics.recall(test_answer, obtained_words_top)
f1_top = metrics.f1(precision_top, recall_top)

print("###    Obtained Scores    ###")
print("### (full dataset, top 10)###")
print("###")
print("### Precision : %.4f" % precision_top)
print("### Recall    : %.4f" % recall_top)
print("### F1        : %.4f" % f1_top)
print("###                       ###")

obtained_words_top = postprocessing.get_top_words(test_doc, output, 15)

precision_top = metrics.precision(test_answer, obtained_words_top)
recall_top = metrics.recall(test_answer, obtained_words_top)
f1_top = metrics.f1(precision_top, recall_top)

print("###    Obtained Scores    ###")
print("### (full dataset, top 15)###")
print("###")
print("### Precision : %.4f" % precision_top)
print("### Recall    : %.4f" % recall_top)
print("### F1        : %.4f" % f1_top)
print("###                       ###")


print("###                       ###")
print("###                       ###")
print("###       STEMMING        ###")
print("###                       ###")
print("###                       ###")

STEM_MODE = metrics.stemMode.both

precision = metrics.precision(test_answer, obtained_words,STEM_MODE)
recall = metrics.recall(test_answer, obtained_words,STEM_MODE)
f1 = metrics.f1(precision, recall)

print("###    Obtained Scores    ###")
print("###     (full dataset)    ###")
print("###")
print("### Precision : %.4f" % precision)
print("### Recall    : %.4f" % recall)
print("### F1        : %.4f" % f1)
print("###                       ###")

keras_precision = keras_metrics.keras_precision(test_y, output)
keras_recall = keras_metrics.keras_recall(test_y, output)
keras_f1 = keras_metrics.keras_f1(test_y, output)

print("###    Obtained Scores    ###")
print("###    (fixed dataset)    ###")
print("###")
print("### Precision : %.4f" % keras_precision)
print("### Recall    : %.4f" % keras_recall)
print("### F1        : %.4f" % keras_f1)
print("###                       ###")

clean_words = postprocessing.get_valid_patterns(obtained_words)

precision = metrics.precision(test_answer, clean_words,STEM_MODE)
recall = metrics.recall(test_answer, clean_words,STEM_MODE)
f1 = metrics.f1(precision, recall)

print("###    Obtained Scores    ###")
print("### (full dataset,        ###")
print("###  pos patterns filter) ###")
print("###")
print("### Precision : %.4f" % precision)
print("### Recall    : %.4f" % recall)
print("### F1        : %.4f" % f1)
print("###                       ###")



obtained_words_top = postprocessing.get_top_words(test_doc, output, 5)

precision_top = metrics.precision(test_answer, obtained_words_top,STEM_MODE)
recall_top = metrics.recall(test_answer, obtained_words_top,STEM_MODE)
f1_top = metrics.f1(precision_top, recall_top)

print("###    Obtained Scores    ###")
print("### (full dataset, top 5) ###")
print("###")
print("### Precision : %.4f" % precision_top)
print("### Recall    : %.4f" % recall_top)
print("### F1        : %.4f" % f1_top)
print("###                       ###")

obtained_words_top = postprocessing.get_top_words(test_doc, output, 10)

precision_top = metrics.precision(test_answer, obtained_words_top,STEM_MODE)
recall_top = metrics.recall(test_answer, obtained_words_top,STEM_MODE)
f1_top = metrics.f1(precision_top, recall_top)

print("###    Obtained Scores    ###")
print("### (full dataset, top 10)###")
print("###")
print("### Precision : %.4f" % precision_top)
print("### Recall    : %.4f" % recall_top)
print("### F1        : %.4f" % f1_top)
print("###                       ###")

obtained_words_top = postprocessing.get_top_words(test_doc, output, 15)

precision_top = metrics.precision(test_answer, obtained_words_top,STEM_MODE)
recall_top = metrics.recall(test_answer, obtained_words_top,STEM_MODE)
f1_top = metrics.f1(precision_top, recall_top)

print("###    Obtained Scores    ###")
print("### (full dataset, top 15)###")
print("###")
print("### Precision : %.4f" % precision_top)
print("### Recall    : %.4f" % recall_top)
print("### F1        : %.4f" % f1_top)
print("###                       ###")
# Out:
# 2021-12-12 04:18:13,289	INFO	Loading existing model from ./model/new_kp20k_mergebigru_1_8_epoch_10...
# 2021-12-12 04:18:25,190	INFO	Completed loading model from file
# 2021-12-12 04:18:25,190	INFO	Predicting on test set...
# 16/16 [==============================] - 14s 735ms/step
# 2021-12-12 04:18:38,938	DEBUG	Shape of output array: (500, 800, 3)
# ###    Obtained Scores    ###
# ###     (full dataset)    ###
# ###
# ### Precision : 0.0817
# ### Recall    : 0.0468
# ### F1        : 0.0595
# ###                       ###
# ###    Obtained Scores    ###
# ###    (fixed dataset)    ###
# ###
# ### Precision : 0.0823
# ### Recall    : 0.0529
# ### F1        : 0.0644
# ###                       ###
# ###    Obtained Scores    ###
# ### (full dataset,        ###
# ###  pos patterns filter) ###
# ###
# ### Precision : 0.1100
# ### Recall    : 0.0495
# ### F1        : 0.0682
# ###                       ###
# ###    Obtained Scores    ###
# ### (full dataset, top 5) ###
# ###
# ### Precision : 0.1036
# ### Recall    : 0.0401
# ### F1        : 0.0578
# ###                       ###
# ###    Obtained Scores    ###
# ### (full dataset, top 10)###
# ###
# ### Precision : 0.0900
# ### Recall    : 0.0462
# ### F1        : 0.0611
# ###                       ###
# ###    Obtained Scores    ###
# ### (full dataset, top 15)###
# ###
# ### Precision : 0.0857
# ### Recall    : 0.0466
# ### F1        : 0.0604
# ###                       ###
# ###                       ###
# ###                       ###
# ###       STEMMING        ###
# ###                       ###
# ###                       ###
# ###    Obtained Scores    ###
# ###     (full dataset)    ###
# ###
# ### Precision : 0.0882
# ### Recall    : 0.0503
# ### F1        : 0.0640
# ###                       ###
# ###    Obtained Scores    ###
# ###    (fixed dataset)    ###
# ###
# ### Precision : 0.0823
# ### Recall    : 0.0529
# ### F1        : 0.0644
# ###                       ###
# ###    Obtained Scores    ###
# ### (full dataset,        ###
# ###  pos patterns filter) ###
# ###
# ### Precision : 0.1176
# ### Recall    : 0.0525
# ### F1        : 0.0726
# ###                       ###
# ###    Obtained Scores    ###
# ### (full dataset, top 5) ###
# ###
# ### Precision : 0.1106
# ### Recall    : 0.0427
# ### F1        : 0.0617
# ###                       ###
# ###    Obtained Scores    ###
# ### (full dataset, top 10)###
# ###
# ### Precision : 0.0967
# ### Recall    : 0.0495
# ### F1        : 0.0654
# ###                       ###
# ###    Obtained Scores    ###
# ### (full dataset, top 15)###
# ###
# ### Precision : 0.0925
# ### Recall    : 0.0501
# ### F1        : 0.0650
# ###                       ###

# %%
obtained_words_top = postprocessing.get_top_words(test_doc, output, 3)

precision_top = metrics.precision(test_answer, obtained_words_top,STEM_MODE)
recall_top = metrics.recall(test_answer, obtained_words_top,STEM_MODE)
f1_top = metrics.f1(precision_top, recall_top)

print("###    Obtained Scores    ###")
print("### (full dataset, top 3) ###")
print("###")
print("### Precision : %.4f" % precision_top)
print("### Recall    : %.4f" % recall_top)
print("### F1        : %.4f" % f1_top)
print("###                       ###")
# Out:
# ###    Obtained Scores    ###
# ### (full dataset, top 3) ###
# ###
# ### Precision : 0.1161
# ### Recall    : 0.0313
# ### F1        : 0.0494
# ###                       ###

# %%
obtained_words_top
# Out:
# {'2007': [['trauma'], ['trauma', 'research'], ['medicine', 'visible']],
#  '2042': [['two-dimensional', 'and'],
#   ['instability', '-'],
#   ['space', 'plasmas']],
#  '308': [['applet'], ['connectivity'], ['individual', 'pedagogical']],
#  '215': [['decision', 'maker'], ['ten'], ['illustration']],
#  '250': [['much'], ['easier'], ['enterprise']],
#  '1996': [['synthetic', 'images', 'based'],
#   ['through', 'three', 'metrics'],
#   ['pixel', 'metric', 'which']],
#  '2162': [['>', '/sup'], ['free', 'product'], ['zfc', 'using', 'pcf']],
#  '2127': [['constructive', 'system'], ['identities'], ['illustrative']],
#  '290': [['pole', 'placement'], ['gimbal'], ['microactuator']],
#  '1956': [['dynamical', 'transition'],
#   ['one', 'period', ')'],
#   ['period', 'n']],
#  '228': [['capillary', 'gel'],
#   ['subsequent', 'ultrathin-layer', 'gel'],
#   ['ultrathin-layer', 'gel', 'electrophoresis', 'analysis']],
#  '370': [['mentioned'], ['national', 'governments'], ['real', 'laws']],
#  '2082': [['manner', 'through'],
#   ['strategic', 'stocks'],
#   ['demand', 'conditions']],
#  '335': [['voices']],
#  '249': [['randomized'], ['test-and-set', 'takes'], ['reset']],
#  '1972': [['lodging', 'industry'], ['predecessor'], ['long', 'run']],
#  '1937': [['extrapolation'], ['v.', 's.', 'pugachev']],
#  '2146': [['particularly', 'where'], ['`', 'next'], ['abandoned', 'all']],
#  '2103': [['given'], ['fastest'], ['gambling']],
#  '4': [['beleaguered', 'sector'], ['insider', 'buying'], ['surge']],
#  '354': [['exists'], ['v.'], ['fault-tolerant', 'hamiltonian']],
#  '311': [['emergent', 'phenomena'],
#   ['periodically', 'considered'],
#   ['partly', 'because']],
#  '369': [['fending', 'off'], ['sides'], ['v.', 'nissan']],
#  '401': [['differential-quad', 'switching'],
#   ['11-b', 'resolution'],
#   ['digital-to-analog', 'converter', 'based']],
#  '2023': [['array'], ['remains', 'too'], ['apertures']],
#  '394': [['intestinal', 'microflora'], ['host-microflora'], ['intestinal']],
#  '2066': [['personal', 'computer'],
#   ['historical', 'studies'],
#   ['industry-level']],
#  '27': [['implemented'], ['price'], ['uncertainty']],
#  '289': [['dynamical', 'patterns'], ['ion', 'channels'], ['memory']],
#  '2186': [['structure-directing'], ['templated', 'zeolite']],
#  '231': [],
#  '274': [['occupancy/nonoccupancy', 'interpretation'], ['pls'], ['mtd-pls']],
#  '2021': [['incoherent', 'correlator', 'based'],
#   ['introducing', 'reference'],
#   ['content-addressable', 'memory', 'processor']],
#  '396': [['assessed'], ['global'], ['strong']],
#  '2064': [['long', 'tradition'], ['additional', 'source'], ['claiming', ',']],
#  '403': [['reduction'], ['channel-erasing'], ['scale']],
#  '2099': [['large', 'scale'], ['one', 'which'], ['under', 'restrictions']],
#  '2184': [['highly', 'interconnected'], ['review'], ['system']],
#  '233': [['national', 'site', 'licensing'],
#   ['subsequent', 'phases'],
#   ['challenges']],
#  '276': [['additional', '``']],
#  '25': [],
#  '2179': [['array'], ['healnet'], ['care']],
#  '2144': [['failing', 'company', 'which']],
#  '2101': [['no', 'additional'],
#   ['optical', 'amplifiers', 'without', 'additional'],
#   ['gb/s']],
#  '1970': [['create'], ['electronic'], ['coherent', 'website']],
#  '1935': [['admissible', 'measurement'], ['possible'], ['measurement']],
#  '2200': [['foster', 'improved'], ['needed']],
#  '356': [['phase-space', 'probability', 'distribution']],
#  '313': [['including', 'where'],
#   ['logistics', 'must'],
#   ['develop', 'more', 'quickly']],
#  '2059': [['basic', 'reference']],
#  '1954': [['no'], ['horizons'], ['asymptotic']],
#  '193': [['its', 'assertion']],
#  '2160': [['throughout'], ['one'], ['ford']],
#  '2125': [['stochastic'], ['its', 'mass'], ['general']],
#  '292': [['earshell', 'vibration'],
#   ['earshell', 'using'],
#   ['single-frequency']],
#  '2038': [['becomes', 'possible'], ['borda', 'count'], ['main', 'options']],
#  '2005': [['operated', 'anatomy'],
#   ['navigation', 'technology'],
#   ['termed', "'surgeon-defined", 'anatomy']],
#  '2040': [['solvability'], ['ion'], ['exchanger']],
#  '1994': [['3-d'], ['scene', 'illuminant'], ['illumination', 'conditions']],
#  '2118': [['games', 'far', 'better'],
#   ['decisions'],
#   ['classical', 'characteristic']],
#  '217': [],
#  '252': [['year'], ['one'], ['email']],
#  '1969': [['second-order', 'moment'], ['two-dimensional'], ['multiclass']],
#  '376': [['transition', 'probabilities', 'following'],
#   ['integrated', 'out'],
#   ['transition', 'probabilities']],
#  '2084': [['routeing', 'plans', '-'],
#   ['combined', 'dispatching'],
#   ['routeing', 'policies', '-', 'no']],
#  '333': [['create'], ['using', 'appropriate', 'control'], ['stand-alone']],
#  '2164': [['implemented'], ['came', 'into', 'force'], ['electronic']],
#  '2121': [['under', 'uncertainty'], ['given'], ['studied']],
#  '296': [['help', 'non-law', 'librarians']],
#  '38': [['acronym', 'p'], ['instrument', 'symbols'], ['prepare', 'drawings']],
#  '2199': [['recognition', 'using'], ['user'], ['walking', 'behaviors']],
#  '1950': [['general'],
#   ['functionally', 'gradient', 'piezoelectric'],
#   ['blocking', 'force']],
#  '197': [['individual', 'internal', 'class-labeled'],
#   ['provides', 'improved'],
#   ['training', 'approach']],
#  '213': [['all'], ['electronic'], ['information', 'technology']],
#  '256': [['arming', 'yourself'], ['considers', 'how', 'one'], ['debugging']],
#  '1990': [['electrical', 'facility', 'construction', 'work'],
#   ['sewer', 'optical', 'fiber', 'teleway'],
#   ['about', '470', 'km']],
#  '40': [['also', 'given'], ['autotuner', 'based']],
#  '2159': [['host'], ['producers'], ['real-time', 'enterprise']],
#  '2001': [['simple', 'graphic', 'approach'],
#   ['observer', 'decomposition', 'based', 'upon'],
#   ['systematic', 'procedure']],
#  '2044': [['indoor', 'environment', 'using'], ['indoor', 'propagation']],
#  '21': [['feedback', 'sliding', 'mode'],
#   ['switching', 'line'],
#   ['switching', 'line', 'technique']],
#  '2138': [['reachability', 'sets'], ['upper', 'estimate']],
#  '1949': [['individual', 'voxels'],
#   ['vivo', 'measurement'],
#   ['resonance', 'imaging']],
#  '2180': [['efficient', 'electronic'],
#   ['health-checkup', 'data', 'based'],
#   ['health/medical']],
#  '237': [['north', 'america'], ['international'], ['agendas']],
#  '272': [['divided', 'into'], ['which', 'representative']],
#  '407': [['define', 'types', ','], ['help'], ['generating', 'code']],
#  '2025': [['capture'], ['one', 'consists']],
#  '392': [['suggesting', 'more', 'complex'],
#   ['time-frequency', 'plane'],
#   ['discern', 'differences']],
#  '2060': [['decisions'],
#   ['academic', 'environment'],
#   ['questions', 'about', 'development']],
#  '2018': [['highly'], ['shaped', 'objects', 'using'], ['3-d']],
#  '2': [['hyped', 'ad'], ['nauseam']],
#  '352': [['stripping'], ['which', 'video'], ['efficient', 'retrieval']],
#  '317': [['citation'], ['one'], ['democracy']],
#  '1974': [['memory', 'requirement'], ["codec's"], ['using']],
#  '1931': [['decision', 'procedure', 'based'],
#   ['decision-making'],
#   ['bayesian']],
#  '2140': [['strong', 'active'],
#   ['non-cooperative', 'games'],
#   ['its', 'place']],
#  '2105': [['offline', 'action'], ['thriving'], ['socially']],
#  '1989': [['managing', 'system']],
#  '350': [['message', 'reaching', 'its', 'destination', 'without']],
#  '315': [['national'], ['services'], ['identify']],
#  '2142': [['consideration'], ['transcendental'], ['under']],
#  '2107': [['much', 'previous'],
#   ['personal', 'identifiability'],
#   ['dispersed', 'computer', 'users']],
#  '208': [['networked', 'electronic', 'environment'], ['simple', 'linkage']],
#  '1976': [['denoising', 'using', 'scale'],
#   ['gradient', 'magnitudes'],
#   ['where', 'homogeneous', 'regions']],
#  '1933': [['general'], ['availability'], ['repair']],
#  '2182': [['unstable', 'environment'],
#   ['continuing', 'influence'],
#   ['create']],
#  '235': [['north', 'america'], ['australian'], ['council']],
#  '270': [['molecular', 'equivalence', 'numbers'],
#   ['functional', 'groups'],
#   ['library', 'which']],
#  '23': [['self-excitation'], ['low-frequency'], ['absorption']],
#  '2027': [['estimates', 'using'], ['correspondence'], ['images']],
#  '390': [['breath', 'detection'], ['interest', 'where']],
#  '2062': [['underground']],
#  '328': [['confound'], ['increasingly'], ['published', 'studies']],
#  '405': [['learned'], ['inductive', 'logic', 'programming'], ['horn-clause']],
#  '1992': [['digital'], ['weaknesses'], ['develop', 'an']],
#  '211': [['goes'], ['managers'], ['also', 'at']],
#  '254': [['you', "'ll"], ['busy'], ['handful']],
#  '349': [['plus', 'one', '``'],
#   ['reserved', 'specifically'],
#   ['designated', '``']],
#  '2003': [['carbonate', 'fuel', 'cells'], ['also', 'adaptively'], ['improve']],
#  '2046': [['preparation'], ['university', 'course', '-'], ['accumulated']],
#  '389': [['electroencephalogram'],
#   ['event-related', 'data'],
#   ['synthetic', 'data']],
#  '374': [['also', 'derived'],
#   ['ground'],
#   ['horizontal', 'waypoint', 'guidance']],
#  '2086': [['product', 'development', 'presents'],
#   ['economical', 'assembly', 'technique'],
#   ['user']],
#  '331': [['multidimensional'], ['varying', 'degrees'], ['sas-jmp']],
#  '1952': [['solid-state', 'quantum'],
#   ['addressing', 'solid-state', 'proposals'],
#   ['decoherence', 'due']],
#  '195': [['music', 'vocabulary'],
#   ['music', 'publishing'],
#   ['out-of-print', 'printed']],
#  '269': [['126', 'descriptors'], ['31', 'compounds'], ['procedure', 'based']],
#  '2166': [['passing', 'off'], ['reed', 'solutions', 'plc'], ['infringement']],
#  '2123': [['hidden'], ['under']],
#  '294': [['million', 'items'], ['located'], ['ohio', 'state']],
#  '312': [['works', 'using'], ['architecture', 'portion'], ['filling']],
#  '357': [['separable', 'banach', 'space']],
#  '2058': [['four', 'factors'], ['which'], ['explained']],
#  '2100': [],
#  '2145': [['at'], ['netsec', '2002', 'netsec', '2002', 'took', 'place']],
#  '1934': [['computational', 'finite-element', 'schemes'],
#   ['space', 'u'],
#   ['feasible', 'control']],
#  '1971': [['global', 'electronic'], ['strategic', 'exploitation'], ['rm']],
#  '277': [['attractive'], ['prediction'], ['predicting']],
#  '2185': [['gem', 'must'], ['frameworks', 'only'], ['gem']],
#  '232': [['distributed', 'ilumina'], ['library', 'services']],
#  '2178': [['health'], ['st'], ['challenges']],
#  '24': [['approaches'], ['function', 'approximation'], ['not', 'possible']],
#  '2065': [['substrate'], ['motive', 'force'], ['where']],
#  '2020': [['array'], ['phased'], ['scenes', 'containing']],
#  '397': [['dqm'], ['dqm', 'reduces'], ['pade']],
#  '402': [['gsamples/s'], ['10.fo-4'], ['phase-frequency', 'detectors']],
#  '2098': [['p/sup'], ['gradient'], ['hele-shaw', 'flows']],
#  '1995': [['surfaces', 'in', 'scenes', 'generated'],
#   ['using', 'synthesized'],
#   ['scene', 'illuminant']],
#  '2119': [['adjacency', 'matrix', 'based'], ['transport'], ['given']],
#  '253': [['article', 'provides'],
#   ['your', 'users'],
#   ['interface', 'elements']],
#  '216': [['38', 'ghz', 'locally'], ['20', 'degrees'], ['tcs']],
#  '1968': [['phase-dependent', 'photon'],
#   ['transition-based', 'fluorescent'],
#   ['pump']],
#  '2041': [['conventionally', 'characterized'],
#   ['gas-dynamic', 'problems'],
#   ['passing', 'interface', '-']],
#  '2004': [['extract'], ['medical'], ['sensory', 'feedback']],
#  '2039': [['coefficient'], ['hierarchical'], ['solvability']],
#  '2081': [['integral', 'sensitivity', 'formulations'], ['moulds']],
#  '373': [['personal', 'digital', 'assistants'], ['point-will'], ['biggest']],
#  '1955': [['evacuation', 'processes'],
#   ['evacuation', 'times'],
#   ['evacuation']],
#  '2124': [['multidimensional', 'stability']],
#  '293': [['which', 'active'], ['reduction'], ['theoretically', 'calculating']],
#  '2161': [['let'], ['algebraic', 'properties', ','], ['intuitionistic']],
#  '2083': [['pro-e', 'data'], ['blades', 'using'], ['impulse', 'turbine']],
#  '334': [['twisted'], ['copper', 'pair'], ['copper']],
#  '371': [['november', '2000'], ['widespread', 'fraud'], ['voting', 'issues']],
#  '2126': [['time-optimal']],
#  '291': [['resonance'], ['interactions'], ['coherent', 'long-lived', '/sup']],
#  '2163': [['consistently', 'successful'],
#   ['client', 'expectations'],
#   ['professional', 'services']],
#  '1957': [['restraining', 'effect'], ['improved', 'model'], ['wolves']],
#  '229': [['simple']],
#  '251': [['gui', 'environment'], ['plus', 'tight', 'integration'], ['6.0']],
#  '214': [['personal', 'computer'], ['technology']],
#  '1997': [['fourier', 'method']],
#  '2043': [['underlying', 'computer'],
#   ['judge'],
#   ['algorithmic', 'complexity']],
#  '2006': [['extremities'],
#   ['metastasis', 'detection'],
#   ['two-dimensional', 'followed']],
#  '309': [['javascripts', 'needed'], ['scales'], ['experimental', 'procedure']],
#  '288': [['memory'], ['global'], ['upper', 'bounds']],
#  '26': [['weighted', 'means'], ['means'], ['also', 'called']],
#  '275': [['organic', 'compounds', 'using'],
#   ['procedure', 'would', 'benefit'],
#   ['prediction']],
#  '2187': [['compensating', 'uncertainty'],
#   ['pm', 'synchronous', 'servo'],
#   ['pm', 'synchronous']],
#  '230': [['date']],
#  '368': [['simple', 'environment'],
#   ['autonomous', 'behavior'],
#   ['autonomous', 'system']],
#  '400': [['fabricated', 'using'],
#   ['logic', 'technology'],
#   ['frame-buffer', 'architectures']],
#  '2067': [['health', 'whilst'], ['health'], ['intertemporal']],
#  '2022': [['two-step', 'integral', 'imaging'], ['3-d'], ['orthoscopic']],
#  '395': [['excellent', 'agreement'],
#   ['additional', 'degrees'],
#   ['conformal-mapping']],
#  '310': [['epsych'], ['phenomena'], ['modules']],
#  '355': [['identity-based', 'society', 'oriented'],
#   ['only', 'one', 'identity']],
#  '248': [['symmetry-breaking', 'conditions'],
#   ['proof', 'technique'],
#   ['n', 'processors']],
#  '1936': [['n'], ['q-partitions.ii'], ['minterms']],
#  '1973': [['registration', 'and'], ['show', 'how'], ['yang']],
#  '2102': [['studies']],
#  '2147': [['ado'], ['virus'], ['impossible']],
#  '2063': [['contradict', '-'], ['-', 'much'], ['conspicuously']],
#  '2026': [['minimizer', 'exists'], ['its', 'convergence'], ['types']],
#  '391': [['bayes'], ['vefs'], ['wald']],
#  '329': [['literacy', 'skills'], ['document-level'], ['tremendous']],
#  '404': [['1.8-v', '0.18-'],
#   ['10-t', 'sls', 'memory', 'cell'],
#   ['l1/l2', 'hit']],
#  '271': [['definitive'], ['capitalizing'], ['krogh']],
#  '2183': [['quinn'], ['relating'], ['employing']],
#  '234': [['national', 'electronic']],
#  '22': [['conventional', 'car-based', 'wafer-lot', 'delivery'],
#   ['transport', 'technology']],
#  '2106': [['accident'], ['composed', 'primarily'], ['community', 'cases']],
#  '2143': [['scaling'], ['technology', 'could'], ['challenges']],
#  '209': [["no-man's"]],
#  '1932': [['three', 'possible'],
#   ['initial', 'state'],
#   ['2', 'residue', 'class']],
#  '1977': [['background', 'clutter'],
#   ['edge', 'map'],
#   ['tracking', 'nonparameterized', 'object', 'contours']],
#  '314': [['finished', 'product-has'], ['just', 'where', 'did'], ['label']],
#  '351': [['availability'], ['j', '='], ['minimizing', 'makespan']],
#  '1953': [['stationary', 'state'],
#   ['mass', 'media'],
#   ['quality', 'expectations']],
#  '194': [['implemented'], ['loan'], ['patron', 'comments']],
#  '268': [['illuminating', 'the', 'multidimensional', 'structural'],
#   ['regions'],
#   ['interest', 'at']],
#  '2122': [['fuzzy-logic', 'adaptation'],
#   ['adaptation', 'circuit'],
#   ['discreteness', 'period']],
#  '295': [['academic', 'library'], ['compares'], ['national']],
#  '2167': [['formally', 'tabled'], ['deemed'], ['national', 'patent', 'laws']],
#  '388': [['procedure'], ['gauss-newton'], ['sinus']],
#  '2087': [['conditions', 'using', 'fractals', 'presents'],
#   ['which', 'challenges', 'conventional']],
#  '330': [['passwords'], ['procedure'], ['improving', 'computer']],
#  '375': [['individual', 'source'],
#   ['latest', 'source'],
#   ['signal', 'location']],
#  '348': [['almost', 'all'], ['secret']],
#  '2047': [['pert/cpm'], ['spreadsheet', 'environment']],
#  '2002': [['subspace', 'identification'],
#   ['subspace', 'identification', 'approach'],
#   ['consistent', 'estimates']],
#  '1993': [['inter-channel', 'correlation'], ['not', 'performed'], ['suffer']],
#  '255': [['affecting'], ['falls', 'short'], ['profit']],
#  '210': [['mistakes'], ['describe', 'two'], ['discuss', 'reasons']],
#  '2045': [['dynamic', 'programming'], ['flip', 'analysis']],
#  '2000': [['sampled'], ['study', 'digital', 'control'], ['non-uniformly']],
#  '257': [['including', 'pointers'], ['memory']],
#  '212': [['programme', 'called'], ['eskom'], ['recent']],
#  '1991': [['information-theoretic', 'model']],
#  '41': [['explicit', 'parametric'], ['tradeoff'], ['obtained']],
#  '2158': [['competitive'], ['integrated'], ['press', 'shop']],
#  '2120': [['active'], ['weighted']],
#  '39': [['which'], ['supervisory'], ['detector']],
#  '297': [['accessibility', 'more'], ['not'], ['library', 'buildings']],
#  '2165': [['damage']],
#  '2198': [['middleware'], ['pervasive'], ['spontaneous']],
#  '1951': [['resonance'], ['procedure', 'at'], ['ground', 'state', 'spin']],
#  '196': [['hidden', 'unit', 'space'], ['principle', 'extract'], ['learned']],
#  '2085': [['promising', 'tool'], ['decision', 'system'], ['at', 'multiple']],
#  '332': [['psychological', 'studies'], ['nlmixed', 'procedure'], ['sas']],
#  '377': [],
#  '1930': [['node-function-object', 'class'],
#   ['procedure'],
#   ['formalized', 'nfo/ufo']],
#  '1975': [['moments', 'local'], ['inherently'], ['moments', 'computed']],
#  '2104': [['problems', 'experienced'], ['remoteness'], ['inappropriate']],
#  '2141': [['interrelated', 'problems-design'],
#   ['plant', 'state', 'separately']],
#  '1988': [['climate'], ['eai'], ['enterprise']],
#  '2019': [['scene', 'analysis'],
#   ['under', 'different'],
#   ['vehicle', 'region', 'based']],
#  '3': [["n't", 'raise', 'cash'], ['nuvox'], ['shows', 'staying']],
#  '316': [['article', 'also', 'shows'], ['simple']],
#  '353': [['simple']],
#  '406': [['built-in', 'capabilities'], ['much', 'more'], ['desktop']],
#  '2061': [['electronic'], ['james', 'ford', 'bell'], ['saying', 'no']],
#  '2024': [['binocular'], ['occluding', 'images'], ['figure-ground']],
#  '393': [['long', 'period'],
#   ['simultaneous', 'perturbation', 'stochastic'],
#   ['much', 'more']],
#  '20': [['uncertain', 'dynamical'],
#   ['robust'],
#   ['exponentially', 'practically']],
#  '2139': [['confidence'], ['normally', 'distributed'], ['possible']],
#  '1948': [['population', 'within'],
#   ['personal', 'computer'],
#   ['electronic', 'population', 'data']],
#  '273': [['bioavailability'], ['scale', 'must'], ['scaling']],
#  '2181': [['resting'], ['improvement'], ['defined']],
#  '236': [['kluwer', 'academic'], ['licensing', 'strategy']],
#  '362': [['insertions', 'through'], ['enormous', 'volume'], ['indexes']],
#  '2090': [['higher']],
#  '327': [['assessed'], ['sert'], ['assessing', 'reader']],
#  '2028': [['centroid', 'detection', 'based'], ['slms']],
#  '2170': [['help'], ['electronic'], ['team']],
#  '2135': [['decisive'], ['subject'], ['under', 'discussion']],
#  '282': [['teachers'], ['decision', 'based'], ['decision']],
#  '1944': [['explored', 'herein'], ['electronic', 'tendering'], ['electronic']],
#  '207': [['challenges', 'beyond', 'those']],
#  '242': [['california', 'digital'], ['more', 'proposals']],
#  '1979': [['scales'], ['gradient', 'amplitudes'], ['gradient', 'phases']],
#  '1984': [['deriving'], ['generator', 'control']],
#  '2108': [['sample', 'attrition'],
#   ['trauma'],
#   ['longitudinal', 'survey', 'research']],
#  '2015': [['optical', 'recognition']],
#  '2050': [['classroom', 'edition'], ['television']],
#  '35': [['additional', 'measurements'], ['qbg'], ['bond', 'graph']],
#  '2169': [['electronic', 'delivery'], ['main', 'issues'], ['e-government']],
#  '2194': [['directory', 'services'],
#   ['services', 'location-dependent', 'information'],
#   ['research', 'issues', 'must']],
#  '223': [['broadcasting']],
#  '266': [['molecular', 'surfaces'],
#   ['hydrogen', 'bond'],
#   ['atomistic', 'resolution']],
#  '413': [['generalizing'], ['beliefs', 'regarding'], ['also', 'measured']],
#  '2089': [['biggest'], ['system']],
#  '2031': [['parabola'], ['s-function-are'], ['speeding']],
#  '386': [['simple'], ['signal', 'space', 'projection'], ['matched-filter']],
#  '2049': [['possible', 'evpi'],
#   ['probability', 'distribution'],
#   ['upper', 'bound']],
#  '346': [['division'], ['division', 'using'], ['not']],
#  '303': [['spanish'], ['normative', 'data'], ['identification', 'thresholds']],
#  '1960': [['large'], ['streaming'], ['simple']],
#  '2154': [['it/'], ['ideal', 'basis'], ['tremendous']],
#  '2111': [['fluorescence', 'provides'],
#   ['individual', 'cells'],
#   ['intact', 'leaves']],
#  '344': [['real', 'capabilities'], ['student'], ['benefit', 'faculty']],
#  '301': [['my'], ['challenges'], ['broader']],
#  '2156': [['expertise', 'might'], ['one'], ['solutions']],
#  '2113': [['ideal', 'sliding', 'mode'], ['sliding']],
#  '259': [['bolts', ':'], ['encode'], ['finding', 'aids']],
#  '1962': [['bagsik'], ['oscillator', 'without', 'complex']],
#  '2196': [['improve', 'electronic'], ['informing', 'users']],
#  '264': [['bearman'], ['article', 'provides'], ['archivist', 'l.']],
#  '198': [['receptor', 'affinity', 'distribution'],
#   ['scaling'],
#   ['sensory', 'neurons', 'whose']],
#  '37': [['frequency-domain', 'response', 'practical'],
#   ['frequency-domain', 'response'],
#   ['maclaurin']],
#  '299': [['library', 'strategic', 'system'],
#   ['library', 'strategic'],
#   ['interlibrary', 'loan']],
#  '2033': [['encode'], ['optical', 'encoding']],
#  '384': [['on-board'], ['initial', 'attitude', 'acquisition'], ['attainable']],
#  '379': [['array'], ['pv'], ['solar', 'cell']],
#  '411': [['reducing'], ['flyback', 'converter'], ['electronic']],
#  '1986': [['package'], ['center', 'must'], ['which', 'after']],
#  '205': [['geotensity'], ['lighting']],
#  '240': [['relevant', 'experience', 'through'],
#   ['life', 'cycle'],
#   ['cornell', 'university']],
#  '318': [['schedule', 'exists'], ['yang', 'et']],
#  '2017': [['accurate', 'micro', 'measurement'],
#   ['focal'],
#   ['beam', 'approach']],
#  '2052': [['my'], ['blitzograms', '-'], ['more']],
#  '408': [["it's", 'probably'], ['benefit', 'at', 'all'], ['simply', 'makes']],
#  '360': [['either', 'directly'], ['multiplicative'], ['represented']],
#  '2092': [['ct/sub'], ['represented'], ['1.3']],
#  '325': [['course-related'], ['higher']],
#  '1946': [['great', 'interest'],
#   ['development', 'technology'],
#   ['bms', 'local']],
#  '238': [['oai'], ['effective', 'digital'], ['simple']],
#  '2172': [['packages'], ['electronic'], ['enabling', 'technology']],
#  '2137': [['boundedness'],
#   ['frequency-modulated', 'pulsed'],
#   ['unstable', 'continuous']],
#  '280': [['promote'], ['student', 'through'], ['interest']],
#  '2013': [['noise', 'sensitivity'], ['randomness'], ['superresolved']],
#  '2056': [['great', 'amounts'], ['altruistic'], ['donate', 'materials']],
#  '359': [['categories'], ['pawlak']],
#  '201': [['panoramic'], ['which', 'whilst'], ['panoramic', 'image']],
#  '244': [['rapidly', 'expanding', 'electronic'],
#   ['symbiosis'],
#   ['joint', 'efforts']],
#  '1982': [],
#  '2176': [['your'], ['wrong'], ['not', 'whether']],
#  '2133': [['multirings', 'and', 'hypercubes', 'at'],
#   ['conflictless'],
#   ['divided']],
#  '284': [['louisiana'],
#   ['cajun', 'culture', 'using'],
#   ['learned', 'computer']],
#  '1942': [['isi', 'channel', 'into'], ['division'], ['rate', 'transmission']],
#  '279': [['university', 'international'],
#   ['procedure', 'blends'],
#   ['skills', 'through']],
#  '364': [['necessary', 'facilities'], ['logic', 'programming'], ['multi']],
#  '2096': [['areas', 'where'], ['year'], ['stations']],
#  '321': [['similar', 'programs', 'could'],
#   ['collection', 'procedure'],
#   ['procedural', 'issues']],
#  '399': [['supporting', 'more', 'cells'],
#   ['low-voltage', 'dram'],
#   ['operations', 'more']],
#  '218': [['fibre']],
#  '1966': [['recurrence', 'quantification'],
#   ['dollar'],
#   ['also', 'demonstrated']],
#  '2152': [['global', 'manufacturing'],
#   ['real-time', 'collaboration'],
#   ['global']],
#  '2117': [['commutators'], ['p-1'], ['generalized', 'hypercubes']],
#  '340': [['about', 'temelin'], ['czech'], ['casts']],
#  '305': [['full-screen', 'display'], ['routine', 'calling']],
#  '338': [],
#  '2037': [['pseudoinverse']],
#  '380': [['srm', 'drive', 'using'], ['its', 'highly'], ['conditions']],
#  '33': [['feedback', 'control'], ['interactions'], ['decoupling']],
#  '2192': [['autonomous'], ['middleware'], ['programming']],
#  '225': [['help', 'lodging', 'establishments'],
#   ['properly', 'integrated', 'into'],
#   ['do']],
#  '260': [['do']],
#  '2035': [['procedure'], ['multi-criterion', 'maximization'], ['vector']],
#  '382': [['robust', 'wavelet', 'neuro', 'control']],
#  '2070': [['modularity'], ['raid']],
#  '1959': [['quantum', 'game'], ['quantum', 'market']],
#  '2190': [['discovery', 'and', 'delivery'], ['hour', 'goes']],
#  '227': [['explicit'], ['distinguishability'], ['orthogonal']],
#  '262': [['about', 'institutional'],
#   ['ead', 'adoption', 'on', 'archival', 'programs'],
#   ['gathering', 'data', 'related']],
#  '31': [['jet', 'engine'], ['composed'], ['radial', 'basis', 'function']],
#  '2128': [['reduction'], ['sequential', 'refinement']],
#  '2150': [['also', 'provides'],
#   ['large', 'industrial', 'buildings'],
#   ['acquire']],
#  '2115': [['low-temperature'], ['steam'], ['toxicity']],
#  '1999': [['d/sub'], ['dead-time'], ['iae']],
#  '1964': [['antipersistent', 'markov', 'behavior']],
#  '342': [['credits'], ['sinai', 'hospital']],
#  '307': [['accumulative'], ['experiencing']],
#  '2008': [['storing', 'more'], ['scene', 'construction'], ['downloadable']],
#  '2189': [],
#  '1940': [['error-correcting', 'codes'], ['z-channel']],
#  '2174': [['mailshell', "'s", 'free'], ['mailshell', 'allows'], ['spam']],
#  '2131': [['closed', 'heat']],
#  '286': [['array-based', 'calculations'],
#   ['spectroscopic', 'data'],
#   ['vivo', 'raman']],
#  '28': [['means'], ['procedure'], ['uncertainty']],
#  '2069': [['organizational', 'structures', 'mix'],
#   ['ultimate'],
#   ['under', 'which', 'superiors']],
#  '366': [['rail'], ['rail', 'grade'], ['federal', 'railroad']],
#  '2094': [['decision', 'procedure'],
#   ['inequality', 'potter'],
#   ['partial', 'prior']],
#  '323': [['create'], ['composed'], ['user']],
#  '2011': [['discontinuity-restoring'], ['wrapped', 'map']],
#  '2054': [['array'], ['decision', 'analysis'], ['skills']],
#  '1980': [['resonance', 'images'], ['3-d'], ['competitive', 'performances']],
#  '2149': [['about', 'how'], ['basics'], ['not']],
#  '203': [['scene', "'s", 'plenoptic'], ['plenoptic'], ['scene']],
#  '246': [['where', 'n'], ['unit'], ['which', 'every', 'active']],
#  '1938': [['reducing']],
#  '2032': [['logic', 'approach']],
#  '385': [['general'], ['hypotheses', 'into'], ['spawning', 'multiple']],
#  '378': [['incremental', 'motion', 'control'],
#   ['multisegment', 'switching', 'surfaces'],
#   ['pc-based', 'computer']],
#  '410': [['dc'], ['ohmic', 'losses'], ['damping', 'effects']],
#  '265': [['molecular', 'surfaces'], ['biomolecular'], ['complexes', 'one']],
#  '2197': [['decision', 'engine']],
#  '220': [],
#  '199': [['hair', 'cell'], ['role', 'played'], ['cochlear', 'nucleus']],
#  '298': [['create'], ['electronic'], ['electronic', 'services', 'librarians']],
#  '36': [['overshoot'],
#   ['becomes', 'even', 'more'],
#   ['tight', 'temperature', 'control']],
#  '2112': [['d.w.'], ['voluminous', 'literature']],
#  '2157': [['high-volume', 'production'],
#   ['offline', 'programming'],
#   ['rudimentary']],
#  '258': [['digital', 'environment'],
#   ['building', 'digital', 'collections'],
#   ['issues', 'explored']],
#  '1963': [['powerlaw', 'nature'], ['not'], ['businesses', 'which']],
#  '300': [['compelling'], ['believed'], ['do', 'so']],
#  '345': [['define', 'strategic'], ['sis'], ['sustainable', 'competitive']],
#  '1947': [['user', 'acceptance']],
#  '239': [['electronic'], ['electronic', 'book']],
#  '2136': [['its', 'complexity']],
#  '281': [['either', 'came'], ['autonomous'], ['teachers', 'needed']],
#  '2173': [['administering'], ['encryption'], ['which', 'e-mails']],
#  '2093': [['accurately', 'track', 'meat'], ['database']],
#  '324': [['create'],
#   ['assisted', 'quality'],
#   ['eliminating', 'inconsistencies']],
#  '361': [['methodological', 'approach'], ['pretopological']],
#  '319': [['optimum', 'test'], ['tseng', 'et'], ['reasonable', 'life-testing']],
#  '2053': [['primary', 'delivery', 'vehicle'], ['future'], ['decision']],
#  '2016': [['interest', 'location'], ['inspection'], ['interest']],
#  '1987': [['goes'], ['worms'], ['notch']],
#  '241': [['see', 'potential'], ['1999.', 'issues'], ['interest']],
#  '204': [['not', 'possible'], ['four', 'successive'], ['measurements']],
#  '2051': [['$', 'million', 'error'],
#   ['increasingly', 'difficult', 'multiple'],
#   ['television', 'show']],
#  '2014': [['noise'], ['more', 'difficult'], ['hue']],
#  '243': [['electronic'], ['kansas'], ['full-text']],
#  '206': [['consider', 'where'], ['no', 'means']],
#  '1978': [['others'], ['superposition'], ['studied', 'its']],
#  '1985': [['interconnected', 'bulk'], ['future', 'computer'], ['prospective']],
#  '2109': [['psychological', 'experimenting'],
#   ['grouped', 'into'],
#   ["internet's"]],
#  '2134': [['l-level', 'circuit', 'based'],
#   ['algebraic', 'model'],
#   ['l', 'decision', 'diagrams']],
#  '283': [['so', 'far'], ['sixth-grade', 'classrooms'], ['middle', 'schools']],
#  '2171': [['future', 'reference'], ['area', 'previously'], ['stored', 'off']],
#  '1945': [['gravity'], ['inspectors', 'must', 'stand'], ['inspection']],
#  '2091': [['fbp'], ['minimization'], ['tomography', 'imaging']],
#  '326': [['learners', 'received'], ['explicit'], ['explicit', 'instructions']],
#  '363': [['decisions'], ['observations'], ['element']],
#  '2029': [['its', 'simple']],
#  '1961': [['also', 'obtain'], ['toll', 'collection']],
#  '2110': [['methodological', 'issues'], ['interactions'], ['useable']],
#  '2048': [['package'], ['simlib'], ['simple']],
#  '302': [['celex'], ['382'], ['month']],
#  '347': [['rm'], ['nonairline', 'industries']],
#  '412': [['objects', 'too'], ['vr'], ['grades']],
#  '2088': [['layer-based', 'machining'], ['stacking'], ['major']],
#  '2030': [['digital', 'holography'], ['its', 'simplicity'], ['simple']],
#  '387': [['help', 'users'], ['illuminated', 'at'], ['phone', 'numbers']],
#  '2168': [['international', 'agreement', 'might'],
#   ['europe', "'s"],
#   ['cybercrime']],
#  '34': [['multiobjective'],
#   ['multiobjective', 'robust', 'control'],
#   ['pid-type', 'controllers', 'using']],
#  '267': [['ao', 'integrals'], ['mp2']],
#  '2195': [['modeling', 'privacy'],
#   ['deriving', 'socially', 'based'],
#   ['socially']],
#  '306': [['comparing', 'keyboard'],
#   ['external', 'measurement', 'equipment'],
#   ['midi']],
#  '343': [['your', 'ideas'], ['cooperative', 'projects'], ['ideas', 'into']],
#  '2009': [['disconnected', 'mesh'], ['tetrahedral', 'objects'], ['mesh']],
#  '2114': [['recovery'], ['serviceability', 'recovery']],
#  '2151': [['industrial/sup'], ['buildings'], ['it/']],
#  '1998': [['pneumatic', 'control'],
#   ['procedure'],
#   ['compensator', 'for', 'pneumatic']],
#  '1965': [['low-dimensional', 'dynamical'],
#   ['which'],
#   ['low-dimensional', 'chaotic', 'trajectory']],
#  '1958': [['levy', 'distributions'], ['path'], ['simple', 'stochastic']],
#  '263': [['promote'], ['electronic'], ['pedagogical']],
#  '2191': [['attractive', 'input', 'mechanism'],
#   ['interface', 'designers', 'must'],
#   ['limited', 'speech', 'interfaces']],
#  '226': [['deceptively', 'simple'], ['one', 'computer'], ['spread']],
#  '30': [['reduction'], ['trapezoid'], ['sample', 'data']],
#  '2129': [['constants', 'obtained'],
#   ['nontrigonometrical', 'polynomials'],
#   ['similar', 'approach']],
#  '383': [['no', 'outliers'], ['mle'], ['robust']],
#  '1981': [['improving', 'stability'], ['wide', 'range'], ['pss']],
#  '2148': [['must', 'fit'], ['guidance'], ['do', 'international']],
#  '247': [['situations', 'where'], ['only', 'one'], ['wait', 'until']],
#  '202': [['3-d', 'surfaces'], ['package'], ['curvature']],
#  '1939': [['upper', 'bounds'],
#   ['considered', 'types'],
#   ['natural', 'numbers', 'criteria']],
#  '2055': [['mba', "'s"], ['preparation'], ['mba', 'programs']],
#  '2010': [['scales'], ['prior', 'distribution'], ['scales', 'depends']],
#  '2068': [['french'], ['large', 'firms'], ['temporary']],
#  '2095': [['almost', 'all'], ['phenomenon'], ['kinetics']],
#  '322': [['real', 'world', 'much'], ['much'], ['test']],
#  '367': [['consultation'],
#   ['consultation', 'system'],
#   ['linguistic', 'activities']],
#  '2188': [['dc'], ['additional', 'state'], ['large', 'disturbances']],
#  '1941': [['descriptological'], ['descriptological', 'foundations']],
#  '2130': [['real', 'numbers'], ['inequalities'], ['without']],
#  '29': [['becomes', 'organized'], ['polynomial']],
#  '287': [['where', 'n'], ['core', 'flux'], ['voice-coil', 'inductance']],
#  '2175': [['at'], ['excellent', 'customer'], ['help']],
#  '2097': [['also', 'all'], ['node', 'pair'], ['undirected', 'graphs']],
#  '320': [['warranty'], ['items'], ['repair']],
#  '365': [['break', 'off'], ['predicting'], ['prognoses']],
#  '398': [['active'], ['also'], ['db']],
#  '2132': [['multiversion'],
#   ['majority-redundant', 'computer-aided'],
#   ['fault-tolerant']],
#  '285': [['information', 'complexity'],
#   ['comprehension', 'goes'],
#   ['reduction']],
#  '2177': [['implemented'], ['made', 'possible'], ['professor', 'jean-raoul']],
#  '1943': [['thus', 'reducing'], ['help'], ['pc', 'users']],
#  '278': [['qsar', 'analysis'],
#   ['two-dimensional', 'molecular'],
#   ['vertex', 'degrees']],
#  '245': [['herein'], ['error', 'assessment'], ['hitherto']],
#  '200': [['implemented'], ['inhibition'], ['preintegration']],
#  '1983': [['challenges'],
#   ['great', 'insight', 'into'],
#   ['rapidly', 'changing']],
#  '2057': [['four', 'factors'], ['2'], ['which']],
#  '2012': [['contouring', 'using'], ['in-plane', 'deformation'], ['moire']],
#  '358': [['interval-valued'], ['lies']],
#  '32': [['linguistic', 'vector'], ['linguistic', 'version'], ['vectors']],
#  '261': [['outreach'], ['pilgrim'], ['administering', 'large', 'academic']],
#  '2193': [['electronic'], ['pervasive'], ['user']],
#  '224': [['help'], ['sun'], ['test']],
#  '339': [['implemented'], ['multiresolution'], ['registration', 'technique']],
#  '414': [['electronic', 'telecommunications'], ['prospective', 'teachers']],
#  '2036': [],
#  '381': [['scaling'], ['80196kc'], ['scaling', 'factors']],
#  '304': [['web-accessible', 'database'],
#   ['1,945', 'basic'],
#   ['pronunciation']],
#  '341': [['slates'], ['team'], ['hat']],
#  '219': [['pci', 'card', 'saves'], ['shields']],
#  '1967': [['42-55'], ['daily', 'realized'], ['effectively', 'captures']],
#  '2116': [],
#  '2153': [['palletizing'], ['united', 'states'], ['usps', 'processing']]}

# %%
output.shape
# Out:
# (500, 800, 3)

# %%
output[0][0]
# Out:
# array([0.9821014 , 0.00326481, 0.01463387], dtype=float32)

# %%
obtained_words_top = postprocessing.get_top_words(test_doc, output, 3)

precision_top = metrics.precision(test_answer, obtained_words_top,STEM_MODE)
recall_top = metrics.recall(test_answer, obtained_words_top,STEM_MODE)
f1_top = metrics.f1(precision_top, recall_top)

print("###    Obtained Scores    ###")
print("### (full dataset, top 3) ###")
print("###")
print("### Precision : %.4f" % precision_top)
print("### Recall    : %.4f" % recall_top)
print("### F1        : %.4f" % f1_top)
print("###                       ###")

obtained_words_top = postprocessing.get_top_words(test_doc, output, 5)

precision_top = metrics.precision(test_answer, obtained_words_top,STEM_MODE)
recall_top = metrics.recall(test_answer, obtained_words_top,STEM_MODE)
f1_top = metrics.f1(precision_top, recall_top)

print("###    Obtained Scores    ###")
print("### (full dataset, top 5) ###")
print("###")
print("### Precision : %.4f" % precision_top)
print("### Recall    : %.4f" % recall_top)
print("### F1        : %.4f" % f1_top)
print("###                       ###")

obtained_words_top = postprocessing.get_top_words(test_doc, output, 10)

precision_top = metrics.precision(test_answer, obtained_words_top,STEM_MODE)
recall_top = metrics.recall(test_answer, obtained_words_top,STEM_MODE)
f1_top = metrics.f1(precision_top, recall_top)

print("###    Obtained Scores    ###")
print("### (full dataset, top 10) ###")
print("###")
print("### Precision : %.4f" % precision_top)
print("### Recall    : %.4f" % recall_top)
print("### F1        : %.4f" % f1_top)
print("###                       ###")
# Out:
# ###    Obtained Scores    ###
# ### (full dataset, top 3) ###
# ###
# ### Precision : 0.1161
# ### Recall    : 0.0313
# ### F1        : 0.0494
# ###                       ###
# ###    Obtained Scores    ###
# ### (full dataset, top 5) ###
# ###
# ### Precision : 0.1106
# ### Recall    : 0.0427
# ### F1        : 0.0617
# ###                       ###
# ###    Obtained Scores    ###
# ### (full dataset, top 10) ###
# ###
# ### Precision : 0.0967
# ### Recall    : 0.0495
# ### F1        : 0.0654
# ###                       ###
